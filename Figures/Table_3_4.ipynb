# %%
from pathlib import Path

import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.multitest import multipletests
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
## FDR Calculation Function ##

def fdr_per_celltype(dge_df):
    """Add FDR-adjusted p-values and significance per cell type."""
    dge_df['p.adjusted'] = None
    dge_df['significant_fdr'] = False
    
    for celltype, group in dge_df.groupby('assay'):
        rejected, pvals_corrected, _, _ = multipletests(group['p.value'], method='fdr_bh')
        dge_df.loc[group.index, 'p.adjusted'] = pvals_corrected
        dge_df.loc[group.index, 'significant_fdr'] = rejected
    
    return dge_df

# %%
## PATHS ## 

CSV_PATH = '/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/'

# %%
## Read in DEG Lists ##

# by manuscript #
dge_fernando = pd.read_csv(Path(CSV_PATH) / 'dreamlet_fernando_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_shin = pd.read_csv(Path(CSV_PATH) / 'dreamlet_shin_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_purcell = pd.read_csv(Path(CSV_PATH) / 'dreamlet_purcell_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_sebastian = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sebastian_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_sawada = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sawada_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_notaras = pd.read_csv(Path(CSV_PATH) / 'dreamlet_notaras_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_rao = pd.read_csv(Path(CSV_PATH) / 'dreamlet_rao_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_walsh_22q11 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_22q11_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_walsh_15q13 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_15q13_dge_scz_results.csv').sort_values(by=['assay', 't'], ascending=[True, False])

# by disease #
dge_nrxn1 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_nrxn1_combined.csv').sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_22q11 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_22q11_combined.csv').sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_idiopathic = pd.read_csv(Path(CSV_PATH) / 'dreamlet_idiopathic_combined.csv').sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_15q13 = dge_walsh_15q13
dge_3q29 = dge_purcell

# %%
## Calculate FDR ##

dge_nrxn1 = fdr_per_celltype(dge_nrxn1)
dge_22q11 = fdr_per_celltype(dge_22q11)
dge_idiopathic = fdr_per_celltype(dge_idiopathic)

# %%
## Read in DEG Lists at Subtype Level ##

# by manuscript #
dge_fernando_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_fernando_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_shin_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_shin_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_purcell_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_purcell_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_sebastian_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sebastian_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_sawada_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sawada_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_notaras_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_notaras_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_rao_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_rao_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_walsh_22q11_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_22q11_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])
dge_walsh_15q13_st = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_15q13_dge_scz_results_subtype.csv').sort_values(by=['assay', 't'], ascending=[True, False])

# by disease #
dge_22q11_st = pd.read_csv(CSV_PATH + "dreamlet_22q11_combined_subtype.csv").sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_nrxn1_st = pd.read_csv(CSV_PATH + "dreamlet_nrxn1_combined_subtype.csv").sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_idiopathic_st = pd.read_csv(CSV_PATH + "dreamlet_idiopathic_combined_subtype.csv").sort_values(by=['assay', 'statistic'], ascending=[True, False])
dge_3q29_st = dge_purcell_st
dge_15q13_st = dge_walsh_15q13_st

# %%
## Calculate FDR at Subtype Level ##

dge_nrxn1_st = fdr_per_celltype(dge_nrxn1_st)
dge_22q11_st = fdr_per_celltype(dge_22q11_st)
dge_idiopathic_st = fdr_per_celltype(dge_idiopathic_st)

# %%
# Output file
OUTPUT_PATH = Path(CSV_PATH) / "Supplementary_Table_3.xlsx"

# Tables to export
tables = {
    
    # Manuscript-level DGE tables
    "Fernando": dge_fernando,
    "Sebastian": dge_sebastian,
    "Shin": dge_shin,
    "Rao": dge_rao,
    "Walsh_22q11": dge_walsh_22q11,
    "Notaras": dge_notaras,
    "Sawada": dge_sawada,
    "Purcell": dge_purcell,
    "Walsh_15q13": dge_walsh_15q13,

    # Meta-analysis DGE tables
    "NRNX1del_Meta-Analysis": dge_nrxn1,
    "22q11.2del_Meta-Analysis": dge_22q11,
    "Schizophrenia_Meta-Analysis": dge_idiopathic,
}

# Write all tables to one Excel workbook
with pd.ExcelWriter(OUTPUT_PATH, engine="xlsxwriter", engine_kwargs={"options": {"strings_to_urls": False}}) as writer:
    for sheet_name, df in tables.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)

# %%
# Output file
OUTPUT_PATH_ST = Path(CSV_PATH) / "Supplementary_Table_4.xlsx"

# Tables to export
tables = {
    
    # Manuscript-level DGE tables
    "Fernando": dge_fernando_st,
    "Sebastian": dge_sebastian_st,
    "Shin": dge_shin_st,
    "Rao": dge_rao_st,
    "Walsh_22q11": dge_walsh_22q11_st,
    "Notaras": dge_notaras_st,
    "Sawada": dge_sawada_st,
    "Purcell": dge_purcell_st,
    "Walsh_15q13": dge_walsh_15q13_st,

    # Meta-analysis DGE tables
    "NRNX1del_Meta-Analysis": dge_nrxn1_st,
    "22q11.2del_Meta-Analysis": dge_22q11_st,
    "Schizophrenia_Meta-Analysis": dge_idiopathic_st,
}

# Write all tables to one Excel workbook
with pd.ExcelWriter(OUTPUT_PATH_ST, engine="xlsxwriter", engine_kwargs={"options": {"strings_to_urls": False}}) as writer:
    for sheet_name, df in tables.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)
