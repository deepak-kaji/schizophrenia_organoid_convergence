# %%
import gc
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
## Import Crumblr Files ##

bg = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/crumblr_broad_genotype.csv')
bgm = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/crumblr_broad_genotype_matrix.csv')

x22q11 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/dream_crumblr_22q11_dge_scz_results.csv')
nrnxn1 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/dream_crumblr_NRNXN1_dge_scz_results.csv')
x3q29 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/dream_crumblr_3q29_dge_scz_results.csv')
x15q13 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/dream_crumblr_15q13_dge_scz_results.csv')
idiopathic = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/dream_crumblr_Idiopathic_dge_scz_results.csv')

# %%
bg
# Out:
#                                      Unnamed: 0  Broad_Genotype     Chemistry  \
# 0                     Astrocyte GFAP+AQP4+HOPX+    2.454587e-11  0.000000e+00
# 1   Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    0.000000e+00  0.000000e+00
# 2                    GABAergic GAD1+GAD2+CALB2+    2.631513e-11  8.133245e-09
# 3            Hindbrain Neurons NR2F2+PBX3+LHX1+    0.000000e+00  0.000000e+00
# 4                       IPC EOMES+NEUROG2+PAX6+    8.525028e-11  4.242300e-10
# 5        Mesenchymal-like cells VIM+VCAN+SPARC+    4.001748e-11  1.015643e-09
# 6            Mixed Neurons FGF12+GRIN2B+CAMK2B+    1.306338e-12  0.000000e+00
# 7                       OPC OLIG1+OLIG2+PDGFRA+    1.053576e-10  0.000000e+00
# 8              Oligodendrocyte OLIG1+OLIG2+MBP+    1.049722e-10  2.280393e-10
# 9    Proliferative Radial Glia SOX2+HES6+TOP2A+    5.151734e-11  0.000000e+00
# 10                 Radial Glia SOX2+PAX6+FABP7+    4.621888e-12  5.961849e-11
# ...

# %%
bgm
# Out:
#                                      Unnamed: 0  0307_GSM4306932  \
# 0                     Astrocyte GFAP+AQP4+HOPX+        -4.243299
# 1   Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+         3.964376
# 2                    GABAergic GAD1+GAD2+CALB2+        -0.273007
# 3            Hindbrain Neurons NR2F2+PBX3+LHX1+         2.891592
# 4                       IPC EOMES+NEUROG2+PAX6+         1.163873
# 5        Mesenchymal-like cells VIM+VCAN+SPARC+        -0.235965
# 6            Mixed Neurons FGF12+GRIN2B+CAMK2B+         0.222610
# 7                       OPC OLIG1+OLIG2+PDGFRA+        -2.633861
# 8              Oligodendrocyte OLIG1+OLIG2+MBP+        -4.243299
# 9    Proliferative Radial Glia SOX2+HES6+TOP2A+         2.450025
# 10                 Radial Glia SOX2+PAX6+FABP7+         3.362094
# 11                  Radial Glia SOX2+VIM+FABP7+         1.818158
# 12                  Stressed Glia FTL+B2M+GLUL+        -4.243299
#
# ...

# %%
x22q11
# Out:
#        logFC   AveExpr         t   P.Value  adj.P.Val         B     z.std
# 0  -1.081220 -4.321028 -1.506152  0.138005   0.953325 -4.581712 -1.483262
# 1  -0.618978  2.743449 -1.473338  0.146869   0.953325 -4.578314 -1.450680
# 2  -1.025467 -3.691510 -1.228361  0.224962   0.953325 -4.586793 -1.213440
# 3   0.617177  0.962552  0.936662  0.353589   0.953325 -4.597648  0.927650
# 4   0.611069 -4.503049  0.858762  0.394778   0.953325 -4.601398  0.850984
# 5   0.317677  1.617717  0.547324  0.586511   0.953325 -4.605135  0.543899
# 6  -0.278557  0.184297 -0.490961  0.625490   0.953325 -4.608521 -0.488084
# 7  -0.212826 -0.719167 -0.431160  0.668173   0.953325 -4.614805 -0.428657
# 8  -0.121787  2.428376 -0.350550  0.727481   0.953325 -4.610210 -0.348478
# 9  -0.158021  2.307339 -0.338185  0.736519   0.953325 -4.619497 -0.336466
# 10  0.202556 -0.760625  0.246126  0.806659   0.953325 -4.616537  0.244738
# 11 -0.075676  1.258890 -0.146217  0.884406   0.958106 -4.605591 -0.145386
# ...
