# %%
import os
import gc
from pathlib import Path
from collections import Counter

import numpy as np
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.multitest import multipletests

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn3
from matplotlib.lines import Line2D

from upsetplot import from_contents, generate_counts, UpSet, plot, from_indicators
from pycirclize import Circos

import seaborn as sns

import anndata as ad
import scanpy as sc

# %matplotlib inline

# %%
## FDR Calculation Function ##

def fdr_per_celltype(dge_df):
    """Add FDR-adjusted p-values and significance per cell type."""
    dge_df['p.adjusted'] = None
    dge_df['significant_fdr'] = False
    
    for celltype, group in dge_df.groupby('assay'):
        rejected, pvals_corrected, _, _ = multipletests(group['p.value'], method='fdr_bh')
        dge_df.loc[group.index, 'p.adjusted'] = pvals_corrected
        dge_df.loc[group.index, 'significant_fdr'] = rejected
    
    return dge_df

# %%
## Import AnnData Object ##

adata = sc.read_h5ad('/mnt/sdb/scz_meta_analysis_processed/anndata_objs/integrated_adata_annotated_w_celltypist_scanvi.h5ad')

## Toss Stressed Glia & Doublets ##

adata = adata[~(adata.obs['subclass_annotations'] == 'Stressed Glia') & ~adata.obs['pred_dbl']].copy()
gc.collect()

# Create Pseudobulk Col ##

adata.obs['Donor_Sample'] = adata.obs['Donor'].astype('str') + '_' + adata.obs['Sample Name'].astype('str')

# %%
## Known Genes In Deleted Regions ##

# https://bioinfo.uth.edu/SZGR/display/showGeneset #

CLASSIC_22q11 = ['TBX1', "COMT", "DGCR8", "TANGO2"]

ALL_22q11 = ["DERL3", "LRP5L", "SGSM1", "C22orf15", "LOC284890", "C22orf36", "PIWIL3", "GSTT2B",
                    "DDTL", "SMARCB1", "VPREB3", "SERPIND1", "MAPK1", "HIRA", "ZNF74", "CLTCL1",
                    "VPREB1", "GSTT2", "MMP11", "ZNF70", "CRYBB1", "CRKL", "BCR", "ADRBK2",
                    "MN1", "CHEK2", "APOL2", "C22orf28", "LOC652968", "FBXO7", "PVALB", "PPARA",
                    "TPST2", "PES1", "SEZ6L", "PITPNB", "TFIP11", "C22orf31", "ASPHD2", "KREMEN1",
                    "ZNRF3", "ASCC2", "HSCB", "CCDC117", "RHBDD3", "C22orf24", "TIMP3", "TBC1D10A",
                    "XBP1", "EWSR1", "LIF", "LIMK2", "DRG1", "NEFH", "NF2", "OSM",
                    "RFPL1", "SMTN", "TCN2", "NIPSNAP1", "THOC5", "MTMR3", "GAL3ST1", "SFI1",
                    "SF3A1", "RASL10A", "GAS2L1", "MORC2", "SEC14L2", "PATZ1", "PISD", "OSBP2",
                    "RNF185", "PIK3IP1", "EMID1", "SELM", "HORMAD2", "DUSP18", "CABP7", "RNF215",
                    "SEC14L3", "SEC14L4", "SLC35E4", "LOC550631", "SLC5A4", "C22orf30", "DGCR5",
                    "DGCR6L", "SUSD2", "SCZD4", "BID", "IL17RA", "BCL2L13", "TUBA8", "GAB4",
                    "CCT8L2", "XKR3", "TRMT2A", "RTDR1", "CECR2", "YPEL1", "LOC51233", "MED15",
                    "UPB1", "CECR1", "DGCR8", "GNB1L", "EIF4ENIF1", "SLC2A11", "THAP7", "OR11H1",
                    "C22orf13", "SLC25A18", "MYO18B", "CRYBB2", "CRYBB3", "CRYBA4", "PLA2G3",
                    "APOL4", "ACO2", "ARVCF", "GSC2", "PI4KA", "SEPT5", "PRODH", "RANBP1",
                    "SLC7A4", "SLC25A1", "TBX1", "CLDN5", "UBE2L3", "UFD1L", "CDC45L", "SNAP29",
                    "DGCR2", "TXNRD2", "USP18", "HIC2", "TSSK2", "SDF2L1", "PPIL2", "ZDHHC8",
                    "PEX26", "MICAL3", "MRPL40", "RTN4R", "C22orf29", "KLHL22", "SCARF2",
                    "C22orf25", "AIFM3", "CCDC116", "FLJ42953", "LOC440792", "COMT", "GP1BB",
                    "DGCR6", "LZTR1", "DGCR14", "GNAZ", "TOP3B", "RAB36", "PPM1F", "PRAME",
                    "DKFZP434P211", "LOC96610", "ZNF280A", "ZNF280B", "ADORA2A", "DDT",
                    "GGT1", "GSTT1", "IGLL1", "MIF", "SNRPD3", "SPECC1L", "CABIN1"]

CLASSIC_3q29 = ['DLG1', "PAK2", "TFRC", "C3orf34"]
BORDERLINE_3q29 = ['HES1', "CLDN1", "OPA1"]
ALL_3q29 = adata.var_names[adata.var_names.isin(CLASSIC_3q29 + BORDERLINE_3q29)].tolist()

CLASSIC_15q13 = ['HERC2', 'CHRFAM7A', 'CHP', 'FMN1']
BORDERLINE_15q13 = ['SCG5', 'SLC12A6', 'GREM1', 'MAP1A']
ALL_15q13 = adata.var_names[adata.var_names.isin(CLASSIC_15q13 + BORDERLINE_15q13)].tolist()

# %%
## Read in DEG Lists ##

CSV_PATH = '/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/'

# by manuscript #
dge_fernando = pd.read_csv(Path(CSV_PATH) / 'dreamlet_fernando_dge_scz_results.csv')
dge_shin = pd.read_csv(Path(CSV_PATH) / 'dreamlet_shin_dge_scz_results.csv')
dge_purcell = pd.read_csv(Path(CSV_PATH) / 'dreamlet_purcell_dge_scz_results.csv')
dge_sebastian = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sebastian_dge_scz_results.csv')
dge_sawada = pd.read_csv(Path(CSV_PATH) / 'dreamlet_sawada_dge_scz_results.csv')
dge_notaras = pd.read_csv(Path(CSV_PATH) / 'dreamlet_notaras_dge_scz_results.csv')
dge_rao = pd.read_csv(Path(CSV_PATH) / 'dreamlet_rao_dge_scz_results.csv')
dge_walsh_22q11 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_22q11_dge_scz_results.csv')
dge_walsh_15q13 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_walsh_15q13_dge_scz_results.csv')

# by disease #
dge_nrxn1 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_nrxn1_combined.csv')
dge_22q11 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_22q11_combined.csv')
dge_idiopathic = pd.read_csv(Path(CSV_PATH) / 'dreamlet_idiopathic_combined.csv')
dge_15q13 = dge_walsh_15q13
dge_3q29 = dge_purcell

# %%
# Make Assay ID #

# Put all dataframes in a dictionary
dge_dfs = {
    'dge_fernando': dge_fernando,
    'dge_shin': dge_shin,
    'dge_purcell': dge_purcell,
    'dge_sebastian': dge_sebastian,
    'dge_sawada': dge_sawada,
    'dge_notaras': dge_notaras,
    'dge_rao': dge_rao,
    'dge_walsh_22q11': dge_walsh_22q11,
    'dge_walsh_15q13': dge_walsh_15q13,
    'dge_nrxn1': dge_nrxn1,
    'dge_22q11': dge_22q11,
    'dge_idiopathic': dge_idiopathic,
    'dge_15q13': dge_15q13,
    'dge_3q29': dge_3q29
}

# Add assay_ID column to each
for name, df in dge_dfs.items():
    df['assay_ID'] = df['assay'].astype(str) + ' | ' + df['ID'].astype(str)

# %%
## Calculate FDR ##

dge_nrxn1 = fdr_per_celltype(dge_nrxn1)
dge_22q11 = fdr_per_celltype(dge_22q11)
dge_idiopathic = fdr_per_celltype(dge_idiopathic)

# %%
## Calculate Significant Gene Lists ##

# refine metaanalysis dataframes to significant hits across all studies 
significant_nrxn1_df = dge_nrxn1[(dge_nrxn1['p.adjusted'] < 0.05) & (dge_nrxn1['n.studies'] == 2)]
significant_22q11_df = dge_22q11[(dge_22q11['p.adjusted'] < 0.05) & (dge_22q11['n.studies'] == 3)]
significant_idiopathic_df = dge_idiopathic[(dge_idiopathic['p.adjusted'] < 0.05) & (dge_idiopathic['n.studies'] == 2)]

# make significnat gene lists
significant_nrxn1 = significant_nrxn1_df['ID'].tolist()
significant_22q11 = significant_22q11_df['ID'].tolist()
significant_idiopathic = significant_idiopathic_df['ID'].tolist()

# make sets from lists #
set_nrxn1 = set(significant_nrxn1)
set_22q11 = set(significant_22q11)
set_idiopathic = set(significant_idiopathic)

# make overlap lists ##
set_22q11_nrxn1 = set_22q11.intersection(set_nrxn1) 
set_22q11_idiopathic = set_22q11.intersection(set_idiopathic) 
set_nrnxn1_idiopathic = set_nrxn1.intersection(set_idiopathic)

# %%
dge_15q13[(dge_15q13['adj.P.Val'] < 0.05)]
# Out:
# Empty DataFrame
# Columns: [assay, ID, logFC, AveExpr, t, P.Value, adj.P.Val, B, z.std, dataset, assay_ID]
# Index: []

# %%
dge_3q29[(dge_3q29['adj.P.Val'] < 0.05)]
# Out:
#                                          assay        ID      logFC   AveExpr  \
# 0                  Radial Glia SOX2+VIM+FABP7+     UBXN7  -1.410543  5.178853
# 1                  Radial Glia SOX2+VIM+FABP7+      PAK2  -1.201422  6.834729
# 2                  Radial Glia SOX2+VIM+FABP7+     NEAT1  -1.604934  8.615706
# 3                      IPC EOMES+NEUROG2+PAX6+     CADM1   2.920552  5.867342
# 4                  Radial Glia SOX2+VIM+FABP7+      SAT1  -1.201880  7.602492
# 5                  Radial Glia SOX2+VIM+FABP7+   TMEM159  -1.539923  3.495084
# 6                  Radial Glia SOX2+VIM+FABP7+   BLOC1S6  -1.103334  6.054103
# 7                  Radial Glia SOX2+VIM+FABP7+    RNF168  -1.560908  4.710141
# 8                  Radial Glia SOX2+VIM+FABP7+      BTG3  -0.975040  7.187944
# 9                  Radial Glia SOX2+VIM+FABP7+      LIPG  -1.263478  3.902009
# 10                 Radial Glia SOX2+VIM+FABP7+      CCN1  -1.254546  5.501446
# 11  Proliferative Radial Glia SOX2+HES6+TOP2A+      PAK2  -1.065260  7.011031
# 12      Mesenchymal-like cells VIM+VCAN+SPARC+    ZNF711  12.771982  3.611446
# 13                 Radial Glia SOX2+VIM+FABP7+    FBXO45  -1.424769  3.846716
# 14                 Radial Glia SOX2+VIM+FABP7+      GAS6  -1.229776  5.169653
# 15                 Radial Glia SOX2+VIM+FABP7+     SCML1  -1.130337  4.285366
# 16                 Radial Glia SOX2+VIM+FABP7+     RSPO2   1.980821  4.424475
# 17                 Radial Glia SOX2+VIM+FABP7+  NCBP2AS2  -0.941412  5.968915
# 18                 Radial Glia SOX2+VIM+FABP7+     NCBP2  -0.922631  6.779685
# 19          Mixed Neurons FGF12+GRIN2B+CAMK2B+   KHDRBS3  -1.423032  6.564618
# 20                 Radial Glia SOX2+VIM+FABP7+      PER1  -1.588656  3.909345
# 21                 Radial Glia SOX2+VIM+FABP7+    TNFSF9  -2.156546  2.279541
# 22  Proliferative Radial Glia SOX2+HES6+TOP2A+      DLG1  -0.999250  4.814198
# 23                 Radial Glia SOX2+VIM+FABP7+      DLG1  -1.074938  4.698816
# 24                 Radial Glia SOX2+VIM+FABP7+     RBBP7  -0.848443  6.878479
# 25  Proliferative Radial Glia SOX2+HES6+TOP2A+   BLOC1S6  -1.040125  5.865128
# 26                 Radial Glia SOX2+VIM+FABP7+      TFRC  -1.400550  5.526094
# 27                 Radial Glia SOX2+VIM+FABP7+      FIBP   0.831452  6.894021
# 28                 Radial Glia SOX2+VIM+FABP7+     RRM2B  -1.113386  5.989374
# 29                 Radial Glia SOX2+VIM+FABP7+     LITAF  -0.983945  5.336237
#
#             t       P.Value  adj.P.Val         B      z.std  dataset  \
# 0  -13.097255  7.995727e-07   0.018796  6.357204 -13.097255  purcell
# 1  -12.554585  1.118057e-06   0.018796  6.147169 -12.554585  purcell
# 2  -12.475494  1.175337e-06   0.018796  6.154063 -12.475494  purcell
# 3    8.295579  1.482729e-06   0.018796 -2.307061   8.295579  purcell
# 4  -12.103017  1.493006e-06   0.018796  5.912923 -12.103017  purcell
# 5  -11.795281  1.828545e-06   0.018796  5.401540 -11.795281  purcell
# 6  -11.776155  1.852020e-06   0.018796  5.664562 -11.776155  purcell
# 7  -11.635163  2.035807e-06   0.018796  5.498788 -11.635163  purcell
# 8  -11.524175  2.194816e-06   0.018796  5.552051 -11.524175  purcell
# 9  -10.940261  3.296072e-06   0.025076  4.967994 -10.940261  purcell
# 10 -10.825305  3.578864e-06   0.025076  5.056668 -10.825305  purcell
# 11 -12.358477  4.406374e-06   0.028302  4.687173 -12.358477  purcell
# 12   4.516390  6.402087e-06   0.035246 -3.417257   4.516390  purcell
# 13 -10.042814  6.402150e-06   0.035246  4.347587 -10.042814  purcell
# 14  -9.919712  7.040577e-06   0.036177  4.402496  -9.919712  purcell
# 15  -9.693347  8.407812e-06   0.040502  4.250016  -9.693347  purcell
# 16   9.601661  9.043570e-06   0.041002  3.965772   9.601661  purcell
# 17  -9.357496  1.101327e-05   0.044921  4.000538  -9.357496  purcell
# 18  -9.311010  1.143992e-05   0.044921  3.965881  -9.311010  purcell
# 19  -6.641457  1.165649e-05   0.044921  0.387412  -6.641457  purcell
# 20  -9.225329  1.227524e-05   0.044944  3.801830  -9.225329  purcell
# 21  -9.148102  1.308648e-05   0.044944  3.722181  -9.148102  purcell
# 22 -10.415621  1.412550e-05   0.044944  3.424753 -10.415621  purcell
# 23  -9.036913  1.436101e-05   0.044944  3.725293  -9.036913  purcell
# 24  -9.019075  1.457803e-05   0.044944  3.729033  -9.019075  purcell
# 25 -10.286099  1.537025e-05   0.045548  3.543398 -10.286099  purcell
# 26  -8.875951  1.645718e-05   0.045548  3.605112  -8.875951  purcell
# 27   8.851467  1.680483e-05   0.045548  3.589789   8.851467  purcell
# 28  -8.828540  1.713777e-05   0.045548  3.570592  -8.828540  purcell
# 29  -8.728874  1.867262e-05   0.047973  3.482508  -8.728874  purcell
#
#                                              assay_ID
# 0                 Radial Glia SOX2+VIM+FABP7+ | UBXN7
# 1                  Radial Glia SOX2+VIM+FABP7+ | PAK2
# 2                 Radial Glia SOX2+VIM+FABP7+ | NEAT1
# 3                     IPC EOMES+NEUROG2+PAX6+ | CADM1
# 4                  Radial Glia SOX2+VIM+FABP7+ | SAT1
# 5               Radial Glia SOX2+VIM+FABP7+ | TMEM159
# 6               Radial Glia SOX2+VIM+FABP7+ | BLOC1S6
# 7                Radial Glia SOX2+VIM+FABP7+ | RNF168
# 8                  Radial Glia SOX2+VIM+FABP7+ | BTG3
# 9                  Radial Glia SOX2+VIM+FABP7+ | LIPG
# 10                 Radial Glia SOX2+VIM+FABP7+ | CCN1
# 11  Proliferative Radial Glia SOX2+HES6+TOP2A+ | PAK2
# 12    Mesenchymal-like cells VIM+VCAN+SPARC+ | ZNF711
# 13               Radial Glia SOX2+VIM+FABP7+ | FBXO45
# 14                 Radial Glia SOX2+VIM+FABP7+ | GAS6
# 15                Radial Glia SOX2+VIM+FABP7+ | SCML1
# 16                Radial Glia SOX2+VIM+FABP7+ | RSPO2
# 17             Radial Glia SOX2+VIM+FABP7+ | NCBP2AS2
# 18                Radial Glia SOX2+VIM+FABP7+ | NCBP2
# 19       Mixed Neurons FGF12+GRIN2B+CAMK2B+ | KHDRBS3
# 20                 Radial Glia SOX2+VIM+FABP7+ | PER1
# 21               Radial Glia SOX2+VIM+FABP7+ | TNFSF9
# 22  Proliferative Radial Glia SOX2+HES6+TOP2A+ | DLG1
# 23                 Radial Glia SOX2+VIM+FABP7+ | DLG1
# 24                Radial Glia SOX2+VIM+FABP7+ | RBBP7
# 25  Proliferative Radial Glia SOX2+HES6+TOP2A+ | B...
# 26                 Radial Glia SOX2+VIM+FABP7+ | TFRC
# 27                 Radial Glia SOX2+VIM+FABP7+ | FIBP
# 28                Radial Glia SOX2+VIM+FABP7+ | RRM2B
# 29                Radial Glia SOX2+VIM+FABP7+ | LITAF

# %%
def add_directional_consistency(df):
    # Remove duplicate columns
    df = df.loc[:, ~df.columns.duplicated()].copy()
    
    # Identify logFC columns
    logfc_cols = [col for col in df.columns if col.startswith('logFC')]
    
    def check_direction(row):
        vals = row[logfc_cols].dropna()
        
        if len(vals) <= 1:
            return np.nan  # not enough data
        
        signs = np.sign(vals)
        signs = signs[signs != 0]  # optionally ignore zeros
        
        if len(signs) == 0:
            return np.nan
        
        return len(set(signs)) == 1  # True if all same sign
    
    # Add new column
    df['directionally_consistent'] = df.apply(check_direction, axis=1)
    
    return df

# %%
## Examining 22q11 Meta-Analysis ##

dge_shin_rao = dge_shin.merge(dge_rao, left_on=['assay', 'ID', 'assay_ID'],
                              right_on=['assay', 'ID', 'assay_ID'], how='inner', suffixes=['_shin', '_rao'])

dge_walsh_22q11_renamed = dge_walsh_22q11.add_suffix('_walsh')
dge_walsh_22q11_renamed = dge_walsh_22q11_renamed.rename(columns={'assay_walsh': 'assay', 'ID_walsh': 'ID', 'assay_ID_walsh':'assay_ID'})

dge_shin_rao_walsh_22q11 = dge_shin_rao.merge(dge_walsh_22q11_renamed,
                                              left_on=['assay', 'ID', 'assay_ID'],
                                              right_on=['assay', 'ID', 'assay_ID'], how='inner')

significant_22q11_df_logfc = significant_22q11_df.merge(dge_shin_rao_walsh_22q11[['assay', 'ID', 'assay_ID', 
                                                                            'logFC_rao','logFC_shin', 'logFC_walsh']],
                                                  left_on=['assay', 'ID', 'assay_ID'], 
                                                  right_on=['assay', 'ID', 'assay_ID'], how='left') 

significant_22q11_df_logfc = add_directional_consistency(significant_22q11_df_logfc)

logfc_cols_22q11 = [i for i in significant_22q11_df_logfc.columns if 'logFC' in i]
significant_22q11_df_logfc['mean_logFC'] = significant_22q11_df_logfc[logfc_cols_22q11].mean(axis=1)

dc_significant_22q11_df_logfc = significant_22q11_df_logfc[significant_22q11_df_logfc['directionally_consistent'] == True]

significant_22q11_df_logfc['directionally_consistent'].mean()
# Out:
# 0.5676126878130217

# %%
## Examining NRXN1 Meta-Analysis ##

dge_sebastian_fernando = dge_sebastian.merge(dge_fernando, left_on=['assay', 'ID', 'assay_ID'],
                              right_on=['assay', 'ID', 'assay_ID'], how='inner', suffixes=['_sebastian', '_fernando'])

significant_nrxn1_df_logfc = significant_nrxn1_df.merge(dge_sebastian_fernando[['assay', 'ID', 'assay_ID', 
                                                                            'logFC_sebastian', 'logFC_fernando']],
                                                                            left_on=['assay', 'ID', 'assay_ID'], 
                                                                            right_on=['assay', 'ID', 'assay_ID'], how='left') 

significant_nrnx1_df_logfc = add_directional_consistency(significant_nrxn1_df_logfc)

logfc_cols_nrxn1 = [i for i in significant_nrnx1_df_logfc.columns if 'logFC' in i]
significant_nrnx1_df_logfc['mean_logFC'] = significant_nrnx1_df_logfc[logfc_cols_nrxn1].mean(axis=1)

dc_significant_nrxn1_df_logfc = significant_nrnx1_df_logfc[significant_nrnx1_df_logfc['directionally_consistent'] == True]

significant_nrnx1_df_logfc['directionally_consistent'].mean()
# Out:
# 0.7546972860125261

# %%
## Examining Idiopathic Meta-Analysis ##

dge_sawada_notaras = dge_sawada.merge(dge_notaras, left_on=['assay', 'ID', 'assay_ID'],
                              right_on=['assay', 'ID', 'assay_ID'], how='inner', suffixes=['_sawada', '_notaras'])

significant_idiopathic_df_logfc = significant_idiopathic_df.merge(dge_sawada_notaras[['assay', 'ID', 'assay_ID', 
                                                                                'logFC_sawada', 'logFC_notaras']],
                                                                                left_on=['assay', 'ID', 'assay_ID'], 
                                                                                right_on=['assay', 'ID', 'assay_ID'], how='left') 

significant_idiopathic_df_logfc = add_directional_consistency(significant_idiopathic_df_logfc)

logfc_cols_idiopathic = [i for i in significant_idiopathic_df_logfc.columns if 'logFC' in i]
significant_idiopathic_df_logfc['mean_logFC'] = significant_idiopathic_df_logfc[logfc_cols_idiopathic].mean(axis=1)

dc_significant_idiopathic_df_logfc = significant_idiopathic_df_logfc[significant_idiopathic_df_logfc['directionally_consistent'] == True]

significant_idiopathic_df_logfc['directionally_consistent'].mean()
# Out:
# 0.744927536231884

# %%
dc_significant_22q11_df_logfc['assay'].value_counts()
# Out:
# assay
# Radial Glia SOX2+VIM+FABP7+                    194
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     50
# Hindbrain Neurons NR2F2+PBX3+LHX1+              45
# Proliferative Radial Glia SOX2+HES6+TOP2A+      39
# Radial Glia SOX2+PAX6+FABP7+                     7
# Mixed Neurons FGF12+GRIN2B+CAMK2B+               5
# Name: count, dtype: int64

# %%
dc_significant_idiopathic_df_logfc['assay'].value_counts()
# Out:
# assay
# Radial Glia SOX2+PAX6+FABP7+                  166
# Proliferative Radial Glia SOX2+HES6+TOP2A+     83
# Hindbrain Neurons NR2F2+PBX3+LHX1+              5
# Radial Glia SOX2+VIM+FABP7+                     3
# Name: count, dtype: int64

# %%
dc_significant_nrxn1_df_logfc['assay'].value_counts()
# Out:
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    300
# Astrocyte GFAP+AQP4+HOPX+                      134
# IPC EOMES+NEUROG2+PAX6+                         88
# Proliferative Radial Glia SOX2+HES6+TOP2A+      85
# Mixed Neurons FGF12+GRIN2B+CAMK2B+              64
# Radial Glia SOX2+PAX6+FABP7+                    31
# Radial Glia SOX2+VIM+FABP7+                     18
# Hindbrain Neurons NR2F2+PBX3+LHX1+               2
# Mesenchymal-like cells VIM+VCAN+SPARC+           1
# Name: count, dtype: int64

# %%
## Check Overlap Between Directionally Consistent MetaAnalyzed DataFrames ##

df_22q11_to_merge = dc_significant_22q11_df_logfc.copy()
df_22q11_to_merge.columns = [i+'_22q11' for i in df_22q11_to_merge.columns]

df_nrxn1_to_merge = dc_significant_nrxn1_df_logfc.copy()
df_nrxn1_to_merge.columns = [i+'_nrxn1' for i in df_nrxn1_to_merge.columns]

df_idiopathic_to_merge = dc_significant_idiopathic_df_logfc.copy()
df_idiopathic_to_merge.columns = [i+'_idiopathic' for i in dc_significant_idiopathic_df_logfc.columns]

df_22q11_nrxn1 = df_22q11_to_merge.merge(df_nrxn1_to_merge, 
                                         right_on=['ID_nrxn1', 'assay_nrxn1'], 
                                         left_on=['ID_22q11', 'assay_22q11'])

df_22q11_idiopathic = df_22q11_to_merge.merge(df_idiopathic_to_merge, 
                                              right_on=['ID_idiopathic', 'assay_idiopathic'], 
                                              left_on=['ID_22q11', 'assay_22q11'])

df_nrxn1_idiopathic = df_nrxn1_to_merge.merge(df_idiopathic_to_merge, 
                                              right_on=['ID_idiopathic', 'assay_idiopathic'], 
                                              left_on=['ID_nrxn1', 'assay_nrxn1'])

# %%
## Venn Diagram Of Overlap CellType Agonstic ##

# Convert your lists to sets
dge_nrxn1_set = set(dc_significant_nrxn1_df_logfc['ID'])
dge_22q11_set = set(dc_significant_22q11_df_logfc['ID'])
dge_idiopathic_set = set(dc_significant_idiopathic_df_logfc['ID'])

# --- Venn diagram for all three lists ---
plt.figure(figsize=(8, 6))
venn3([dge_nrxn1_set, dge_22q11_set, dge_idiopathic_set],
      set_labels=('NRXN1', '22q11', 'Idiopathic'))
plt.title("Overlap of Significant Genes")
plt.show()

# %%
dge_22q11_set.intersection(dge_idiopathic_set).intersection(dge_nrxn1_set)
# Out:
# {'WWC2'}

# %%
# Convert to sets
dge_nrxn1_set = set(dc_significant_nrxn1_df_logfc['ID'])
dge_22q11_set = set(dc_significant_22q11_df_logfc['ID'])
dge_idiopathic_set = set(dc_significant_idiopathic_df_logfc['ID'])

# Custom colors
COLORS = {
    "NRXN1": "#fc8d62ff",
    "22q11": "#8da0cbff",
    "Idiopathic": "#66c2a5ff"
}

plt.figure(figsize=(8, 6))

v = venn3(
    [dge_nrxn1_set, dge_22q11_set, dge_idiopathic_set],
    set_labels=('NRXN1', '22q11', 'Idiopathic')
)

# =====================================================
# MAIN SET COLORS + EDGES
# =====================================================

v.get_patch_by_id('100').set_color(COLORS["NRXN1"])
v.get_patch_by_id('100').set_alpha(0.6)
v.get_patch_by_id('100').set_edgecolor('black')
v.get_patch_by_id('100').set_linewidth(1.5)

v.get_patch_by_id('010').set_color(COLORS["22q11"])
v.get_patch_by_id('010').set_alpha(0.6)
v.get_patch_by_id('010').set_edgecolor('black')
v.get_patch_by_id('010').set_linewidth(1.5)

v.get_patch_by_id('001').set_color(COLORS["Idiopathic"])
v.get_patch_by_id('001').set_alpha(0.6)
v.get_patch_by_id('001').set_edgecolor('black')
v.get_patch_by_id('001').set_linewidth(1.5)

# =====================================================
# LABEL STYLING (optional polish)
# =====================================================

for text in v.set_labels:
    if text:
        text.set_fontsize(15)

for text in v.subset_labels:
    if text:
        text.set_fontsize(15)

plt.title("Overlap of Significant Genes")
plt.tight_layout()
plt.savefig(f"/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_all_celltypes_venn.svg", bbox_inches='tight')
plt.show()

# %%
## Venn Diagram Of Overlap CellType Specific ##

# get all unique assays
assays = set(dc_significant_nrxn1_df_logfc['assay']) \
    | set(dc_significant_22q11_df_logfc['assay']) \
    | set(dc_significant_idiopathic_df_logfc['assay'])

for assay in assays:

    nrxn1_genes = set(dc_significant_nrxn1_df_logfc.loc[dc_significant_nrxn1_df_logfc['assay'] == assay, 'ID'])

    q22_genes = set(dc_significant_22q11_df_logfc.loc[dc_significant_22q11_df_logfc['assay'] == assay, 'ID'])

    idiopathic_genes = set(dc_significant_idiopathic_df_logfc.loc[dc_significant_idiopathic_df_logfc['assay'] == assay, 'ID'])

    sets = [('NRXN1', nrxn1_genes), ('22q11', q22_genes), ('Idiopathic', idiopathic_genes)]

    # keep only non-empty sets
    non_empty = [(name, s) for name, s in sets if len(s) > 0]

    # skip if fewer than 2 sets
    if len(non_empty) < 2:
        continue

    plt.figure(figsize=(6, 5))

    if len(non_empty) == 3:
        venn3([s for _, s in non_empty],
              set_labels=[n for n, _ in non_empty])

    elif len(non_empty) == 2:
        venn2([s for _, s in non_empty],
              set_labels=[n for n, _ in non_empty])

    plt.title(f"Overlap of Significant Genes\n{assay}")
    safe_assay = assay.replace(" ", "_").replace("+", "").replace("/", "_")
    
    plt.savefig(
        f"/home/deepak/datasets/scz_meta_analysis/panels/Figure_4_{safe_assay}_venn.svg", bbox_inches='tight')
    
    plt.show()

# %%
df_22q11_nrxn1[[i for i in df_22q11_nrxn1.columns if ('logFC' in i) or ('assay' in i)]]

## Theres only 4 instances across 2 celltypes when a gene is directionally shared across all manuscripts and significant ##
## In all of those intsances the signs are changed ##
# Out:
#                                    assay_22q11  \
# 0  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+
# 1                  Radial Glia SOX2+VIM+FABP7+
#
#                                       assay_ID_22q11  logFC_rao_22q11  \
# 0  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        -0.931210
# 1                 Radial Glia SOX2+VIM+FABP7+ | PIM1        -0.573554
#
#    logFC_shin_22q11  logFC_walsh_22q11  mean_logFC_22q11  \
# 0         -0.482282          -0.962693         -0.792062
# 1         -1.385680          -0.540774         -0.833336
#
#                                    assay_nrxn1  \
# 0  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+
# 1                  Radial Glia SOX2+VIM+FABP7+
#
#                                       assay_ID_nrxn1  logFC_sebastian_nrxn1  \
# 0  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...               0.117488
# 1                 Radial Glia SOX2+VIM+FABP7+ | PIM1               0.214780
#
#    logFC_fernando_nrxn1  mean_logFC_nrxn1
# 0              0.517913          0.317700
# 1              1.481326          0.848053

# %%
df_22q11_nrxn1[[i for i in df_22q11_nrxn1.columns if ('logFC' in i) or ('ID' in i)]]
# Out:
#   ID_22q11                                     assay_ID_22q11  \
# 0     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 1     PIM1                 Radial Glia SOX2+VIM+FABP7+ | PIM1
#
#    logFC_rao_22q11  logFC_shin_22q11  logFC_walsh_22q11  mean_logFC_22q11  \
# 0        -0.931210         -0.482282          -0.962693         -0.792062
# 1        -0.573554         -1.385680          -0.540774         -0.833336
#
#   ID_nrxn1                                     assay_ID_nrxn1  \
# 0     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 1     PIM1                 Radial Glia SOX2+VIM+FABP7+ | PIM1
#
#    logFC_sebastian_nrxn1  logFC_fernando_nrxn1  mean_logFC_nrxn1
# 0               0.117488              0.517913          0.317700
# 1               0.214780              1.481326          0.848053

# %%
df_22q11_idiopathic
# Out:
#   ID_22q11                                 assay_22q11  estimate_22q11  \
# 0   PTPN13  Proliferative Radial Glia SOX2+HES6+TOP2A+       -0.322741
#
#    std.error_22q11  statistic_22q11  p.value_22q11  n.studies_22q11  \
# 0         0.082883        -3.893935       0.000099                3
#
#   method_22q11                                     assay_ID_22q11  \
# 0           FE  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...
#
#   p.adjusted_22q11  ...  p.value_idiopathic  n.studies_idiopathic  \
# 0         0.015274  ...            0.000514                     2
#
#    method_idiopathic                                assay_ID_idiopathic  \
# 0                 FE  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...
#
#    p.adjusted_idiopathic  significant_fdr_idiopathic logFC_sawada_idiopathic  \
# 0               0.006092                        True               -0.104303
#
#   logFC_notaras_idiopathic  directionally_consistent_idiopathic  \
# 0                 -1.94918                                 True
#
#    mean_logFC_idiopathic
# 0              -1.026742
#
# [1 rows x 31 columns]

# %%
df_nrxn1_idiopathic
# Out:
# Empty DataFrame
# Columns: [ID_nrxn1, assay_nrxn1, estimate_nrxn1, std.error_nrxn1, statistic_nrxn1, p.value_nrxn1, n.studies_nrxn1, method_nrxn1, assay_ID_nrxn1, p.adjusted_nrxn1, significant_fdr_nrxn1, logFC_sebastian_nrxn1, logFC_fernando_nrxn1, directionally_consistent_nrxn1, mean_logFC_nrxn1, ID_idiopathic, assay_idiopathic, estimate_idiopathic, std.error_idiopathic, statistic_idiopathic, p.value_idiopathic, n.studies_idiopathic, method_idiopathic, assay_ID_idiopathic, p.adjusted_idiopathic, significant_fdr_idiopathic, logFC_sawada_idiopathic, logFC_notaras_idiopathic, directionally_consistent_idiopathic, mean_logFC_idiopathic]
# Index: []
#
# [0 rows x 30 columns]

# %%
## Identify Genes Across Disease That May Not be Directionally Consistent Within a Disease, but Significant Within and Across Dx ##

df_22q11_non_dc_to_merge = significant_22q11_df_logfc.copy()
df_22q11_non_dc_to_merge.columns = [i+'_22q11' for i in df_22q11_non_dc_to_merge.columns]

df_nrxn1_non_dc_to_merge = significant_nrnx1_df_logfc.copy()
df_nrxn1_non_dc_to_merge.columns = [i+'_nrxn1' for i in df_nrxn1_non_dc_to_merge.columns]

df_idiopathic_non_dc_to_merge = significant_idiopathic_df_logfc.copy()
df_idiopathic_non_dc_to_merge.columns = [i+'_idiopathic' for i in df_idiopathic_non_dc_to_merge.columns]

df_22q11_nrxn1_non_dc = df_22q11_non_dc_to_merge.merge(df_nrxn1_non_dc_to_merge, 
                                         right_on=['ID_nrxn1', 'assay_nrxn1'], 
                                         left_on=['ID_22q11', 'assay_22q11'])

df_22q11_idiopathic_non_dc = df_22q11_non_dc_to_merge.merge(df_idiopathic_non_dc_to_merge, 
                                              right_on=['ID_idiopathic', 'assay_idiopathic'], 
                                              left_on=['ID_22q11', 'assay_22q11'])

df_nrxn1_idiopathic_non_dc = df_nrxn1_non_dc_to_merge.merge(df_idiopathic_non_dc_to_merge, 
                                              right_on=['ID_idiopathic', 'assay_idiopathic'], 
                                              left_on=['ID_nrxn1', 'assay_nrxn1'])

# %%
df_22q11_nrxn1_non_dc[[i for i in df_22q11_nrxn1_non_dc.columns if ('logFC' in i) or ('ID' in i)]]

## if you lax the constraints to take things thta dont have full directional consistency, you can get a few extra hits ##
## one of which has NRXN1 22q11.2 deletion mixup ## Nothing Shared with Idiopathic ##
# Out:
#   ID_22q11                                     assay_ID_22q11  \
# 0     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 1  GOLGA8B  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 2    PDGFD                Radial Glia SOX2+VIM+FABP7+ | PDGFD
# 3     PIM1                 Radial Glia SOX2+VIM+FABP7+ | PIM1
#
#    logFC_rao_22q11  logFC_shin_22q11  logFC_walsh_22q11  mean_logFC_22q11  \
# 0        -0.931210         -0.482282          -0.962693         -0.792062
# 1         0.771310         -0.019227           1.023847          0.591977
# 2         0.810287          0.751816           0.082459          0.548187
# 3        -0.573554         -1.385680          -0.540774         -0.833336
#
#   ID_nrxn1                                     assay_ID_nrxn1  \
# 0     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 1  GOLGA8B  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...
# 2    PDGFD                Radial Glia SOX2+VIM+FABP7+ | PDGFD
# 3     PIM1                 Radial Glia SOX2+VIM+FABP7+ | PIM1
#
#    logFC_sebastian_nrxn1  logFC_fernando_nrxn1  mean_logFC_nrxn1
# 0               0.117488              0.517913          0.317700
# 1               0.251183             -1.051003         -0.399910
# 2               0.163255             -1.800072         -0.818409
# 3               0.214780              1.481326          0.848053

# %%
df_22q11_idiopathic_non_dc
# Out:
#   ID_22q11                                 assay_22q11  estimate_22q11  \
# 0   PTPN13  Proliferative Radial Glia SOX2+HES6+TOP2A+       -0.322741
#
#    std.error_22q11  statistic_22q11  p.value_22q11  n.studies_22q11  \
# 0         0.082883        -3.893935       0.000099                3
#
#   method_22q11                                     assay_ID_22q11  \
# 0           FE  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...
#
#   p.adjusted_22q11  ...  p.value_idiopathic  n.studies_idiopathic  \
# 0         0.015274  ...            0.000514                     2
#
#    method_idiopathic                                assay_ID_idiopathic  \
# 0                 FE  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...
#
#    p.adjusted_idiopathic  significant_fdr_idiopathic logFC_sawada_idiopathic  \
# 0               0.006092                        True               -0.104303
#
#   logFC_notaras_idiopathic  directionally_consistent_idiopathic  \
# 0                 -1.94918                                 True
#
#    mean_logFC_idiopathic
# 0              -1.026742
#
# [1 rows x 31 columns]

# %%
df_nrxn1_idiopathic_non_dc
# Out:
# Empty DataFrame
# Columns: [ID_nrxn1, assay_nrxn1, estimate_nrxn1, std.error_nrxn1, statistic_nrxn1, p.value_nrxn1, n.studies_nrxn1, method_nrxn1, assay_ID_nrxn1, p.adjusted_nrxn1, significant_fdr_nrxn1, logFC_sebastian_nrxn1, logFC_fernando_nrxn1, directionally_consistent_nrxn1, mean_logFC_nrxn1, ID_idiopathic, assay_idiopathic, estimate_idiopathic, std.error_idiopathic, statistic_idiopathic, p.value_idiopathic, n.studies_idiopathic, method_idiopathic, assay_ID_idiopathic, p.adjusted_idiopathic, significant_fdr_idiopathic, logFC_sawada_idiopathic, logFC_notaras_idiopathic, directionally_consistent_idiopathic, mean_logFC_idiopathic]
# Index: []
#
# [0 rows x 30 columns]

# %%
## What if it was enough that a single gene was showing up in multiple different disease in the same direction ideally ##

sig_22q11_idiopathic_set = set(dc_significant_22q11_df_logfc['ID']).intersection(dc_significant_idiopathic_df_logfc['ID'])

sig_22q11_nrxn1_set = set(dc_significant_22q11_df_logfc['ID']).intersection(dc_significant_nrxn1_df_logfc['ID'])

sig_idiopathic_nrxn1_set = set(dc_significant_idiopathic_df_logfc['ID']).intersection(dc_significant_nrxn1_df_logfc['ID'])

# %%
dc_significant_all = pd.concat([dc_significant_idiopathic_df_logfc.assign(group='Idiopathic Schizophrenia'),
                                dc_significant_nrxn1_df_logfc.assign(group='NRXN1del'), 
                                dc_significant_22q11_df_logfc.assign(group='22q11.2del')], axis=0)

# %%
dc_significant_all[dc_significant_all['ID'].isin(sig_22q11_idiopathic_set)]
# Out:
#           ID                                        assay  estimate  \
# 13   ARFGAP1                 Radial Glia SOX2+PAX6+FABP7+  1.138057
# 15     ARL5B                 Radial Glia SOX2+PAX6+FABP7+  0.593515
# 68     CNOT1                 Radial Glia SOX2+PAX6+FABP7+  0.660485
# 86     CWC22                 Radial Glia SOX2+PAX6+FABP7+ -0.753128
# 116    FGFR3                 Radial Glia SOX2+PAX6+FABP7+  0.949626
# 152     IST1                 Radial Glia SOX2+PAX6+FABP7+  0.612144
# 180     NAE1                 Radial Glia SOX2+PAX6+FABP7+ -0.588743
# 207    PCGF5                 Radial Glia SOX2+PAX6+FABP7+ -0.671878
# 230   PTPN13   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.821684
# 268  SLC25A1                 Radial Glia SOX2+PAX6+FABP7+  0.526404
# 269  SLC25A1                  Radial Glia SOX2+VIM+FABP7+ -1.157783
# 330    WDR36                 Radial Glia SOX2+PAX6+FABP7+  0.657502
# 334     WWC2                 Radial Glia SOX2+PAX6+FABP7+  0.716472
# 917     WWC2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.977343
# 26   ARFGAP1                  Radial Glia SOX2+VIM+FABP7+ -0.283706
# 29     ARL5B                  Radial Glia SOX2+VIM+FABP7+ -0.534914
# 80     CNOT1                  Radial Glia SOX2+VIM+FABP7+ -0.330990
# 100    CWC22                  Radial Glia SOX2+VIM+FABP7+ -0.276309
# 182    FGFR3                  Radial Glia SOX2+VIM+FABP7+ -0.676409
# 242     IST1                  Radial Glia SOX2+VIM+FABP7+ -0.301900
# 321     NAE1                  Radial Glia SOX2+VIM+FABP7+  0.300269
# 347    PCGF5                  Radial Glia SOX2+VIM+FABP7+ -0.291696
# 398   PTPN13   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.322741
# 457  SLC25A1  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.814468
# 458  SLC25A1           Hindbrain Neurons NR2F2+PBX3+LHX1+ -0.876600
# 560    WDR36                  Radial Glia SOX2+VIM+FABP7+ -0.345726
# 563     WWC2                  Radial Glia SOX2+VIM+FABP7+  0.575885
#
#      std.error  statistic       p.value  n.studies method  \
# 13    0.253955   4.481326  7.418086e-06          2     FE
# 15    0.209138   2.837905  4.541065e-03          2     FE
# 68    0.195281   3.382234  7.189898e-04          2     FE
# 86    0.223357  -3.371860  7.466239e-04          2     FE
# 116   0.301747   3.147093  1.649026e-03          2     FE
# 152   0.202261   3.026504  2.473994e-03          2     FE
# 180   0.201519  -2.921522  3.483255e-03          2     FE
# 207   0.219370  -3.062763  2.193037e-03          2     FE
# 230   0.236569  -3.473342  5.140207e-04          2     FE
# 268   0.193213   2.724475  6.440377e-03          2     FE
# 269   0.194833  -5.942451  2.807913e-09          2     FE
# 330   0.229960   2.859198  4.247142e-03          2     FE
# 334   0.222280   3.223286  1.267291e-03          2     FE
# 917   0.133706  -7.309649  2.678409e-13          2     FE
# 26    0.080167  -3.538920  4.017668e-04          3     FE
# 29    0.108894  -4.912227  9.004781e-07          3     FE
# 80    0.097068  -3.409866  6.499471e-04          3     FE
# 100   0.079878  -3.459126  5.419307e-04          3     FE
# 182   0.199281  -3.394247  6.881771e-04          3     FE
# 242   0.081957  -3.683647  2.299209e-04          3     FE
# 321   0.076657   3.917038  8.964346e-05          3     FE
# 347   0.082441  -3.538244  4.027974e-04          3     FE
# 398   0.082883  -3.893935  9.863113e-05          3     FE
# 457   0.125582  -6.485544  8.841244e-11          3     FE
# 458   0.169973  -5.157305  2.505301e-07          3     FE
# 560   0.088141  -3.922399  8.767156e-05          3     FE
# 563   0.147246   3.911047  9.189683e-05          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 13              Radial Glia SOX2+PAX6+FABP7+ | ARFGAP1   0.000175  ...
# 15                Radial Glia SOX2+PAX6+FABP7+ | ARL5B   0.026245  ...
# 68                Radial Glia SOX2+PAX6+FABP7+ | CNOT1   0.006441  ...
# 86                Radial Glia SOX2+PAX6+FABP7+ | CWC22   0.006642  ...
# 116               Radial Glia SOX2+PAX6+FABP7+ | FGFR3   0.012185  ...
# 152                Radial Glia SOX2+PAX6+FABP7+ | IST1   0.016366  ...
# 180                Radial Glia SOX2+PAX6+FABP7+ | NAE1   0.021367  ...
# 207               Radial Glia SOX2+PAX6+FABP7+ | PCGF5   0.014942  ...
# 230  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...   0.006092  ...
# 268             Radial Glia SOX2+PAX6+FABP7+ | SLC25A1   0.034063  ...
# 269              Radial Glia SOX2+VIM+FABP7+ | SLC25A1   0.000002  ...
# 330               Radial Glia SOX2+PAX6+FABP7+ | WDR36   0.025007  ...
# 334                Radial Glia SOX2+PAX6+FABP7+ | WWC2   0.009917  ...
# 917  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
# 26               Radial Glia SOX2+VIM+FABP7+ | ARFGAP1    0.01587  ...
# 29                 Radial Glia SOX2+VIM+FABP7+ | ARL5B   0.000166  ...
# 80                 Radial Glia SOX2+VIM+FABP7+ | CNOT1   0.021876  ...
# 100                Radial Glia SOX2+VIM+FABP7+ | CWC22   0.019363  ...
# 182                Radial Glia SOX2+VIM+FABP7+ | FGFR3    0.02272  ...
# 242                 Radial Glia SOX2+VIM+FABP7+ | IST1   0.011064  ...
# 321                 Radial Glia SOX2+VIM+FABP7+ | NAE1   0.005514  ...
# 347                Radial Glia SOX2+VIM+FABP7+ | PCGF5    0.01587  ...
# 398  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...   0.015274  ...
# 457  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
# 458       Hindbrain Neurons NR2F2+PBX3+LHX1+ | SLC25A1   0.000079  ...
# 560                Radial Glia SOX2+VIM+FABP7+ | WDR36   0.005444  ...
# 563                 Radial Glia SOX2+VIM+FABP7+ | WWC2   0.005575  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 13       0.236067       1.538420                      True    0.887243
# 15       0.444488       0.712637                      True    0.578563
# 68       0.254040       0.898589                      True    0.576314
# 86      -0.015964      -1.163962                      True   -0.589963
# 116      1.289521       0.809575                      True    1.049548
# 152      0.369468       0.750609                      True    0.560039
# 180     -0.194280      -0.797137                      True   -0.495708
# 207     -0.738346      -0.608290                      True   -0.673318
# 230     -0.104303      -1.949180                      True   -1.026742
# 268      0.115050       0.743852                      True    0.429451
# 269     -0.856983      -1.369621                      True   -1.113302
# 330      0.385906       0.709780                      True    0.547843
# 334      0.441549       0.888741                      True    0.665145
# 917           NaN            NaN                      True   -0.644792
# 26            NaN            NaN                      True   -0.233388
# 29            NaN            NaN                      True   -0.638713
# 80            NaN            NaN                      True   -0.330566
# 100           NaN            NaN                      True   -0.275570
# 182           NaN            NaN                      True   -0.693098
# 242           NaN            NaN                      True   -0.313971
# 321           NaN            NaN                      True    0.297948
# 347           NaN            NaN                      True   -0.282890
# 398           NaN            NaN                      True   -0.420705
# 457           NaN            NaN                      True   -0.666451
# 458           NaN            NaN                      True   -0.790831
# 560           NaN            NaN                      True   -0.411982
# 563           NaN            NaN                      True    0.570024
#
#                         group logFC_sebastian  logFC_fernando  logFC_rao  \
# 13   Idiopathic Schizophrenia             NaN             NaN        NaN
# 15   Idiopathic Schizophrenia             NaN             NaN        NaN
# 68   Idiopathic Schizophrenia             NaN             NaN        NaN
# 86   Idiopathic Schizophrenia             NaN             NaN        NaN
# 116  Idiopathic Schizophrenia             NaN             NaN        NaN
# 152  Idiopathic Schizophrenia             NaN             NaN        NaN
# 180  Idiopathic Schizophrenia             NaN             NaN        NaN
# 207  Idiopathic Schizophrenia             NaN             NaN        NaN
# 230  Idiopathic Schizophrenia             NaN             NaN        NaN
# 268  Idiopathic Schizophrenia             NaN             NaN        NaN
# 269  Idiopathic Schizophrenia             NaN             NaN        NaN
# 330  Idiopathic Schizophrenia             NaN             NaN        NaN
# 334  Idiopathic Schizophrenia             NaN             NaN        NaN
# 917                  NRXN1del       -0.156282       -1.133303        NaN
# 26                 22q11.2del             NaN             NaN  -0.468379
# 29                 22q11.2del             NaN             NaN  -0.361179
# 80                 22q11.2del             NaN             NaN  -0.258627
# 100                22q11.2del             NaN             NaN  -0.309290
# 182                22q11.2del             NaN             NaN  -0.560274
# 242                22q11.2del             NaN             NaN  -0.280678
# 321                22q11.2del             NaN             NaN   0.237204
# 347                22q11.2del             NaN             NaN  -0.092716
# 398                22q11.2del             NaN             NaN  -0.260769
# 457                22q11.2del             NaN             NaN  -0.560547
# 458                22q11.2del             NaN             NaN  -0.870662
# 560                22q11.2del             NaN             NaN  -0.589437
# 563                22q11.2del             NaN             NaN   0.529589
#
#      logFC_shin  logFC_walsh
# 13          NaN          NaN
# 15          NaN          NaN
# 68          NaN          NaN
# 86          NaN          NaN
# 116         NaN          NaN
# 152         NaN          NaN
# 180         NaN          NaN
# 207         NaN          NaN
# 230         NaN          NaN
# 268         NaN          NaN
# 269         NaN          NaN
# 330         NaN          NaN
# 334         NaN          NaN
# 917         NaN          NaN
# 26    -0.120433    -0.111350
# 29    -0.671502    -0.883458
# 80    -0.358950    -0.374121
# 100   -0.227645    -0.289776
# 182   -0.858861    -0.660159
# 242   -0.375713    -0.285523
# 321    0.357769     0.298872
# 347   -0.498651    -0.257303
# 398   -0.232399    -0.768948
# 457   -0.464521    -0.974284
# 458   -0.541840    -0.959993
# 560   -0.279913    -0.366597
# 563    0.604951     0.575531
#
# [27 rows x 21 columns]

# %%
dc_significant_all[dc_significant_all['ID'].isin(sig_22q11_nrxn1_set)]
# Out:
#           ID                                        assay  estimate  \
# 334     WWC2                 Radial Glia SOX2+PAX6+FABP7+  0.716472
# 34   ALDH9A1  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.403603
# 150   CITED2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.571930
# 151   CITED2           Mixed Neurons FGF12+GRIN2B+CAMK2B+  0.625684
# 277     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.381210
# 278    ETNK1                    Astrocyte GFAP+AQP4+HOPX+  1.079115
# 389     IER5  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.540688
# 399     IRS1           Mixed Neurons FGF12+GRIN2B+CAMK2B+  0.541232
# 411  KHDRBS3  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.667535
# 445    LRIF1   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.464016
# 518     NBEA  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.899903
# 572   NUP153  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.348227
# 610     PIM1                  Radial Glia SOX2+VIM+FABP7+  1.006274
# 785     SMN1   Proliferative Radial Glia SOX2+HES6+TOP2A+  0.393750
# 862  TMEM38B           Mixed Neurons FGF12+GRIN2B+CAMK2B+  0.498254
# 878   TRIAP1  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.533048
# 903     VCAN                    Astrocyte GFAP+AQP4+HOPX+ -1.164505
# 917     WWC2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.977343
# 17   ALDH9A1                  Radial Glia SOX2+VIM+FABP7+  0.342379
# 75    CITED2                  Radial Glia SOX2+VIM+FABP7+  0.655290
# 159     ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.861508
# 160     ESS2           Hindbrain Neurons NR2F2+PBX3+LHX1+ -0.842950
# 161     ESS2                 Radial Glia SOX2+PAX6+FABP7+ -0.856466
# 162     ESS2                  Radial Glia SOX2+VIM+FABP7+ -0.983782
# 163    ETNK1                  Radial Glia SOX2+VIM+FABP7+ -0.371684
# 228     IER5                  Radial Glia SOX2+VIM+FABP7+ -0.443845
# 239     IRS1                  Radial Glia SOX2+VIM+FABP7+ -0.657800
# 249  KHDRBS3   Proliferative Radial Glia SOX2+HES6+TOP2A+  0.710519
# 267    LRIF1           Hindbrain Neurons NR2F2+PBX3+LHX1+  0.511958
# 322     NBEA                  Radial Glia SOX2+VIM+FABP7+  0.398295
# 339   NUP153                  Radial Glia SOX2+VIM+FABP7+ -0.353502
# 372     PIM1                  Radial Glia SOX2+VIM+FABP7+ -1.011566
# 469     SMN1                  Radial Glia SOX2+VIM+FABP7+ -0.312979
# 521  TMEM38B   Proliferative Radial Glia SOX2+HES6+TOP2A+  0.394485
# 530   TRIAP1                  Radial Glia SOX2+VIM+FABP7+ -0.357742
# 556     VCAN  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.719581
# 563     WWC2                  Radial Glia SOX2+VIM+FABP7+  0.575885
#
#      std.error  statistic       p.value  n.studies method  \
# 334   0.222280   3.223286  1.267291e-03          2     FE
# 34    0.102877   3.923170  8.739134e-05          2     FE
# 150   0.140862   4.060220  4.902647e-05          2     FE
# 151   0.128969   4.851446  1.225649e-06          2     FE
# 277   0.100870   3.779235  1.573109e-04          2     FE
# 278   0.331134   3.258847  1.118659e-03          2     FE
# 389   0.136857   3.950752  7.790596e-05          2     FE
# 399   0.136237   3.972731  7.105335e-05          2     FE
# 411   0.167700   3.980543  6.875808e-05          2     FE
# 445   0.119987  -3.867220  1.100832e-04          2     FE
# 518   0.269287  -3.341805  8.323549e-04          2     FE
# 572   0.106089  -3.282411  1.029236e-03          2     FE
# 610   0.209890   4.794298  1.632453e-06          2     FE
# 785   0.105999   3.714662  2.034756e-04          2     FE
# 862   0.116727   4.268544  1.967527e-05          2     FE
# 878   0.117260   4.545859  5.471176e-06          2     FE
# 903   0.254861  -4.569171  4.896571e-06          2     FE
# 917   0.133706  -7.309649  2.678409e-13          2     FE
# 17    0.111753   3.063717  2.186059e-03          3     FE
# 75    0.211724   3.095020  1.967999e-03          3     FE
# 159   0.117751  -7.316366  2.547755e-13          3     FE
# 160   0.088572  -9.517118  1.780489e-21          3     FE
# 161   0.137941  -6.208948  5.334032e-10          3     FE
# 162   0.114052  -8.625699  6.370245e-18          3     FE
# 163   0.115892  -3.207150  1.340569e-03          3     FE
# 228   0.113073  -3.925292  8.662445e-05          3     FE
# 239   0.209739  -3.136275  1.711087e-03          3     FE
# 249   0.188751   3.764327  1.669985e-04          3     FE
# 267   0.106098   4.825328  1.397733e-06          3     FE
# 322   0.128721   3.094260  1.973044e-03          3     FE
# 339   0.110817  -3.189966  1.422896e-03          3     FE
# 372   0.177351  -5.703763  1.171907e-08          3     FE
# 469   0.101500  -3.083532  2.045592e-03          3     FE
# 521   0.102316   3.855571  1.154597e-04          3     FE
# 530   0.092310  -3.875447  1.064290e-04          3     FE
# 556   0.199722  -3.602921  3.146612e-04          3     FE
# 563   0.147246   3.911047  9.189683e-05          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 334                Radial Glia SOX2+PAX6+FABP7+ | WWC2   0.009917  ...
# 34   Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.005844  ...
# 150  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.003828  ...
# 151        Mixed Neurons FGF12+GRIN2B+CAMK2B+ | CITED2   0.000732  ...
# 277  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.008815  ...
# 278                  Astrocyte GFAP+AQP4+HOPX+ | ETNK1   0.019474  ...
# 389  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.005328  ...
# 399          Mixed Neurons FGF12+GRIN2B+CAMK2B+ | IRS1   0.014299  ...
# 411  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.004848  ...
# 445  Proliferative Radial Glia SOX2+HES6+TOP2A+ | L...   0.019336  ...
# 518  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.030074  ...
# 572  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.034319  ...
# 610                 Radial Glia SOX2+VIM+FABP7+ | PIM1   0.000937  ...
# 785  Proliferative Radial Glia SOX2+HES6+TOP2A+ | SMN1   0.029665  ...
# 862       Mixed Neurons FGF12+GRIN2B+CAMK2B+ | TMEM38B   0.005848  ...
# 878  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.000656  ...
# 903                   Astrocyte GFAP+AQP4+HOPX+ | VCAN   0.000416  ...
# 917  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
# 17               Radial Glia SOX2+VIM+FABP7+ | ALDH9A1   0.048732  ...
# 75                Radial Glia SOX2+VIM+FABP7+ | CITED2   0.045505  ...
# 159  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
# 160          Hindbrain Neurons NR2F2+PBX3+LHX1+ | ESS2        0.0  ...
# 161                Radial Glia SOX2+PAX6+FABP7+ | ESS2        0.0  ...
# 162                 Radial Glia SOX2+VIM+FABP7+ | ESS2        0.0  ...
# 163                Radial Glia SOX2+VIM+FABP7+ | ETNK1   0.035247  ...
# 228                 Radial Glia SOX2+VIM+FABP7+ | IER5   0.005405  ...
# 239                 Radial Glia SOX2+VIM+FABP7+ | IRS1   0.041019  ...
# 249  Proliferative Radial Glia SOX2+HES6+TOP2A+ | K...   0.021657  ...
# 267         Hindbrain Neurons NR2F2+PBX3+LHX1+ | LRIF1   0.000391  ...
# 322                 Radial Glia SOX2+VIM+FABP7+ | NBEA   0.045541  ...
# 339               Radial Glia SOX2+VIM+FABP7+ | NUP153   0.036609  ...
# 372                 Radial Glia SOX2+VIM+FABP7+ | PIM1   0.000005  ...
# 469                 Radial Glia SOX2+VIM+FABP7+ | SMN1   0.046475  ...
# 521  Proliferative Radial Glia SOX2+HES6+TOP2A+ | T...   0.016816  ...
# 530               Radial Glia SOX2+VIM+FABP7+ | TRIAP1   0.006224  ...
# 556  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...    0.03602  ...
# 563                 Radial Glia SOX2+VIM+FABP7+ | WWC2   0.005575  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 334      0.441549       0.888741                      True    0.665145
# 34            NaN            NaN                      True    0.393876
# 150           NaN            NaN                      True    0.416502
# 151           NaN            NaN                      True    0.415624
# 277           NaN            NaN                      True    0.317700
# 278           NaN            NaN                      True    0.744709
# 389           NaN            NaN                      True    0.460562
# 399           NaN            NaN                      True    0.346463
# 411           NaN            NaN                      True    0.704091
# 445           NaN            NaN                      True   -0.328131
# 518           NaN            NaN                      True   -0.832898
# 572           NaN            NaN                      True   -0.301279
# 610           NaN            NaN                      True    0.848053
# 785           NaN            NaN                      True    0.764826
# 862           NaN            NaN                      True    0.392617
# 878           NaN            NaN                      True    0.566625
# 903           NaN            NaN                      True   -0.703819
# 917           NaN            NaN                      True   -0.644792
# 17            NaN            NaN                      True    0.336351
# 75            NaN            NaN                      True    0.640211
# 159           NaN            NaN                      True   -0.792062
# 160           NaN            NaN                      True   -0.971627
# 161           NaN            NaN                      True   -0.545744
# 162           NaN            NaN                      True   -1.071630
# 163           NaN            NaN                      True   -0.329391
# 228           NaN            NaN                      True   -0.562396
# 239           NaN            NaN                      True   -0.604193
# 249           NaN            NaN                      True    0.686771
# 267           NaN            NaN                      True    0.398403
# 322           NaN            NaN                      True    0.293523
# 339           NaN            NaN                      True   -0.315141
# 372           NaN            NaN                      True   -0.833336
# 469           NaN            NaN                      True   -0.282004
# 521           NaN            NaN                      True    0.230906
# 530           NaN            NaN                      True   -0.280322
# 556           NaN            NaN                      True   -0.768753
# 563           NaN            NaN                      True    0.570024
#
#                         group logFC_sebastian  logFC_fernando  logFC_rao  \
# 334  Idiopathic Schizophrenia             NaN             NaN        NaN
# 34                   NRXN1del        0.229658        0.558094        NaN
# 150                  NRXN1del        0.111346        0.721659        NaN
# 151                  NRXN1del        0.100658        0.730591        NaN
# 277                  NRXN1del        0.117488        0.517913        NaN
# 278                  NRXN1del        0.146993        1.342426        NaN
# 389                  NRXN1del        0.107279        0.813845        NaN
# 399                  NRXN1del        0.069387        0.623538        NaN
# 411                  NRXN1del        0.511655        0.896527        NaN
# 445                  NRXN1del       -0.084454       -0.571807        NaN
# 518                  NRXN1del       -0.355508       -1.310288        NaN
# 572                  NRXN1del       -0.147255       -0.455302        NaN
# 610                  NRXN1del        0.214780        1.481326        NaN
# 785                  NRXN1del        0.017615        1.512038        NaN
# 862                  NRXN1del        0.092346        0.692889        NaN
# 878                  NRXN1del        0.209690        0.923560        NaN
# 903                  NRXN1del       -0.038142       -1.369496        NaN
# 917                  NRXN1del       -0.156282       -1.133303        NaN
# 17                 22q11.2del             NaN             NaN   0.475208
# 75                 22q11.2del             NaN             NaN   0.351415
# 159                22q11.2del             NaN             NaN  -0.931210
# 160                22q11.2del             NaN             NaN  -0.897151
# 161                22q11.2del             NaN             NaN  -0.981742
# 162                22q11.2del             NaN             NaN  -1.299083
# 163                22q11.2del             NaN             NaN  -0.267766
# 228                22q11.2del             NaN             NaN  -0.403689
# 239                22q11.2del             NaN             NaN  -0.633630
# 249                22q11.2del             NaN             NaN   1.377186
# 267                22q11.2del             NaN             NaN   0.010113
# 322                22q11.2del             NaN             NaN   0.085446
# 339                22q11.2del             NaN             NaN  -0.386439
# 372                22q11.2del             NaN             NaN  -0.573554
# 469                22q11.2del             NaN             NaN  -0.352395
# 521                22q11.2del             NaN             NaN   0.426338
# 530                22q11.2del             NaN             NaN  -0.276081
# 556                22q11.2del             NaN             NaN  -0.910889
# 563                22q11.2del             NaN             NaN   0.529589
#
#      logFC_shin  logFC_walsh
# 334         NaN          NaN
# 34          NaN          NaN
# 150         NaN          NaN
# 151         NaN          NaN
# 277         NaN          NaN
# 278         NaN          NaN
# 389         NaN          NaN
# 399         NaN          NaN
# 411         NaN          NaN
# 445         NaN          NaN
# 518         NaN          NaN
# 572         NaN          NaN
# 610         NaN          NaN
# 785         NaN          NaN
# 862         NaN          NaN
# 878         NaN          NaN
# 903         NaN          NaN
# 917         NaN          NaN
# 17     0.314958     0.218887
# 75     0.346848     1.222370
# 159   -0.482282    -0.962693
# 160   -0.718545    -1.299184
# 161   -0.046447    -0.609044
# 162   -0.667296    -1.248512
# 163   -0.507961    -0.212446
# 228   -0.922523    -0.360976
# 239   -0.006725    -1.172223
# 249    0.386642     0.296485
# 267    0.925001     0.260095
# 322    0.730483     0.064641
# 339   -0.343310    -0.215673
# 372   -1.385680    -0.540774
# 469   -0.252304    -0.241313
# 521    0.091082     0.175298
# 530   -0.453320    -0.111566
# 556   -0.306301    -1.089068
# 563    0.604951     0.575531
#
# [37 rows x 21 columns]

# %%
dc_significant_all[dc_significant_all['ID'].isin(sig_idiopathic_nrxn1_set)]
# Out:
#           ID                                        assay  estimate  \
# 2      ACAT2   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.769977
# 124     GMNN                 Radial Glia SOX2+PAX6+FABP7+ -0.830328
# 132   GTF2H2                 Radial Glia SOX2+PAX6+FABP7+ -0.728649
# 134    H2AZ1                 Radial Glia SOX2+PAX6+FABP7+ -0.523346
# 143  IER3IP1                 Radial Glia SOX2+PAX6+FABP7+ -0.518882
# 158    KLF13   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.753806
# 173  MID1IP1                 Radial Glia SOX2+PAX6+FABP7+  0.655463
# 175     MPP5   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.896524
# 243    RIOK3                 Radial Glia SOX2+PAX6+FABP7+  0.603009
# 281    SNHG8   Proliferative Radial Glia SOX2+HES6+TOP2A+  1.008659
# 295  THUMPD3   Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.729841
# 314   TUBA1B                 Radial Glia SOX2+PAX6+FABP7+ -0.630875
# 316    TXNIP   Proliferative Radial Glia SOX2+HES6+TOP2A+  0.802542
# 317    TXNIP                 Radial Glia SOX2+PAX6+FABP7+  0.871573
# 334     WWC2                 Radial Glia SOX2+PAX6+FABP7+  0.716472
# 6      ACAT2                    Astrocyte GFAP+AQP4+HOPX+  1.317077
# 340     GMNN  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.677147
# 358   GTF2H2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.475634
# 361    H2AZ1                    Astrocyte GFAP+AQP4+HOPX+  0.941811
# 388  IER3IP1                      IPC EOMES+NEUROG2+PAX6+  0.630658
# 419    KLF13                      IPC EOMES+NEUROG2+PAX6+  0.680146
# 479  MID1IP1  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.820810
# 487     MPP5  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.490600
# 707    RIOK3                    Astrocyte GFAP+AQP4+HOPX+ -0.691638
# 788    SNHG8                      IPC EOMES+NEUROG2+PAX6+  0.839458
# 842  THUMPD3                      IPC EOMES+NEUROG2+PAX6+  0.648543
# 885   TUBA1B                    Astrocyte GFAP+AQP4+HOPX+  0.790021
# 889    TXNIP                    Astrocyte GFAP+AQP4+HOPX+ -1.346288
# 917     WWC2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.977343
# 563     WWC2                  Radial Glia SOX2+VIM+FABP7+  0.575885
#
#      std.error  statistic       p.value  n.studies method  \
# 2     0.239647  -3.212958  1.313754e-03          2     FE
# 124   0.205176  -4.046906  5.189914e-05          2     FE
# 132   0.202898  -3.591212  3.291439e-04          2     FE
# 134   0.196016  -2.669914  7.587061e-03          2     FE
# 143   0.187641  -2.765286  5.687293e-03          2     FE
# 158   0.261557  -2.881992  3.951692e-03          2     FE
# 173   0.191980   3.414226  6.396339e-04          2     FE
# 175   0.255693  -3.506252  4.544641e-04          2     FE
# 243   0.218876   2.755021  5.868840e-03          2     FE
# 281   0.322687   3.125808  1.773170e-03          2     FE
# 295   0.271553  -2.687661  7.195449e-03          2     FE
# 314   0.198424  -3.179419  1.475704e-03          2     FE
# 316   0.227556   3.526786  4.206360e-04          2     FE
# 317   0.276759   3.149218  1.637082e-03          2     FE
# 334   0.222280   3.223286  1.267291e-03          2     FE
# 6     0.310341   4.243963  2.196063e-05          2     FE
# 340   0.186848   3.624062  2.900124e-04          2     FE
# 358   0.116975   4.066107  4.780508e-05          2     FE
# 361   0.308195   3.055891  2.243926e-03          2     FE
# 388   0.185737   3.395432  6.852027e-04          2     FE
# 419   0.187135   3.634530  2.784879e-04          2     FE
# 479   0.187046   4.388269  1.142563e-05          2     FE
# 487   0.121510   4.037520  5.401933e-05          2     FE
# 707   0.220956  -3.130208  1.746823e-03          2     FE
# 788   0.237090   3.540676  3.991034e-04          2     FE
# 842   0.199203   3.255684  1.131197e-03          2     FE
# 885   0.231198   3.417074  6.329810e-04          2     FE
# 889   0.341190  -3.945859  7.951440e-05          2     FE
# 917   0.133706  -7.309649  2.678409e-13          2     FE
# 563   0.147246   3.911047  9.189683e-05          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 2    Proliferative Radial Glia SOX2+HES6+TOP2A+ | A...   0.012434  ...
# 124                Radial Glia SOX2+PAX6+FABP7+ | GMNN   0.000812  ...
# 132              Radial Glia SOX2+PAX6+FABP7+ | GTF2H2    0.00349  ...
# 134               Radial Glia SOX2+PAX6+FABP7+ | H2AZ1   0.038336  ...
# 143             Radial Glia SOX2+PAX6+FABP7+ | IER3IP1   0.031074  ...
# 158  Proliferative Radial Glia SOX2+HES6+TOP2A+ | K...   0.028208  ...
# 173             Radial Glia SOX2+PAX6+FABP7+ | MID1IP1   0.005852  ...
# 175  Proliferative Radial Glia SOX2+HES6+TOP2A+ | MPP5   0.005541  ...
# 243               Radial Glia SOX2+PAX6+FABP7+ | RIOK3   0.031844  ...
# 281  Proliferative Radial Glia SOX2+HES6+TOP2A+ | S...   0.015761  ...
# 295  Proliferative Radial Glia SOX2+HES6+TOP2A+ | T...   0.043977  ...
# 314              Radial Glia SOX2+PAX6+FABP7+ | TUBA1B   0.011241  ...
# 316  Proliferative Radial Glia SOX2+HES6+TOP2A+ | T...   0.005238  ...
# 317               Radial Glia SOX2+PAX6+FABP7+ | TXNIP   0.012137  ...
# 334                Radial Glia SOX2+PAX6+FABP7+ | WWC2   0.009917  ...
# 6                    Astrocyte GFAP+AQP4+HOPX+ | ACAT2   0.001205  ...
# 340  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.013428  ...
# 358  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.003767  ...
# 361                  Astrocyte GFAP+AQP4+HOPX+ | H2AZ1   0.030655  ...
# 388                  IPC EOMES+NEUROG2+PAX6+ | IER3IP1    0.02485  ...
# 419                    IPC EOMES+NEUROG2+PAX6+ | KLF13    0.01351  ...
# 479  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.001235  ...
# 487  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.004136  ...
# 707                  Astrocyte GFAP+AQP4+HOPX+ | RIOK3   0.025709  ...
# 788                    IPC EOMES+NEUROG2+PAX6+ | SNHG8   0.017038  ...
# 842                  IPC EOMES+NEUROG2+PAX6+ | THUMPD3   0.035361  ...
# 885                 Astrocyte GFAP+AQP4+HOPX+ | TUBA1B   0.013163  ...
# 889                  Astrocyte GFAP+AQP4+HOPX+ | TXNIP   0.002954  ...
# 917  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
# 563                 Radial Glia SOX2+VIM+FABP7+ | WWC2   0.005575  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 2       -0.531587      -1.100589                      True   -0.816088
# 124     -0.233035      -1.160199                      True   -0.696617
# 132     -0.004402      -1.463980                      True   -0.734191
# 134     -0.515356      -0.528945                      True   -0.522150
# 143     -0.061245      -0.828717                      True   -0.444981
# 158     -0.470349      -1.071876                      True   -0.771112
# 173      0.296491       0.887862                      True    0.592176
# 175     -0.554074      -1.111785                      True   -0.832929
# 243      0.301603       0.712202                      True    0.506902
# 281      0.033287       3.440751                      True    1.737019
# 295     -0.361375      -1.508459                      True   -0.934917
# 314     -0.354139      -0.779753                      True   -0.566946
# 316      0.580400       1.409482                      True    0.994941
# 317      1.287230       0.653108                      True    0.970169
# 334      0.441549       0.888741                      True    0.665145
# 6             NaN            NaN                      True    0.986586
# 340           NaN            NaN                      True    0.465609
# 358           NaN            NaN                      True    0.393736
# 361           NaN            NaN                      True    0.731326
# 388           NaN            NaN                      True    0.589798
# 419           NaN            NaN                      True    0.612417
# 479           NaN            NaN                      True    0.725728
# 487           NaN            NaN                      True    0.363790
# 707           NaN            NaN                      True   -0.605364
# 788           NaN            NaN                      True    0.834252
# 842           NaN            NaN                      True    0.649424
# 885           NaN            NaN                      True    0.476272
# 889           NaN            NaN                      True   -1.067313
# 917           NaN            NaN                      True   -0.644792
# 563           NaN            NaN                      True    0.570024
#
#                         group logFC_sebastian  logFC_fernando  logFC_rao  \
# 2    Idiopathic Schizophrenia             NaN             NaN        NaN
# 124  Idiopathic Schizophrenia             NaN             NaN        NaN
# 132  Idiopathic Schizophrenia             NaN             NaN        NaN
# 134  Idiopathic Schizophrenia             NaN             NaN        NaN
# 143  Idiopathic Schizophrenia             NaN             NaN        NaN
# 158  Idiopathic Schizophrenia             NaN             NaN        NaN
# 173  Idiopathic Schizophrenia             NaN             NaN        NaN
# 175  Idiopathic Schizophrenia             NaN             NaN        NaN
# 243  Idiopathic Schizophrenia             NaN             NaN        NaN
# 281  Idiopathic Schizophrenia             NaN             NaN        NaN
# 295  Idiopathic Schizophrenia             NaN             NaN        NaN
# 314  Idiopathic Schizophrenia             NaN             NaN        NaN
# 316  Idiopathic Schizophrenia             NaN             NaN        NaN
# 317  Idiopathic Schizophrenia             NaN             NaN        NaN
# 334  Idiopathic Schizophrenia             NaN             NaN        NaN
# 6                    NRXN1del        0.511047        1.462126        NaN
# 340                  NRXN1del        0.048918        0.882300        NaN
# 358                  NRXN1del        0.114300        0.673173        NaN
# 361                  NRXN1del        0.436772        1.025881        NaN
# 388                  NRXN1del        0.317479        0.862117        NaN
# 419                  NRXN1del        0.493204        0.731630        NaN
# 479                  NRXN1del        0.448905        1.002552        NaN
# 487                  NRXN1del        0.068277        0.659303        NaN
# 707                  NRXN1del       -0.228923       -0.981804        NaN
# 788                  NRXN1del        0.258982        1.409522        NaN
# 842                  NRXN1del        0.116375        1.182473        NaN
# 885                  NRXN1del        0.120534        0.832011        NaN
# 889                  NRXN1del       -0.669246       -1.465380        NaN
# 917                  NRXN1del       -0.156282       -1.133303        NaN
# 563                22q11.2del             NaN             NaN   0.529589
#
#      logFC_shin  logFC_walsh
# 2           NaN          NaN
# 124         NaN          NaN
# 132         NaN          NaN
# 134         NaN          NaN
# 143         NaN          NaN
# 158         NaN          NaN
# 173         NaN          NaN
# 175         NaN          NaN
# 243         NaN          NaN
# 281         NaN          NaN
# 295         NaN          NaN
# 314         NaN          NaN
# 316         NaN          NaN
# 317         NaN          NaN
# 334         NaN          NaN
# 6           NaN          NaN
# 340         NaN          NaN
# 358         NaN          NaN
# 361         NaN          NaN
# 388         NaN          NaN
# 419         NaN          NaN
# 479         NaN          NaN
# 487         NaN          NaN
# 707         NaN          NaN
# 788         NaN          NaN
# 842         NaN          NaN
# 885         NaN          NaN
# 889         NaN          NaN
# 917         NaN          NaN
# 563    0.604951     0.575531
#
# [30 rows x 21 columns]

# %%
def plot_count_strip(values, orientation="horizontal", cmap="Reds", figsize=None, dataset_label='',
                     annotate=True, vmin=None, vmax=None, cbar=True, save=False):
    
    values = np.array(values)
    
    if orientation == "horizontal":
        data = values.reshape(1, -1)
        if figsize is None:
            figsize = (len(values)*1.24191295198, 1)
        xticklabels = False
        yticklabels = False
        
    elif orientation == "vertical":
        data = values.reshape(-1, 1)
        if figsize is None:
            figsize = (1.24191295198, len(values))
        xticklabels = False
        yticklabels = False
        
    else:
        raise ValueError("orientation must be 'horizontal' or 'vertical'")
    
    plt.figure(figsize=figsize)
    
    sns.heatmap(data, cmap=cmap, cbar=cbar, annot=annotate, fmt=".0f", xticklabels=xticklabels, 
                yticklabels=yticklabels, vmin=vmin, vmax=vmax)
    
    #plt.tight_layout()
    
    if save:
        plt.savefig(f"/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_{dataset_label}_{orientation}_upset_heatmap.svg")
    
    plt.show()

# %%
def plot_assay_upset(df, set_col='group', gene_col='ID', significance_col='significant_fdr', 
                     min_size=1, dataset_label="", top_graph=True, side_graph=True, title=True, 
                     save=False):

    # filter significant genes
    if significance_col in df.columns:
        df = df[df[significance_col] == True]
    
    assay_sets = {val: set(group[gene_col].dropna().unique())
        for val, group in df.groupby(set_col)}
    
    # remove small sets
    assay_sets = {k: v for k, v in assay_sets.items() if len(v) >= min_size}
    
    # safety check
    if len(assay_sets) < 2:
        print(f"Not enough groups to plot: {list(assay_sets.keys())}")
        return
    
    # convert
    upset_data = from_contents(assay_sets)
    
    plt.figure(figsize=(10, 6))

    if top_graph and side_graph:
        upset = UpSet(upset_data, show_counts=True, sort_by='degree')
    elif top_graph and not side_graph:
        upset = UpSet(upset_data, show_counts=True, with_lines=True, element_size=49, totals_plot_elements=0)
    elif side_graph and not top_graph:
        upset = UpSet(upset_data, show_counts=True, with_lines=True, element_size=49, intersection_plot_elements=())
    else:
        upset = UpSet(upset_data, show_counts=True, with_lines=True, element_size=49, intersection_plot_elements=(), totals_plot_elements=0)
    
    upset.plot()

    if title:
        plt.suptitle(f"{dataset_label} Shared DGEs")
        
    if save:
        plt.savefig(f"/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_{dataset_label}_upset_.svg")
    
    plt.show()

# %%
dc_significant_all['group'].value_counts()
# Out:
# group
# NRXN1del                    723
# 22q11.2del                  340
# Idiopathic Schizophrenia    257
# Name: count, dtype: int64

# %%
dc_significant_all['assay'].value_counts()
# Out:
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    350
# Radial Glia SOX2+VIM+FABP7+                    215
# Proliferative Radial Glia SOX2+HES6+TOP2A+     207
# Radial Glia SOX2+PAX6+FABP7+                   204
# Astrocyte GFAP+AQP4+HOPX+                      134
# IPC EOMES+NEUROG2+PAX6+                         88
# Mixed Neurons FGF12+GRIN2B+CAMK2B+              69
# Hindbrain Neurons NR2F2+PBX3+LHX1+              52
# Mesenchymal-like cells VIM+VCAN+SPARC+           1
# Name: count, dtype: int64

# %%
dc_significant_all_rg_pax6 = dc_significant_all[dc_significant_all['assay'] == 'Radial Glia SOX2+PAX6+FABP7+']
dc_significant_all_prg = dc_significant_all[dc_significant_all['assay'] == 'Proliferative Radial Glia SOX2+HES6+TOP2A+']
dc_significant_all_rg_vim = dc_significant_all[dc_significant_all['assay'] == 'Radial Glia SOX2+VIM+FABP7+']
dc_significant_all_ipc = dc_significant_all[dc_significant_all['assay'] == 'IPC EOMES+NEUROG2+PAX6+']
dc_significant_all_dorsal = dc_significant_all[dc_significant_all['assay'] == 'Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+']
dc_significant_all_mixed = dc_significant_all[dc_significant_all['assay'] == 'Mixed Neurons FGF12+GRIN2B+CAMK2B+']
dc_significant_all_hindbrain = dc_significant_all[dc_significant_all['assay'] == 'Hindbrain Neurons NR2F2+PBX3+LHX1+']
dc_significant_all_mc = dc_significant_all[dc_significant_all['assay'] == 'Mesenchymal-like cells VIM+VCAN+SPARC+']
dc_significant_all_astro = dc_significant_all[dc_significant_all['assay'] == 'Astrocyte GFAP+AQP4+HOPX+']

# %%
plot_count_strip([166, 31, 7], dataset_label="Radial Glia SOX2+PAX6+FABP7+", save=True)

# %%
plot_assay_upset(dc_significant_all_rg_pax6,  dataset_label="Radial Glia SOX2+PAX6+FABP7+", 
                 set_col='group', top_graph=True, side_graph=False, save=True)

# %%
plot_count_strip([85, 82, 38, 1], dataset_label="Proliferative Radial Glia SOX2+HES6+TOP2A+", save=True)

# %%
plot_assay_upset(dc_significant_all_prg, dataset_label="Proliferative Radial Glia SOX2+HES6+TOP2A+", 
                 set_col='group', top_graph=True, side_graph=False, save=True)

# %%
plot_count_strip([45, 5, 2], dataset_label="Hindbrain Neurons NR2F2+PBX3+LHX1+", save=True)

# %%
plot_assay_upset(dc_significant_all_hindbrain, dataset_label="Hindbrain Neurons NR2F2+PBX3+LHX1+",
                 set_col='group', top_graph=True, side_graph=False, save=True)

# %%
plot_count_strip([193, 17, 3, 1], dataset_label="Radial Glia SOX2+VIM+FABP7+", save=True)

# %%
plot_assay_upset(dc_significant_all_rg_vim, dataset_label="Radial Glia SOX2+VIM+FABP7+", set_col='group',
                 top_graph=True, side_graph=False, save=True)

# %%
plot_count_strip([299, 49, 1], dataset_label="Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+", save=True)

# %%
plot_assay_upset(dc_significant_all_dorsal, dataset_label="Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+",
                 set_col='group', top_graph=True, side_graph=False, save=True)

# %%
plot_count_strip([64, 5], dataset_label="Mixed Neurons FGF12+GRIN2B+CAMK2B+", save=True)

# %%
plot_assay_upset(dc_significant_all_mixed, dataset_label="Mixed Neurons FGF12+GRIN2B+CAMK2B+",  
                 set_col='group', top_graph=True, side_graph=False, save=True)

# %%
plot_assay_upset(dc_significant_all_astro, dataset_label="Astrocyte",  
                 set_col='group', top_graph=True, side_graph=False, save=True)
# Out:
# Not enough groups to plot: ['NRXN1del']

# %%
plot_assay_upset(dc_significant_all_ipc, dataset_label="IPC",  
                 set_col='group', top_graph=True, side_graph=False, save=True)
# Out:
# Not enough groups to plot: ['NRXN1del']

# %%
## Find Duplicates in Dorsal DGE ##

dc_significant_all_dorsal[dc_significant_all_dorsal['ID'].duplicated(keep=False)]
# Out:
#        ID                                        assay  estimate  std.error  \
# 277  ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.381210   0.100870
# 159  ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.861508   0.117751
#
#      statistic       p.value  n.studies method  \
# 277   3.779235  1.573109e-04          2     FE
# 159  -7.316366  2.547755e-13          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 277  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.008815  ...
# 159  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 277           NaN            NaN                      True    0.317700
# 159           NaN            NaN                      True   -0.792062
#
#           group logFC_sebastian  logFC_fernando  logFC_rao  logFC_shin  \
# 277    NRXN1del        0.117488        0.517913        NaN         NaN
# 159  22q11.2del             NaN             NaN   -0.93121   -0.482282
#
#      logFC_walsh
# 277          NaN
# 159    -0.962693
#
# [2 rows x 21 columns]

# %%
## Find Duplicates in RG VIM+ DGE ##

dc_significant_all_rg_vim[dc_significant_all_rg_vim['ID'].duplicated(keep=False)]
# Out:
#        ID                        assay  estimate  std.error  statistic  \
# 610  PIM1  Radial Glia SOX2+VIM+FABP7+  1.006274   0.209890   4.794298
# 372  PIM1  Radial Glia SOX2+VIM+FABP7+ -1.011566   0.177351  -5.703763
#
#           p.value  n.studies method                            assay_ID  \
# 610  1.632453e-06          2     FE  Radial Glia SOX2+VIM+FABP7+ | PIM1
# 372  1.171907e-08          3     FE  Radial Glia SOX2+VIM+FABP7+ | PIM1
#
#     p.adjusted  ...  logFC_sawada  logFC_notaras  directionally_consistent  \
# 610   0.000937  ...           NaN            NaN                      True
# 372   0.000005  ...           NaN            NaN                      True
#
#      mean_logFC       group logFC_sebastian  logFC_fernando  logFC_rao  \
# 610    0.848053    NRXN1del         0.21478        1.481326        NaN
# 372   -0.833336  22q11.2del             NaN             NaN  -0.573554
#
#      logFC_shin  logFC_walsh
# 610         NaN          NaN
# 372    -1.38568    -0.540774
#
# [2 rows x 21 columns]

# %%
## Find Duplicates in proliferative RGs ##

dc_significant_all_prg[dc_significant_all_prg['ID'].duplicated(keep=False)]
# Out:
#          ID                                       assay  estimate  std.error  \
# 230  PTPN13  Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.821684   0.236569
# 398  PTPN13  Proliferative Radial Glia SOX2+HES6+TOP2A+ -0.322741   0.082883
#
#      statistic   p.value  n.studies method  \
# 230  -3.473342  0.000514          2     FE
# 398  -3.893935  0.000099          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 230  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...   0.006092  ...
# 398  Proliferative Radial Glia SOX2+HES6+TOP2A+ | P...   0.015274  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 230     -0.104303       -1.94918                      True   -1.026742
# 398           NaN            NaN                      True   -0.420705
#
#                         group logFC_sebastian  logFC_fernando  logFC_rao  \
# 230  Idiopathic Schizophrenia             NaN             NaN        NaN
# 398                22q11.2del             NaN             NaN  -0.260769
#
#      logFC_shin  logFC_walsh
# 230         NaN          NaN
# 398   -0.232399    -0.768948
#
# [2 rows x 21 columns]

# %%
dc_significant_all_dorsal[dc_significant_all_dorsal['ID'].duplicated(keep=False)]
# Out:
#        ID                                        assay  estimate  std.error  \
# 277  ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  0.381210   0.100870
# 159  ESS2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.861508   0.117751
#
#      statistic       p.value  n.studies method  \
# 277   3.779235  1.573109e-04          2     FE
# 159  -7.316366  2.547755e-13          3     FE
#
#                                               assay_ID p.adjusted  ...  \
# 277  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...   0.008815  ...
# 159  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0  ...
#
#      logFC_sawada  logFC_notaras  directionally_consistent  mean_logFC  \
# 277           NaN            NaN                      True    0.317700
# 159           NaN            NaN                      True   -0.792062
#
#           group logFC_sebastian  logFC_fernando  logFC_rao  logFC_shin  \
# 277    NRXN1del        0.117488        0.517913        NaN         NaN
# 159  22q11.2del             NaN             NaN   -0.93121   -0.482282
#
#      logFC_walsh
# 277          NaN
# 159    -0.962693
#
# [2 rows x 21 columns]

# %%
forest_dfs = pd.concat([dc_significant_all_rg_vim[dc_significant_all_rg_vim['ID'].duplicated(keep=False)],
              dc_significant_all_prg[dc_significant_all_prg['ID'].duplicated(keep=False)],
              dc_significant_all_dorsal[dc_significant_all_dorsal['ID'].duplicated(keep=False)]], axis=0)

# %%
# MANUAL COLORS
META_COLOR = "#000000"

STUDY_COLORS = {
    "logFC_sawada": "#E64B35",
    "logFC_notaras": "#4DBBD5",
    "logFC_sebastian": "#00A087",
    "logFC_fernando": "#3C5488",
    "logFC_rao": "#F39B7F",
    "logFC_shin": "#8491B4",
    "logFC_walsh": "#91D1C2",
}

# =====================================================
# SPACING CONTROL
# =====================================================

WITHIN_GENE_SPACING = 0.7
BETWEEN_GENE_SPACING = 1.5

# =====================================================
# Prepare data
# =====================================================

df = forest_dfs.copy()

logfc_cols = [c for c in df.columns if c.startswith("logFC_")]

df = df.sort_values(["assay", "group"])
df["label"] = df["group"]

# =====================================================
# Custom grouped y positions
# =====================================================

y_positions = []
current_y = 0
prev_gene = None

for _, row in df.iterrows():

    gene = row["assay"]

    if prev_gene is None:
        pass
    elif gene == prev_gene:
        current_y -= WITHIN_GENE_SPACING
    else:
        current_y -= BETWEEN_GENE_SPACING

    y_positions.append(current_y)
    prev_gene = gene

df["y"] = y_positions
df["y"] = df["y"] - df["y"].min()

fig, ax = plt.subplots(figsize=(19, 7))

# GRID CONTROL (EDIT THIS BLOCK)

ax.grid(
    True,
    axis='both',          
    color='#E5E5E5',
    linestyle=':',
    linewidth=0.7,
    alpha=0.8)

# PLOT

for _, row in df.iterrows():

    y = row["y"]

    est = row["estimate"]
    se = row["std.error"]

    ci_low = est - 1.96 * se
    ci_high = est + 1.96 * se

    # meta-analysis
    ax.errorbar(
        est,
        y,
        xerr=[[est - ci_low], [ci_high - est]],
        fmt='s',
        markersize=25,
        color=META_COLOR,
        ecolor=META_COLOR,
        elinewidth=2.5,
        capsize=4,
        markeredgecolor='black',
        zorder=4)

    # individual studies
    study_vals = row[logfc_cols].dropna()
    offsets = np.linspace(-0.15, 0.15, len(study_vals))

    for offset, (col, val) in zip(offsets, study_vals.items()):

        color = STUDY_COLORS.get(col, "#808080")

        ax.scatter(
            val,
            y + offset,
            s=678,
            color=color,
            alpha=0.9,
            edgecolor='black',
            linewidth=1.5,
            zorder=3)

# AXIS FORMATTING

ax.axvline(0, linestyle='--', color='black', alpha=0.5)

ax.set_yticks(df["y"])
ax.set_yticklabels(df["label"])
# # gene labels
# gene_midpoints = df.groupby("assay_ID")["y"].mean()

# for gene, y in gene_midpoints.items():
#     ax.text(
#         ax.get_xlim()[0] - 0.15,
#         y,
#         gene,
#         ha='right',
#         va='center',
#         fontsize=13
#     )

# LEGEND

legend_elements = [
    Line2D(
        [0], [0],
        marker='o',
        color='w',
        label=col.replace("logFC_", ""),
        markerfacecolor=color,
        markersize=9)
    for col, color in STUDY_COLORS.items()
]

legend_elements.insert(
    0,
    Line2D([0], [0],
        marker='s',
        color=META_COLOR,
        label='Meta-analysis',
        markersize=10,
        linewidth=2)
)

ax.legend(
    handles=legend_elements,
    title="Study",
    bbox_to_anchor=(1.02, 1),
    loc='upper left')

ax.tick_params(axis='x', labelsize=25)
ax.tick_params(axis='y', labelsize=30)
ax.set_xlabel("logFC", fontsize=30)
ax.set_title("Forest Plot with Study Contributions", fontsize=30)

sns.despine()
# plt.tight_layout()
plt.savefig("/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_forest_plot.svg", format="svg", bbox_inches="tight", dpi=300)
plt.show()

# %%
# MANUAL COLORS

META_COLOR = "#000000"

STUDY_COLORS = {
    "logFC_sawada": "#E64B35",
    "logFC_notaras": "#4DBBD5",
    "logFC_sebastian": "#00A087",
    "logFC_fernando": "#3C5488",
    "logFC_rao": "#F39B7F",
    "logFC_shin": "#8491B4",
    "logFC_walsh": "#91D1C2"}

# SPACING CONTROL (NOW ON X-AXIS)

WITHIN_GENE_SPACING = 0.7
BETWEEN_GENE_SPACING = 1.5

# PREPARE DATA

df = forest_dfs.copy()

logfc_cols = [c for c in df.columns if c.startswith("logFC_")]

df = df.sort_values(["assay", "group"])
df["label"] = df["group"]

# CUSTOM X POSITIONS (NOW GROUPED ON X-AXIS)

x_positions = []
current_x = 0
prev_gene = None

for _, row in df.iterrows():

    gene = row["assay"]

    if prev_gene is None:
        pass
    elif gene == prev_gene:
        current_x -= WITHIN_GENE_SPACING
    else:
        current_x -= BETWEEN_GENE_SPACING

    x_positions.append(current_x)
    prev_gene = gene

df["x"] = x_positions
df["x"] = df["x"] - df["x"].min()

# STYLE

sns.set_style("white")
sns.set_context("paper", font_scale=1.1)

fig, ax = plt.subplots(figsize=(7,7))

# GRID

ax.grid(
    True,
    axis='y',
    color='#EAEAEA',
    linestyle=':',
    linewidth=0.8,
    alpha=0.9
)

ax.xaxis.grid(False)
ax.set_axisbelow(True)

# DRAW PLOT (SWAPPED)

for _, row in df.iterrows():

    x = row["x"]

    est = row["estimate"]
    se = row["std.error"]

    ci_low = est - 1.96 * se
    ci_high = est + 1.96 * se

    # -------------------------------------------------
    # META-ANALYSIS (NOW VERTICAL = y-axis)
    # -------------------------------------------------
    ax.errorbar(
        x,
        est,
        yerr=[[est - ci_low], [ci_high - est]],
        fmt='s',
        markersize=20,
        color=META_COLOR,
        ecolor=META_COLOR,
        elinewidth=2.0,
        capsize=4,
        markeredgecolor='black',
        zorder=4
    )

    # STUDY POINTS
    study_vals = row[logfc_cols].dropna()
    offsets = np.linspace(-0.15, 0.15, len(study_vals))

    for offset, (col, val) in zip(offsets, study_vals.items()):

        color = STUDY_COLORS.get(col, "#808080")

        ax.scatter(
            x + offset,
            val,
            s=200,
            color=color,
            alpha=0.95,
            edgecolor='black',
            linewidth=1.2,
            zorder=5
        )

# AXIS FORMATTING

ax.axhline(0, linestyle=':', color='black', alpha=0.6)

ax.set_xticks(df["x"])
ax.set_xticklabels(df["label"])

ax.set_xlabel("Group")
ax.set_ylabel("logFC")

# # GENE LABELS (BOTTOM, NOT TOP)

# gene_midpoints = df.groupby("assay_ID")["x"].mean()

# y_bottom = ax.get_ylim()[0] - 1  # small padding below axis

# for gene, x in gene_midpoints.items():
#     ax.text(
#         x,
#         y_bottom,
#         gene,
#         ha='center',
#         va='top',
#         fontsize=12
#     )

# LEGEND
legend_elements = [
    Line2D(
        [0], [0],
        marker='o',
        color='w',
        label=col.replace("logFC_", ""),
        markerfacecolor=color,
        markeredgecolor='black',
        markersize=8
    )
    for col, color in STUDY_COLORS.items()
]

legend_elements.insert(
    0,
    Line2D(
        [0], [0],
        marker='s',
        color=META_COLOR,
        label='Meta-analysis',
        markersize=9,
        linewidth=2
    )
)

ax.legend(
    handles=legend_elements,
    title="Study",
    bbox_to_anchor=(1.02, 1),
    loc='upper left')

plt.setp(
    ax.get_xticklabels(),
    rotation=-30,
    ha='left',
    # rotation_mode='anchor'
)

ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=15)
ax.set_xlabel("")
ax.set_ylabel("logFC", fontsize=25)
ax.set_title("Forest Plot", fontsize=25)

# =====================================================
# FINAL CLEANUP
# =====================================================

sns.despine(top=True, right=True)
# plt.tight_layout()

plt.savefig(
    "/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_forest_plot_swapped.svg",
    format="svg",
    bbox_inches="tight",
    dpi=300)

plt.show()

# %%
wwc_forest_plots = pd.concat([dc_significant_idiopathic_df_logfc[dc_significant_idiopathic_df_logfc['ID'] == 'WWC2'],
                              dc_significant_22q11_df_logfc[dc_significant_22q11_df_logfc['ID'] == 'WWC2'],
                              dc_significant_nrxn1_df_logfc[dc_significant_nrxn1_df_logfc['ID'] == 'WWC2']], axis=0)

# %%
wwc_forest_plots
# Out:
#        ID                                        assay  estimate  std.error  \
# 334  WWC2                 Radial Glia SOX2+PAX6+FABP7+  0.716472   0.222280
# 563  WWC2                  Radial Glia SOX2+VIM+FABP7+  0.575885   0.147246
# 917  WWC2  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ -0.977343   0.133706
#
#      statistic       p.value  n.studies method  \
# 334   3.223286  1.267291e-03          2     FE
# 563   3.911047  9.189683e-05          3     FE
# 917  -7.309649  2.678409e-13          2     FE
#
#                                               assay_ID p.adjusted  \
# 334                Radial Glia SOX2+PAX6+FABP7+ | WWC2   0.009917
# 563                 Radial Glia SOX2+VIM+FABP7+ | WWC2   0.005575
# 917  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+ | ...        0.0
#
#      significant_fdr  logFC_sawada  logFC_notaras  directionally_consistent  \
# 334             True      0.441549       0.888741                      True
# 563             True           NaN            NaN                      True
# 917             True           NaN            NaN                      True
#
#      mean_logFC  logFC_rao  logFC_shin  logFC_walsh  logFC_sebastian  \
# 334    0.665145        NaN         NaN          NaN              NaN
# 563    0.570024   0.529589    0.604951     0.575531              NaN
# 917   -0.644792        NaN         NaN          NaN        -0.156282
#
#      logFC_fernando
# 334             NaN
# 563             NaN
# 917       -1.133303

# %%
# =====================================================
# FOREST PLOT FOR SINGLE GENE (WWC2)
# Assays = x-axis
# logFC = y-axis
# Meta-analysis estimate = square + CI
# Individual studies = colored circles
# =====================================================

# =====================================================
# MANUAL COLORS
# =====================================================

META_COLOR = "#000000"

STUDY_COLORS = {
    "logFC_sawada": "#E64B35",
    "logFC_notaras": "#4DBBD5",
    "logFC_sebastian": "#00A087",
    "logFC_fernando": "#3C5488",
    "logFC_rao": "#F39B7F",
    "logFC_shin": "#8491B4",
    "logFC_walsh": "#91D1C2",
}

# =====================================================
# SPACING
# =====================================================

COLUMN_SPACING = 0.8

# =====================================================
# PREPARE DATA
# =====================================================

df = wwc_forest_plots.copy()

# all study-level logFC columns
logfc_cols = [c for c in df.columns if c.startswith("logFC_")]

# sort assays
df = df.sort_values("estimate", ascending=False)

# assay labels
df["label"] = df["assay"]

# x positions
df["x"] = np.arange(len(df)) * COLUMN_SPACING

# =====================================================
# FIGURE
# =====================================================

fig, ax = plt.subplots(figsize=(7, 7))

# =====================================================
# GRID
# =====================================================

ax.grid(
    True,
    axis='both',
    color='#E5E5E5',
    linestyle=':',
    linewidth=0.7,
    alpha=0.8
)

# =====================================================
# PLOT
# =====================================================

for _, row in df.iterrows():

    x = row["x"]

    # meta-analysis estimate
    est = row["estimate"]
    se = row["std.error"]

    ci_low = est - 1.96 * se
    ci_high = est + 1.96 * se

    # ---------------------------------------------
    # META-ANALYSIS CI LINE
    # ---------------------------------------------

    ax.vlines(
        x=x,
        ymin=ci_low,
        ymax=ci_high,
        color=META_COLOR,
        linewidth=2.5,
        zorder=1
    )

    # CI caps
    ax.hlines(
        [ci_low, ci_high],
        x - 0.04,
        x + 0.04,
        color=META_COLOR,
        linewidth=2,
        zorder=1
    )

    # ---------------------------------------------
    # META-ANALYSIS SQUARE
    # ---------------------------------------------

    ax.scatter(
        x,
        est,
        marker='s',
        s=260,
        color=META_COLOR,
        edgecolor='black',
        linewidth=1.2,
        zorder=2
    )

    # ---------------------------------------------
    # INDIVIDUAL STUDIES
    # ---------------------------------------------

    study_vals = row[logfc_cols].dropna()

    offsets = np.linspace(-0.08, 0.08, len(study_vals))

    for offset, (col, val) in zip(offsets, study_vals.items()):

        color = STUDY_COLORS.get(col, "#808080")

        ax.scatter(
            x + offset,
            val,
            s=220,
            color=color,
            alpha=0.95,
            edgecolor='black',
            linewidth=1.3,
            zorder=5)

# =====================================================
# AXIS FORMATTING
# =====================================================

# zero line
ax.axhline(
    0,
    linestyle='--',
    color='black',
    alpha=0.5
)

# x labels
ax.set_xticks(df["x"])
ax.set_xticklabels(
    df["label"],
    rotation=25,
    ha='right'
)

# =====================================================
# LEGEND
# =====================================================

legend_elements = [
    Line2D(
        [0], [0],
        marker='o',
        color='w',
        label=col.replace("logFC_", ""),
        markerfacecolor=color,
        markeredgecolor='black',
        markersize=10
    )
    for col, color in STUDY_COLORS.items()
]

legend_elements.insert(
    0,
    Line2D(
        [0], [0],
        marker='s',
        color=META_COLOR,
        label='Meta-analysis',
        markersize=11,
        linewidth=2
    )
)

ax.legend(
    handles=legend_elements,
    title="Study",
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    fontsize=12,
    title_fontsize=13
)

# =====================================================
# FINAL FORMATTING
# =====================================================

sns.despine()

ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=15)

ax.set_xticks(df["x"])

ax.set_xticklabels(
    df["label"],
    rotation=-30,
    ha='left')

# tick sizes
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=15)
ax.set_ylabel("logFC", fontsize=25)
ax.set_title("WWC Forest Plot", fontsize=25)


plt.savefig(
    "/home/deepak/datasets/scz_meta_analysis/panels/Fig_4_WWC2_forest_plot_vertical.svg",
    format="svg",
    bbox_inches="tight",
    dpi=300)

plt.show()
