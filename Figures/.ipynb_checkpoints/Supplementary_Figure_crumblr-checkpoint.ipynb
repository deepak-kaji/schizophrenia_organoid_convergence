# %%
import gc
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
## Import CRumblr Files ##

bg = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/crumblr_broad_genotype.csv')
bgm = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/crumblr_broad_genotype_matrix.csv')

x22q11 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/dream_crumblr_22q11_dge_scz_results.csv')
nrnxn1 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/dream_crumblr_NRNXN1_dge_scz_results.csv')
x3q29 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/dream_crumblr_3q29_dge_scz_results.csv')
x15q13 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/dream_crumblr_15q13_dge_scz_results.csv')
idiopathic = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/dge_signatures/crumblr_outs/dream_crumblr_Idiopathic_dge_scz_results.csv')
