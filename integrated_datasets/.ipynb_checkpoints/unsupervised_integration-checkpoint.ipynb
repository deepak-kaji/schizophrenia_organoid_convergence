# %%
import os
import glob
import gc
import random

import numpy as np
import pandas as pd

from scipy.stats import median_abs_deviation, percentileofscore
import torch

import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc
import scvi

import pegasus as pg
from pegasusio import UnimodalData, MultimodalData

from tqdm import tqdm

# %matplotlib inline

sc.settings.n_jobs = 25

random.seed(0)
np.random.seed(0)
sc.settings.seed = 0

torch.set_float32_matmul_precision("high")
# Out:
# /home/deepak/pixi_envs/scanvi/.pixi/envs/default/lib/python3.11/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/deepak/pixi_envs/scanvi/.pixi/envs/default/lib/python3.11/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)

# %%
## Import All Datasets ##

# capture file paths
FILE_PATHS = glob.glob('/mnt/sdb/scz_meta_analysis_processed/studies/*/anndata_objs/*qc.h5ad')
FILE_PATHS = [file_path for file_path in FILE_PATHS if (('shin_thal' not in file_path) and ('shin_qc' not in file_path))]

# import anndata objects into list
ANNDATA_LIST = [sc.read_h5ad(file_path) for file_path in FILE_PATHS]

# reset ensembl ids as index 
for anndata_obj in ANNDATA_LIST:
    anndata_obj.var.index = anndata_obj.var['ensembl_gene_id']

# concatenate
adata = sc.concat(ANNDATA_LIST, axis='obs', join='outer')
adata.var.index.name = None

# recovery memory
del ANNDATA_LIST
del adata.obsm
del adata.uns
gc.collect()
# Out:
# 44082

# %%
## Log Normalization ##

# normalize 
scales_counts = sc.pp.normalize_total(adata, layer='raw_counts', target_sum=None, inplace=False)

# log1p transform
adata.layers["log1p_norm"] = sc.pp.log1p(scales_counts["X"], copy=True)

# set X as log1p normed counts
adata.X = adata.layers["log1p_norm"]

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
p1 = sns.histplot(adata.obs["n_counts"], bins=100, kde=False, ax=axes[0])
axes[0].set_title("Total counts")
p2 = sns.histplot(adata.layers["log1p_norm"].sum(1), bins=100, kde=False, ax=axes[1])
axes[1].set_title("Shifted logarithm")
plt.show()

# %%
## Map NCBI Gene Names w/Prasanth's File ##

# load prasanth's annotation file
prasanth_annot = pd.read_csv('/home/deepak/datasets/annotations/all_genes_EnsemblInfo_104.csv')

# merge prasanth's gene info into the var dataframe
adata.var['ensembl_gene_id'] = adata.var.index
adata.var = adata.var.merge(prasanth_annot, left_on='ensembl_gene_id', right_on='ensembl_gene_id', how='left')
adata.var.chromosome_name = adata.var.chromosome_name.astype('str')

# fix gene name that is NaN
adata.var.loc[adata.var['hgnc_symbol'].isna(),'hgnc_symbol'] = adata.var.loc[adata.var['hgnc_symbol'].isna(),'ensembl_gene_id']

#reset the index as the hgnc_symbol
adata.var.index = adata.var['hgnc_symbol']
adata.var.index.name = None

#some ensembls map to same hgnc so we make them unique
adata.var_names_make_unique(join='#')

gc.collect()
# Out:
# /tmp/ipykernel_461101/2840611834.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   prasanth_annot = pd.read_csv('/home/deepak/datasets/annotations/all_genes_EnsemblInfo_104.csv')
# 187

# %%
## Set Up QC Metrics ##

# filter on robust genes
pg.identify_robust_genes(adata, percent_cells=0.05)
adata = adata[:,adata.var['robust']].copy()
gc.collect()

# mitochondrial genes, "MT-" for human, "Mt-" for mouse
adata.var["mt"] = adata.var_names.str.startswith("MT-")
# ribosomal genes
adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))
# hemoglobin genes
adata.var["hb"] = adata.var_names.str.contains("^HB[^(P)]")

# add protein_coding genes
adata.var['protein_coding'] = adata.var['gene_biotype'].apply(lambda x: True if 'protein_coding' == x else False)
adata.var['protein_coding'] = adata.var['protein_coding'].astype('bool')

# define mitocarta_genes
mitocarta_df = pd.read_csv('/home/deepak/datasets/annotations/Human.MitoCarta3.0.csv')
adata.var['mitocarta'] = [True if x in list(mitocarta_df['Symbol']) else False for x in adata.var.index]

# define robust_protein_coding genes (exclude ribosomal (RPL,RPS), mitochondrial, or mitocarta genes
adata.var['robust_protein_coding'] = adata.var['robust'] & adata.var['protein_coding']
adata.var.loc[adata.var.ribo, 'robust_protein_coding'] = False
adata.var.loc[adata.var.mt, 'robust_protein_coding'] = False
adata.var.loc[adata.var.mitocarta, 'robust_protein_coding'] = False

# define robust_protein_coding_autosome genes (exclude ribosomal (RPL,RPS), mitochondrial, or mitocarta genes
adata.var['autosome'] = adata.var.chromosome_name.isin([str(i) for i in range(1,23)])
adata.var['robust_protein_coding_autosome'] = adata.var['robust_protein_coding'] & adata.var['autosome'] 
pg.qc_metrics(UnimodalData(adata), mito_prefix='MT-')
# Out:
# 2026-02-27 22:30:55,359 - pegasus.tools.preprocessing - INFO - After filtration, 23954/23959 genes are kept. Among 23954 genes, 19264 genes are robust.
# 2026-02-27 22:30:55,359 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 60.30s.

# %%
## Prepare Variables for Unsupervised Integration ##

# Use Imputed Sex #

adata.obs['Sex'] = adata.obs['Sex'].replace({'M': 'Male', 'F': 'Female'}).astype('str')
adata.obs.loc[adata.obs['Sex'] == 'nan', 'Sex'] = adata.obs['Imputed_Sex'].str.replace('Imputed ', '')

# Make Day Float #
adata.obs['Day'] = adata.obs['Day'].astype('float')

# Find symmetry between genotypes #
adata.obs['Genotype'] = adata.obs['Genotype'].str.replace('22q11DS', '22q11.2DS').str.replace('22q11.2 deletion', '22q11.2DS')
adata.obs['Broad_Genotype'] = adata.obs['Genotype']
adata.obs['Broad_Genotype'] = adata.obs['Broad_Genotype'].str.replace("3'-NRXN1-Deletion", "NRXN1del")
adata.obs['Broad_Genotype'] = adata.obs['Broad_Genotype'].str.replace("5'-NRXN1-Deletion", "NRXN1del")

# Prep Covariates for scVI #
adata.obs["Donor"] = adata.obs["Donor"].astype(str).astype("category")
adata.obs["Manuscript"] = adata.obs["Manuscript"].astype(str).astype("category")
adata.obs["Sex"] = adata.obs["Sex"].astype(str).astype("category")

# calc score requires a float downcast for some reason
adata.X = adata.X.astype('float32')
pg.calc_signature_score(UnimodalData(adata), 'cell_cycle_human')
# Out:
# 2026-02-27 22:32:08,763 - pegasus.tools.utils - INFO - Loaded signatures from GMT file /home/deepak/pixi_envs/scanvi/.pixi/envs/default/lib/python3.11/site-packages/pegasus/data_files/cell_cycle_human.gmt.
# 2026-02-27 22:32:08,766 - pegasus.tools.signature_score - INFO - Signature G1/S: 43 out of 43 genes are used in signature score calculation.
# 2026-02-27 22:32:08,766 - pegasus.tools.signature_score - WARNING - Signature key G1/S exists in data.obs, the existing content will be overwritten!
# 2026-02-27 22:32:13,015 - pegasus.tools.signature_score - INFO - Signature G2/M: 54 out of 54 genes are used in signature score calculation.
# 2026-02-27 22:32:13,016 - pegasus.tools.signature_score - WARNING - Signature key G2/M exists in data.obs, the existing content will be overwritten!
# 2026-02-27 22:32:17,817 - pegasus.tools.signature_score - INFO - Function 'calc_signature_score' finished in 18.30s.

# %%
## Batched HVG Selection ##

# calculate HVGs on a protein_coding_autosomal only gene list
adata_hvg = adata[:,adata.var.robust_protein_coding_autosome].copy()
sc.pp.highly_variable_genes(adata_hvg, layer='log1p_norm', n_top_genes=3000, inplace=True, subset=True, batch_key='Manuscript')

# apply that HVG list to your original anndata object
adata.var['highly_variable_features'] = False
adata.var['highly_variable_features'] = adata.var.index.isin(adata_hvg.var.index)

# %%
## Setup Model & Begin Training ##

scvi.model.SCVI.setup_anndata(adata_hvg, layer="raw_counts",                        
                              categorical_covariate_keys=["Donor", "Manuscript", "Sex"],
                              continuous_covariate_keys=["n_counts", "percent_mito"])

model = scvi.model.SCVI(adata_hvg, n_hidden=1024, n_latent=30, n_layers=4)

model.train(max_epochs=30, train_size=0.9, early_stopping=True, batch_size=2048)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Training:   0%|          | 0/30 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=30` reached.

# %%
## Exaamine Train/Val Loss ELBO and Reconstruction/Kullback-Leiber Val Loss

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ---- Left plot: Train vs Validation ELBO ----
axes[0].plot(model.history["elbo_train"], label="Train ELBO")
axes[0].plot(model.history["elbo_validation"], label="Validation ELBO")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("ELBO")
axes[0].set_ylim(0, 1000)
axes[0].set_title("Train vs Validation ELBO")
axes[0].legend()

# ---- Right plot: Reconstruction vs KL ----
axes[1].plot(model.history["reconstruction_loss_validation"], label="Reconstruction (val)")
axes[1].plot(model.history["kl_local_validation"], label="KL (val)")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss Component")
axes[1].set_ylim(0, 1000)
axes[1].set_title("Reconstruction vs KL (Validation)")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
## Save and Loading ##

model_dir = os.path.join("/mnt/sdb/scz_meta_analysis_processed/models", "scvi_model")
model.save(model_dir, overwrite=True)

model = scvi.model.SCVI.load(model_dir, adata=adata_hvg)
# Out:
# INFO     File /mnt/sdb/scz_meta_analysis_processed/models/scvi_model/model.pt already downloaded

# %%
## Save Model Representation ##

adata_hvg.obsm["X_scVI"] = model.get_latent_representation()

adata_hvg.layers["scvi_normalized"] = model.get_normalized_expression(library_size=10e4)

pg.pca(adata_hvg, n_components=30)
pg.regress_out(adata_hvg, ['n_counts', 'percent_mito'])
# Out:
# 2026-02-27 23:43:23,233 - pegasus.tools.preprocessing - INFO - Function 'pca' finished in 837.80s.
# 2026-02-27 23:43:25,080 - pegasus.tools.preprocessing - INFO - Function 'regress_out' finished in 1.85s.
# 'pca_regressed'

# %%
adata_hvg.shape
# Out:
# (1574165, 3000)

# %%
adata_hvg = UnimodalData(adata_hvg)

# %%
## Calculate UMAP Without Batch Correction ##

pg.neighbors(adata_hvg, rep='pca_regressed', use_cache=False, dist='l2', K=100, n_comps=30)
pg.umap(adata_hvg, rep='pca_regressed', n_neighbors=15, rep_ncomps=30)
adata_hvg.obsm['X_umap_unharmonized'] = adata_hvg.obsm['X_umap']
# Out:
# 2026-02-27 23:49:09,961 - pegasus.tools.nearest_neighbors - INFO - Function 'get_neighbors' finished in 193.71s.
# 2026-02-27 23:49:33,668 - pegasus.tools.nearest_neighbors - INFO - Function 'calculate_affinity_matrix' finished in 23.71s.
# 2026-02-27 23:49:33,668 - pegasus.tools.nearest_neighbors - INFO - Found cached kNN results, no calculation is required.
# 2026-02-27 23:49:33,668 - pegasus.tools.nearest_neighbors - INFO - Function 'get_neighbors' finished in 0.00s.
# UMAP(min_dist=0.5, n_jobs=1, precomputed_knn=(array([[      0, 170792, 170916, ..., 107393, 41, 170857],
#        [      1, 107405, 28, ..., 257834, 170849, 257914],
#        [      2, 324696, 40729, ..., 40096, 170814, 135821],
#        ...,
#        [1574162, 661039, 38867, ..., 1402722, 1443511, 218685],
#        [1574163, 1339232, 690597, ..., 1308055, 1054604, 1216034],
#        [1574164, 1308077, 1574074, ..., 1013537, 985082, 1192587]]), array([[0.       , 3.5716705, 3.7167928, ..., 4.4191146, 4.564765 ,
# ...

# %%
## Calculate UMAP With Harmony Only Batch Correction ##

pg.run_harmony(adata_hvg, batch=['Donor'], rep='pca_regressed', max_iter_harmony=20, n_comps=30)
pg.neighbors(adata_hvg, rep='pca_regressed_harmony', use_cache=False, dist='l2', K=100, n_comps=30)
pg.umap(adata_hvg, rep='pca_regressed_harmony', n_neighbors=15, rep_ncomps=30)
adata_hvg.obsm['X_umap_harmonized'] = adata_hvg.obsm['X_umap']
# Out:
# 2026-02-28 00:38:50,913 - pegasus.tools.batch_correction - INFO - Start integration using Harmony.
# /home/deepak/pixi_envs/scanvi/.pixi/envs/default/lib/python3.11/site-packages/pegasus/tools/utils.py:185: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(data.obs[bat]):
# 	Initialization is completed.
# 	Completed 1 / 20 iteration(s).
# 	Completed 2 / 20 iteration(s).
# 	Completed 3 / 20 iteration(s).
# 	Completed 4 / 20 iteration(s).
# 	Completed 5 / 20 iteration(s).
# Reach convergence after 5 iteration(s).
# 2026-02-28 00:47:38,424 - pegasus.tools.batch_correction - INFO - Function 'run_harmony' finished in 527.52s.
# 2026-02-28 00:52:25,345 - pegasus.tools.nearest_neighbors - INFO - Function 'get_neighbors' finished in 286.92s.
# 2026-02-28 00:52:49,507 - pegasus.tools.nearest_neighbors - INFO - Function 'calculate_affinity_matrix' finished in 24.16s.
# ...

# %%
## Calculate UMAP With scVI Correction ##

# use scVI latent space for UMAP generation
pg.neighbors(adata_hvg, rep='scVI', use_cache=False, dist='l2', K=50, n_comps=30)
pg.umap(adata_hvg, rep='scVI', n_neighbors=15, rep_ncomps=30)
adata_hvg.obsm['X_umap_scVI'] = adata_hvg.obsm['X_umap']
# Out:
# 2026-02-28 01:46:42,988 - pegasus.tools.nearest_neighbors - INFO - Function 'get_neighbors' finished in 258.21s.
# 2026-02-28 01:47:00,092 - pegasus.tools.nearest_neighbors - INFO - Function 'calculate_affinity_matrix' finished in 17.10s.
# 2026-02-28 01:47:00,093 - pegasus.tools.nearest_neighbors - INFO - Found cached kNN results, no calculation is required.
# 2026-02-28 01:47:00,093 - pegasus.tools.nearest_neighbors - INFO - Function 'get_neighbors' finished in 0.00s.
# UMAP(min_dist=0.5, n_jobs=1, precomputed_knn=(array([[      0, 76796, 304742, ..., 108403, 170916, 327974],
#        [      1, 673177, 707089, ..., 471600, 222437, 360675],
#        [      2, 324696, 301437, ..., 39843, 136474, 1186561],
#        ...,
#        [1574162, 736525, 661055, ..., 13760, 301313, 661218],
#        [1574163, 1402007, 1053473, ..., 1018591, 1346599, 1054349],
# ...

# %%
# Convert Back To Anndata #

adata_hvg = adata_hvg.to_anndata()

# %%
# Quick Comparison of Manuscripts #

# Create a figure with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot each embedding on its own axis
sc.pl.embedding(adata_hvg, basis='X_umap_unharmonized', color='Manuscript', ax=axes[0], show=False)

sc.pl.embedding(adata_hvg, basis='X_umap_harmonized', color='Manuscript', ax=axes[1], show=False)

sc.pl.embedding(adata_hvg, basis='X_umap_scVI', color='Manuscript', ax=axes[2], show=False)

plt.tight_layout()
plt.show()

# %%
# Quick Comparison of Donor Distributions #

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, basis in zip(axes, ['X_umap_unharmonized', 'X_umap_harmonized', 'X_umap_scVI']):
    sc.pl.embedding(adata_hvg, basis=basis, color='Donor', ax=ax, show=False, legend_loc=None)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3, frameon=False)

plt.tight_layout()
plt.show()

# %%
# Quick Comparison of Days #

# Create a figure with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot each embedding on its own axis
sc.pl.embedding(adata_hvg, basis='X_umap_unharmonized', color='Day', ax=axes[0], show=False)

sc.pl.embedding(adata_hvg, basis='X_umap_harmonized', color='Day', ax=axes[1], show=False)

sc.pl.embedding(adata_hvg, basis='X_umap_scVI', color='Day', ax=axes[2], show=False)

plt.tight_layout()
plt.show()

# %%
sc.pl.embedding(adata_hvg, basis='X_umap_scVI', color=['SOX2', 'VIM', 'GFAP', 'AQP4',
                                                       'HOPX', 'NEUROD6', 'DLX1', 'DLX2', 'DLX5', 
                                                       'DLX6', 'SST', 'SOX10', 'OLIG1', 'OLIG2'], ncols=1)

# %%
## Cluster To Confirm Clusters Reflect Biology ##

adata_hvg = UnimodalData(adata_hvg)

pg.leiden(adata_hvg, rep='scVI', resolution=0.3, class_label='class')

adata_hvg = adata_hvg.to_anndata()
# Out:
# 2026-02-28 02:37:27,591 - pegasus.tools.graph_operations - INFO - Function 'construct_graph' finished in 16.28s.
# 2026-02-28 03:02:00,857 - pegasus.tools.clustering - INFO - Leiden clustering is done. Get 8 clusters.
# 2026-02-28 03:02:01,197 - pegasus.tools.clustering - INFO - Function 'leiden' finished in 1489.89s.

# %%
sc.pl.embedding(adata_hvg, basis='X_umap_scVI', color=['class', 'SOX2', 'NEUROD6', 'DLX5', 'OLIG2'], ncols=1)

# %%
## Differential Gene Expression ##

sc.tl.rank_genes_groups(adata_hvg, 'class', method='wilcoxon')

df = sc.get.rank_genes_groups_df(adata_hvg, group=None)

df_lim = df[((df['logfoldchanges'] > 1) & (df['pvals_adj'] < 0.05))].sort_values(by=['group', 'scores'], ascending=False)

# %%
## Examine Clusters By Gene Expression ##

df_lim.groupby('group').head(40)[240:250]
# Out:
# /tmp/ipykernel_461101/1733726075.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_lim.groupby('group').head(40)[240:250]
#      group    names      scores  logfoldchanges  pvals  pvals_adj
# 3004     2    STMN2  485.242249        2.339325    0.0        0.0
# 3005     2     SYT1  451.061432        2.202155    0.0        0.0
# 3006     2     RTN1  435.226044        2.125490    0.0        0.0
# 3007     2  NEUROD2  425.532532        5.389763    0.0        0.0
# 3008     2    SOX11  419.482819        1.851398    0.0        0.0
# 3009     2   TMSB10  391.732971        1.163010    0.0        0.0
# 3010     2    GAP43  390.477844        1.819542    0.0        0.0
# 3011     2    KIF5C  384.510498        1.633227    0.0        0.0
# ...

# %%
## Reasonable Clusters ##

## 8 - PTPRZ1 SOX2 VIM TTYH1 - astrocytes 
## 7 - VIM SOX2 IGFBP2 HES1 ID4 - radial glia
## 6 - HES6 VIM IGFBP2 NR2F1 - radial glia
## 5 - COL3A1 COL3A1 COL1A2 S100A10 - fibroblast / astrocyte
## 4 - DLX5 SOX11 TCF4 SOX6 SOX11 - interneuron
## 3 - NEUROD2 NEUROD6 MAPT GRIA2 - EN
## 2 - VIM TOP2A TUBA1B - a cycling progenitor (see whats its closest to) probably RG since VIM. EOMES contained in here.
## 1 - MAPT GAP43 STMN2 STMN4 - some sort of undefined neuron

# %%
## Save HVG adata and Full adata ##

adata.obs['Donor'] = adata.obs['Donor'].astype('str')
adata.obs['Age'] = adata.obs['Age'].astype('str')
adata.write_h5ad('/mnt/sdb/scz_meta_analysis_processed/anndata_objs/integrated_adata.h5ad')

adata_hvg.obs['Donor'] = adata_hvg.obs['Donor'].astype('str')
adata_hvg.obs['Age'] = adata_hvg.obs['Age'].astype('str')
adata_hvg.write_h5ad('/mnt/sdb/scz_meta_analysis_processed/anndata_objs/integrated_adata_hvg.h5ad')
