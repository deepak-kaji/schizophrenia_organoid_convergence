# %%
import os
import glob
import gc

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import anndata as ad
import scanpy as sc

# pySCENIC imports

from dask.distributed import Client
from dask.diagnostics import ProgressBar

from arboreto.algo import grnboost2

from pyscenic.utils import modules_from_adjacencies, load_motifs
from pyscenic.prune import prune2df, df2regulons
from pyscenic.aucell import aucell
from pyscenic.rss import regulon_specificity_scores

import networkx as nx
import community as community_louvain
from collections import defaultdict

from ctxcore.rnkdb import FeatherRankingDatabase as RankingDatabase

# %matplotlib inline
# Out:
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
# DEFINE PATHS ##

SCENIC_PATH = '/mnt/sdb/scz_meta_analysis_processed/scenic_files/'
FEATHER_RANKINGS_FILE = 'hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather'
DATABASES_GLOB = os.path.join(SCENIC_PATH, FEATHER_RANKINGS_FILE)
MOTIF_ANNOTATIONS_FNAME = os.path.join(SCENIC_PATH, 'motifs-v10nr_clust-nr.hgnc-m0.001-o0.0.tbl')

# %%
## SAVE LOAD ##

# Organoids #
ORGANOIDS_PATH = '/mnt/sdb/scz_meta_analysis_processed/anndata_objs'
organoids_filename = 'integrated_adata_annotated_w_celltypist_scanvi.h5ad'
scz_adata = sc.read_h5ad(os.path.join(ORGANOIDS_PATH, organoids_filename))

# TF List ##
TF_LIST = "/home/deepak/datasets/developing_hippocampus/roussos_organoid_snrnaseq/scenic_files/allTFs_hg38.txt"
tf_list = pd.read_csv(TF_LIST, header=None)[0].tolist()

# %%
# Work With Raw Counts #

scz_adata.X = scz_adata.layers['raw_counts']

genotype_order = ['Control', 'Idiopathic_Schizophrenia', '3q29del', '15q13.3del', '22q11.2del', 'NRXN1del']

celltype_order = ['Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+',
                   'Radial Glia SOX2+VIM+FABP7+', 'Proliferative Radial Glia SOX2+HES6+TOP2A+',
                   'Hindbrain Neurons NR2F2+PBX3+LHX1+',  'Radial Glia SOX2+PAX6+FABP7+', 
                  'Mesenchymal-like cells VIM+VCAN+SPARC+', 'Mixed Neurons FGF12+GRIN2B+CAMK2B+', 
                  'GABAergic GAD1+GAD2+CALB2+', 'Stressed Glia FTL+B2M+GLUL+']

scz_adata.obs['Genotype_Celltype'] = (scz_adata.obs['Broad_Genotype'].astype('str') + '_' +
                                      scz_adata.obs['subclass_annotations_markers'].astype('str'))

split = scz_adata.obs['Genotype_Celltype'].str.split('_', n=1, expand=True)
scz_adata.obs['Genotype'] = pd.Categorical(split[0], genotype_order, True)
scz_adata.obs['CellType'] = pd.Categorical(split[1], celltype_order, True)
scz_adata.obs['Donor_Sample'] = scz_adata.obs['Donor'].astype('str') + '_' + scz_adata.obs['Sample Name'].astype('str')

# %%
## Filter Adata ##

# filter on HVGs but spare TFs #
sc.pp.highly_variable_genes(scz_adata, layer='log1p_norm', n_top_genes=10000, subset=False, inplace=True, batch_key='Manuscript')

min_cells = max(10, int(0.01 * scz_adata.n_obs))
expressed_TFs = scz_adata.var_names[scz_adata.var_names.isin(tf_list) & 
                ((scz_adata.X > 0).sum(axis=0).A1 >= min_cells)]

# Union of HVGs and expressed TFs
gene_filter = scz_adata.var['highly_variable_features'] | scz_adata.var_names.isin(expressed_TFs)
scz_adata = scz_adata[:, gene_filter].copy()

# Convert to genes x cells DataFrame (pySCENIC expects this shape)
counts_matrix_not_pb = pd.DataFrame(
    scz_adata.X.T.toarray() if not isinstance(scz_adata.X, np.ndarray) else scz_adata.X.T,
    index=scz_adata.var['hgnc_symbol'],
    columns=scz_adata.obs_names)

counts_matrix = counts_matrix_not_pb.groupby(scz_adata.obs['Donor_Sample'], axis=1).agg(np.nanmean)
# Out:
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:508: FutureWarning: The provided callable <function nanmean at 0x7f85801cf130> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df = df.groupby("gene").agg(
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:508: FutureWarning: The provided callable <function nanmean at 0x7f85801cf130> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df = df.groupby("gene").agg(
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:508: FutureWarning: The provided callable <function nansum at 0x7f85801cea70> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df = df.groupby("gene").agg(
# /tmp/ipykernel_134569/3186565345.py:23: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   counts_matrix = counts_matrix_not_pb.groupby(scz_adata.obs['Donor_Sample'], axis=1).agg(np.nanmean)
# /tmp/ipykernel_134569/3186565345.py:23: FutureWarning: The provided callable <function nanmean at 0x7f85801cf130> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   counts_matrix = counts_matrix_not_pb.groupby(scz_adata.obs['Donor_Sample'], axis=1).agg(np.nanmean)

# %%
counts_matrix.index.isin(tf_list).sum()
# Out:
# 1453

# %%
## RUN GRNBOOST2

# 1) Make sure your expression is cells × genes
expr = counts_matrix.T  # cells x genes
# ensure columns are strings
expr.columns = expr.columns.astype(str)

# 2) Start a local in-process client (no separate worker processes)
client = Client(
    n_workers=1,
    threads_per_worker=24,   # or 24/32 if you have lots of cores
    processes=False,         # <<< critical: use threads, not processes
    dashboard_address=None)

print(client)  # sanity check

# 3) Run GRNBoost2 with the local threaded client
adjacencies = grnboost2(
    expression_data=expr,
    gene_names=expr.columns,   # make the mapping explicit
    tf_names=list(expr.columns[expr.columns.isin(tf_list)]),
    client_or_address=client,
    verbose=True)
# Out:
# <Client: 'inproc://192.168.4.23/134569/1' processes=1 threads=24, memory=503.56 GiB>
# preparing dask client
# parsing input
# creating dask graph
# 1 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
# 2026-04-18 11:27:36,274 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 352.51 GiB -- Worker memory limit: 503.56 GiB

# %%
len(tf_list)
# Out:
# 1892

# %%
adjacencies.to_csv("/mnt/sdb/scz_meta_analysis_processed/scenic_files/grnboost2_adjacencies.tsv", index=False)

# %%
DATABASES_GLOB
# Out:
# '/mnt/sdb/scz_meta_analysis_processed/scenic_files/hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings.feather'

# %%
## STEP 2-3: Regulon prediction aka cisTarget from CLI ##

# Build Modules #

modules = list(modules_from_adjacencies(adjacencies, expr))

## Makes Rankings File Into FeatherRankignsDatabase Object ##

db_fnames = glob.glob(DATABASES_GLOB)

def name(fname):
    return os.path.splitext(os.path.basename(fname))[0]
    
dbs = [RankingDatabase(fname=fname, name=name(fname)) for fname in db_fnames]

## Calculate a list of enriched motifs and the corresponding target genes for all modules ##

with ProgressBar():
    df = prune2df(dbs, modules, MOTIF_ANNOTATIONS_FNAME)

## Create regulons from this table of enriched motifs.

regulons = df2regulons(df)
# Out:
# 2026-04-18 11:21:34,244 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2026-04-18 11:21:34,307 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [False].
#
# 2026-04-18 11:21:36,262 - pyscenic.utils - INFO - Creating modules.
# [                                        ] | 0% Completed | 129.81 ms
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/dask/base.py:1368: UserWarning: Running on a single-machine scheduler when a distributed client is active might lead to unexpected results.
#   warnings.warn(
# [                                        ] | 0% Completed | 5.83 s ms
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 6.23 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 6.53 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 6.74 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 7.08 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 7.48 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 7.78 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 8.11 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 8.41 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 8.74 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 9.14 s
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/ctxcore/__init__.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [                                        ] | 0% Completed | 15.28 s
# 2026-04-18 11:22:01,195 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for MELK could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 18.81 s
# 2026-04-18 11:22:04,735 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for NAP1L1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2026-04-18 11:22:04,745 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF730 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 19.51 s
# 2026-04-18 11:22:05,377 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF66 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 27.87 s
# 2026-04-18 11:22:13,783 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for PARP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 31.09 s
# 2026-04-18 11:22:16,973 - pyscenic.transform - WARNING - Less than 80% of the genes in SIN3A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 40.46 s
# 2026-04-18 11:22:26,369 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RNASEH2C could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 42.77 s
# 2026-04-18 11:22:28,673 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ATOH8 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 44.18 s
# 2026-04-18 11:22:30,127 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SIN3A could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 44.99 s
# 2026-04-18 11:22:30,869 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for BRCA1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [                                        ] | 0% Completed | 47.20 s
# 2026-04-18 11:22:33,135 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CENPB could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [##                                      ] | 5% Completed | 61.80 s
# 2026-04-18 11:22:47,674 - pyscenic.transform - WARNING - Less than 80% of the genes in HIRIP3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [##                                      ] | 5% Completed | 74.39 s
# 2026-04-18 11:23:00,324 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for HMGB3 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [##                                      ] | 5% Completed | 79.43 s
# 2026-04-18 11:23:05,342 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF66 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [################                        ] | 40% Completed | 83.65 s
# 2026-04-18 11:23:09,602 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for LEF1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [####################################    ] | 91% Completed | 91.61 s
# 2026-04-18 11:23:17,525 - pyscenic.transform - WARNING - Less than 80% of the genes in PARP1 could be mapped to hg38_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
# [########################################] | 100% Completed | 93.22 s
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []

# %%
## Visualize Regulons ##

auc_mtx = aucell(counts_matrix_not_pb.T, regulons, num_workers=8)

# ensure alignment
auc_mtx = auc_mtx.loc[scz_adata.obs_names]

# calculate rss specificity score
rss = regulon_specificity_scores(auc_mtx, scz_adata.obs['Genotype_Celltype'])

# %%
## Make Disease Specific AUC MTXs ##
rss_22q11 = auc_mtx.copy()
rss_nrxn1 = auc_mtx.copy()
rss_idiopathic = auc_mtx.copy()

## 22q11 ##
rss_22q11['Broad_Genotype'] = scz_adata.obs['Broad_Genotype']
rss_22q11['Manuscript'] = scz_adata.obs['Manuscript']
rss_22q11 = rss_22q11[(rss_22q11['Manuscript'].str.contains('Rao|Shin|Walsh') & ~(rss_22q11['Broad_Genotype'].str.contains('15q13')))]
del rss_22q11['Manuscript']
del rss_22q11['Broad_Genotype']

## NRXN1 ##
rss_nrxn1['Manuscript'] = scz_adata.obs['Manuscript']
rss_nrxn1 = rss_nrxn1[rss_nrxn1['Manuscript'].str.contains('Fernando|Sebastian')]
del rss_nrxn1['Manuscript']

## Idiopathic ##
rss_idiopathic['Manuscript'] = scz_adata.obs['Manuscript']
rss_idiopathic = rss_idiopathic[rss_idiopathic['Manuscript'].str.contains('Notaras|Sawada')]
del rss_idiopathic['Manuscript']

## AUC MTX ##
auc_mtx_idiopathic = auc_mtx.loc[rss_idiopathic.index]
auc_mtx_22q11 = auc_mtx.loc[rss_22q11.index]
auc_mtx_nrxn1 = auc_mtx.loc[rss_nrxn1.index]

# %%
sns.clustermap(auc_mtx.groupby(scz_adata.obs['subclass_annotations_markers']).mean())
# Out:
# /tmp/ipykernel_134569/326546180.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.clustermap(auc_mtx.groupby(scz_adata.obs['subclass_annotations_markers']).mean())

# %%
sns.clustermap(auc_mtx.groupby(scz_adata.obs['subtype_cluster_annotations']).mean())
# Out:
# /tmp/ipykernel_134569/697381507.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.clustermap(auc_mtx.groupby(scz_adata.obs['subtype_cluster_annotations']).mean())
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/deepak/pixi_envs/scenic/.pixi/envs/default/lib/python3.10/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
regulon_sizes = [len(r.genes) for r in regulons]
plt.hist(regulon_sizes, bins=50)
plt.xlabel("Number of target genes")
plt.ylabel("Number of regulons")
# Out:
# Text(0, 0.5, 'Number of regulons')

# %%
list([len(r.genes) for r in regulons])
# Out:
# [4,
#  40,
#  25,
#  8,
#  10,
#  23,
#  45,
#  53,
#  44,
#  16,
#  57,
#  84,
#  47,
#  35,
#  11,
#  32,
#  9,
#  38,
#  14,
#  18,
#  25,
#  24,
#  17,
#  9,
#  36,
#  52,
#  9,
#  20,
#  8,
#  3,
#  47,
#  46,
#  17,
#  34,
#  62,
#  14,
#  15,
#  17,
#  28,
#  18,
#  46,
#  42,
#  17,
#  19,
#  11,
#  43,
#  27,
#  20,
#  80,
#  53,
#  24,
#  7,
#  19,
#  6,
#  6,
#  43,
#  28,
#  11,
#  54,
#  14,
#  46,
#  63,
#  32,
#  26,
#  7,
#  14,
#  7,
#  9,
#  31,
#  10,
#  10,
#  14,
#  10,
#  13,
#  38,
#  28,
#  7,
#  38,
#  7,
#  28,
#  22,
#  4,
#  6,
#  24,
#  20,
#  61,
#  22,
#  23,
#  17,
#  24,
#  11,
#  60,
#  14,
#  9,
#  14,
#  20,
#  12,
#  38,
#  31,
#  11,
#  24,
#  5,
#  22,
#  31,
#  9,
#  22,
#  11,
#  21,
#  3,
#  12,
#  29,
#  42,
#  18,
#  48,
#  5,
#  91,
#  8,
#  40,
#  32,
#  36,
#  5,
#  20,
#  19,
#  26,
#  21,
#  31,
#  46,
#  10,
#  15,
#  9,
#  19,
#  10,
#  7,
#  4,
#  11,
#  11,
#  29,
#  18,
#  42,
#  18,
#  35,
#  9,
#  20,
#  26,
#  19,
#  16,
#  5,
#  40,
#  23,
#  8,
#  6,
#  14,
#  26,
#  34,
#  6,
#  9,
#  18,
#  31,
#  17,
#  13,
#  29,
#  5,
#  12,
#  40,
#  5,
#  20,
#  10,
#  16,
#  7,
#  26,
#  18,
#  8,
#  42,
#  11,
#  19,
#  20,
#  8,
#  61,
#  31,
#  24,
#  6,
#  10,
#  29,
#  13,
#  24,
#  33,
#  29,
#  13,
#  26,
#  24,
#  42,
#  3,
#  50,
#  18,
#  9,
#  14,
#  10,
#  27,
#  20,
#  20,
#  8,
#  10,
#  64,
#  23,
#  17,
#  10,
#  6,
#  14,
#  8,
#  26,
#  17,
#  6,
#  38,
#  38,
#  9,
#  2,
#  48,
#  25,
#  6,
#  8,
#  4,
#  9,
#  3,
#  6,
#  5,
#  5,
#  9,
#  22,
#  9,
#  14,
#  15,
#  8,
#  32,
#  3,
#  10,
#  18,
#  9,
#  6,
#  19,
#  14,
#  18,
#  14,
#  8,
#  15,
#  9,
#  6,
#  6,
#  7,
#  17,
#  20,
#  9,
#  4,
#  7,
#  13,
#  11,
#  34,
#  5,
#  11,
#  32,
#  34,
#  7,
#  6,
#  6,
#  22,
#  7,
#  19,
#  22,
#  19,
#  5]

# %%
for r in regulons:
    print(r.name, len(r.genes), r.transcription_factor, r.context)
# Out:
# AR(+) 4 AR frozenset({'activating', 'cisbp__M00821.png'})
# ARID3A(+) 40 ARID3A frozenset({'tfdimers__MD00032.png', 'activating'})
# ATF2(+) 25 ATF2 frozenset({'activating', 'tfdimers__MD00437.png'})
# ATF3(+) 8 ATF3 frozenset({'activating', 'metacluster_111.4.png'})
# ATF4(+) 10 ATF4 frozenset({'activating', 'taipale_tf_pairs__ATF4_TEF_RNMTGATGCAATN_CAP.png'})
# BACH1(+) 23 BACH1 frozenset({'activating', 'tfdimers__MD00098.png'})
# BACH2(+) 45 BACH2 frozenset({'tfdimers__MD00332.png', 'activating'})
# BCL11A(+) 53 BCL11A frozenset({'activating', 'metacluster_167.2.png'})
# BHLHE41(+) 44 BHLHE41 frozenset({'tfdimers__MD00046.png', 'activating'})
# BPTF(+) 16 BPTF frozenset({'activating', 'tfdimers__MD00229.png'})
# CEBPA(+) 57 CEBPA frozenset({'activating', 'tfdimers__MD00535.png'})
# CEBPB(+) 84 CEBPB frozenset({'tfdimers__MD00394.png', 'activating'})
# CEBPD(+) 47 CEBPD frozenset({'tfdimers__MD00110.png', 'activating'})
# CEBPG(+) 35 CEBPG frozenset({'tfdimers__MD00263.png', 'activating'})
# CENPB(+) 11 CENPB frozenset({'metacluster_182.1.png', 'activating'})
# CHD1(+) 32 CHD1 frozenset({'metacluster_133.2.png', 'activating'})
# CHURC1(+) 9 CHURC1 frozenset({'tfdimers__MD00143.png', 'activating'})
# CREM(+) 38 CREM frozenset({'activating', 'tfdimers__MD00322.png'})
# CRX(+) 14 CRX frozenset({'tfdimers__MD00371.png', 'activating'})
# CUX1(+) 18 CUX1 frozenset({'taipale_tf_pairs__CUX1_HOXB13_SYMRTAAANATYGATN_CAP.png', 'activating'})
# DBP(+) 25 DBP frozenset({'tfdimers__MD00240.png', 'activating'})
# DDX20(+) 24 DDX20 frozenset({'activating', 'metacluster_24.4.png'})
# DLX1(+) 17 DLX1 frozenset({'taipale_tf_pairs__HOXA6_SYMATTAN_HT.png', 'activating'})
# DLX2(+) 9 DLX2 frozenset({'activating', 'metacluster_9.41.png'})
# DLX5(+) 36 DLX5 frozenset({'metacluster_184.13.png', 'activating'})
# E2F1(+) 52 E2F1 frozenset({'tfdimers__MD00356.png', 'activating'})
# E2F3(+) 9 E2F3 frozenset({'metacluster_141.2.png', 'activating'})
# E2F4(+) 20 E2F4 frozenset({'metacluster_133.2.png', 'activating'})
# E2F6(+) 8 E2F6 frozenset({'activating', 'metacluster_197.3.png'})
# EBF4(+) 3 EBF4 frozenset({'activating', 'tfdimers__MD00481.png'})
# ELF1(+) 47 ELF1 frozenset({'metacluster_2.6.png', 'activating'})
# ELF2(+) 46 ELF2 frozenset({'activating', 'metacluster_166.2.png'})
# ELF3(+) 17 ELF3 frozenset({'activating', 'taipale_tf_pairs__ETV7_TBX21_NSCGGAARNNNNNNTCACACNN_CAP_repr.png'})
# ELK1(+) 34 ELK1 frozenset({'activating', 'tfdimers__MD00168.png'})
# ELK3(+) 62 ELK3 frozenset({'tfdimers__MD00007.png', 'activating'})
# EOMES(+) 14 EOMES frozenset({'taipale_tf_pairs__E2F1_EOMES_NGGTGTGNNNGGCGCSNNNCRC_CAP_repr.png', 'activating'})
# EP300(+) 15 EP300 frozenset({'activating', 'tfdimers__MD00581.png'})
# ERF(+) 17 ERF frozenset({'activating', 'taipale_tf_pairs__FLI1_DLX2_RSCGGAANNNNNYAATTAN_CAP.png'})
# ESR1(+) 28 ESR1 frozenset({'metacluster_121.1.png', 'activating'})
# ESRRA(+) 18 ESRRA frozenset({'metacluster_90.4.png', 'activating'})
# ETS1(+) 46 ETS1 frozenset({'activating', 'tfdimers__MD00351.png'})
# ETS2(+) 42 ETS2 frozenset({'tfdimers__MD00106.png', 'activating'})
# ETV1(+) 17 ETV1 frozenset({'activating', 'taipale_tf_pairs__GCM1_ERG_RTRYGGGCGGAARKN_CAP.png'})
# ETV2(+) 19 ETV2 frozenset({'jaspar__MA1952.1.png', 'activating'})
# ETV3(+) 11 ETV3 frozenset({'taipale_tf_pairs__ETV2_GSC2_RCCGGANNNNNNNNNTAATCCN_CAP_repr.png', 'activating'})
# ETV4(+) 43 ETV4 frozenset({'taipale_tf_pairs__ETV2_DLX2_RCCGGAANNNNNYAATTA_CAP.png', 'activating'})
# ETV6(+) 27 ETV6 frozenset({'activating', 'tfdimers__MD00131.png'})
# FHL2(+) 20 FHL2 frozenset({'activating', 'hdpi__FHL2.png'})
# FLI1(+) 80 FLI1 frozenset({'tfdimers__MD00066.png', 'activating'})
# FOS(+) 53 FOS frozenset({'activating', 'metacluster_137.5.png'})
# FOSB(+) 24 FOSB frozenset({'activating', 'tfdimers__MD00014.png'})
# FOSL1(+) 7 FOSL1 frozenset({'tfdimers__MD00221.png', 'activating'})
# FOSL2(+) 19 FOSL2 frozenset({'activating', 'tfdimers__MD00601.png'})
# FOXJ3(+) 6 FOXJ3 frozenset({'activating', 'metacluster_79.37.png'})
# FOXM1(+) 6 FOXM1 frozenset({'activating', 'tfdimers__MD00130.png'})
# FOXO1(+) 43 FOXO1 frozenset({'taipale_tf_pairs__FLI1_FOXI1_GAAAACCGAAAN_CAP_repr.png', 'activating'})
# FOXO3(+) 28 FOXO3 frozenset({'metacluster_133.2.png', 'activating'})
# FOXP4(+) 11 FOXP4 frozenset({'activating', 'metacluster_129.1.png'})
# GABPA(+) 54 GABPA frozenset({'activating', 'taipale_tf_pairs__ETV2_RFX5_NNNTTCCGSNNNNGCAACNN_CAP_repr.png'})
# GABPB1(+) 14 GABPB1 frozenset({'activating', 'tfdimers__MD00310.png'})
# GATA2(+) 46 GATA2 frozenset({'activating', 'transfac_pro__M01207.png'})
# GATA3(+) 63 GATA3 frozenset({'activating', 'transfac_pro__M04910.png'})
# GATAD1(+) 32 GATAD1 frozenset({'metacluster_191.3.png', 'activating'})
# GBX2(+) 26 GBX2 frozenset({'activating', 'metacluster_9.35.png'})
# GMEB2(+) 7 GMEB2 frozenset({'activating', 'metacluster_19.7.png'})
# GTF2I(+) 14 GTF2I frozenset({'transfac_pro__M00706.png', 'activating'})
# GTF2IRD1(+) 7 GTF2IRD1 frozenset({'activating', 'transfac_pro__M01240.png'})
# HAND1(+) 9 HAND1 frozenset({'tfdimers__MD00264.png', 'activating'})
# HDX(+) 31 HDX frozenset({'activating', 'tfdimers__MD00337.png'})
# HEY1(+) 10 HEY1 frozenset({'metacluster_14.3.png', 'activating'})
# HEY2(+) 10 HEY2 frozenset({'activating', 'taipale_tf_pairs__TFAP4_MAX_NCAGCTGNNNNNCACGTGN_CAP.png'})
# HIC1(+) 14 HIC1 frozenset({'activating', 'tfdimers__MD00501.png'})
# HMBOX1(+) 10 HMBOX1 frozenset({'activating', 'tfdimers__MD00165.png'})
# HMG20B(+) 13 HMG20B frozenset({'metacluster_127.2.png', 'activating'})
# HMGA1(+) 38 HMGA1 frozenset({'tfdimers__MD00104.png', 'activating'})
# HMGA2(+) 28 HMGA2 frozenset({'activating', 'metacluster_164.1.png'})
# HOXB2(+) 7 HOXB2 frozenset({'activating', 'taipale_tf_pairs__HOXD12_TBX21_NGGTGTNNNNNNNNNNNNNCACNTNNTWAN_CAP_repr.png'})
# HOXB3(+) 38 HOXB3 frozenset({'activating', 'metacluster_184.57.png'})
# HOXC9(+) 7 HOXC9 frozenset({'metacluster_9.29.png', 'activating'})
# IKZF1(+) 28 IKZF1 frozenset({'activating', 'tfdimers__MD00593.png'})
# IKZF2(+) 22 IKZF2 frozenset({'activating', 'metacluster_167.2.png'})
# IKZF5(+) 4 IKZF5 frozenset({'tfdimers__MD00006.png', 'activating'})
# ILF2(+) 6 ILF2 frozenset({'tfdimers__MD00064.png', 'activating'})
# ING4(+) 24 ING4 frozenset({'activating', 'metacluster_35.3.png'})
# IRF1(+) 20 IRF1 frozenset({'activating', 'tfdimers__MD00438.png'})
# IRF2(+) 61 IRF2 frozenset({'activating', 'tfdimers__MD00138.png'})
# IRF7(+) 22 IRF7 frozenset({'metacluster_2.9.png', 'activating'})
# IRF9(+) 23 IRF9 frozenset({'activating', 'tfdimers__MD00075.png'})
# ISL1(+) 17 ISL1 frozenset({'tfdimers__MD00452.png', 'activating'})
# JDP2(+) 24 JDP2 frozenset({'activating', 'metacluster_22.34.png'})
# JUN(+) 11 JUN frozenset({'tfdimers__MD00353.png', 'activating'})
# JUNB(+) 60 JUNB frozenset({'tfdimers__MD00036.png', 'activating'})
# JUND(+) 14 JUND frozenset({'activating', 'metacluster_58.8.png'})
# LEF1(+) 9 LEF1 frozenset({'activating', 'tfdimers__MD00299.png'})
# LHX1(+) 14 LHX1 frozenset({'metacluster_9.29.png', 'activating'})
# LHX2(+) 20 LHX2 frozenset({'activating', 'metacluster_184.19.png'})
# LHX4(+) 12 LHX4 frozenset({'activating', 'metacluster_9.10.png'})
# MAF(+) 38 MAF frozenset({'activating', 'metacluster_22.27.png'})
# MAFA(+) 31 MAFA frozenset({'tfdimers__MD00102.png', 'activating'})
# MAFF(+) 11 MAFF frozenset({'tfdimers__MD00285.png', 'activating'})
# MAFG(+) 24 MAFG frozenset({'tfdimers__MD00298.png', 'activating'})
# MAFK(+) 5 MAFK frozenset({'tfdimers__MD00264.png', 'activating'})
# MEIS1(+) 22 MEIS1 frozenset({'activating', 'metacluster_68.4.png'})
# MITF(+) 31 MITF frozenset({'activating', 'metacluster_177.3.png'})
# MSX1(+) 9 MSX1 frozenset({'activating', 'metacluster_150.2.png'})
# MXD1(+) 22 MXD1 frozenset({'activating', 'tfdimers__MD00500.png'})
# MXD4(+) 11 MXD4 frozenset({'homer__AGATSTNDNNDSAGATAASN_GATA3.png', 'activating'})
# MYBL2(+) 21 MYBL2 frozenset({'taipale__MYBL2_DBD_AACCGTTAACGGNN.png', 'activating'})
# MYC(+) 3 MYC frozenset({'activating', 'cisbp__M07803.png'})
# MYNN(+) 12 MYNN frozenset({'metacluster_26.7.png', 'activating'})
# MZF1(+) 29 MZF1 frozenset({'tfdimers__MD00451.png', 'activating'})
# NFATC2(+) 42 NFATC2 frozenset({'tfdimers__MD00066.png', 'activating'})
# NFATC3(+) 18 NFATC3 frozenset({'tfdimers__MD00466.png', 'activating'})
# NFATC4(+) 48 NFATC4 frozenset({'activating', 'transfac_pro__M07607.png'})
# NFE2L1(+) 5 NFE2L1 frozenset({'tfdimers__MD00466.png', 'activating'})
# NFE2L2(+) 91 NFE2L2 frozenset({'activating', 'metacluster_22.19.png'})
# NFE2L3(+) 8 NFE2L3 frozenset({'activating', 'tfdimers__MD00013.png'})
# NFIA(+) 40 NFIA frozenset({'activating', 'tfdimers__MD00316.png'})
# NFYB(+) 32 NFYB frozenset({'metacluster_174.2.png', 'activating'})
# NFYC(+) 36 NFYC frozenset({'metacluster_174.2.png', 'activating'})
# NHLH1(+) 5 NHLH1 frozenset({'activating', 'metacluster_117.7.png'})
# NKX2-1(+) 20 NKX2-1 frozenset({'tfdimers__MD00215.png', 'activating'})
# NKX6-2(+) 19 NKX6-2 frozenset({'activating', 'metacluster_0.2.png'})
# NR1H2(+) 26 NR1H2 frozenset({'metacluster_64.3.png', 'activating'})
# NR2F1(+) 21 NR2F1 frozenset({'tfdimers__MD00061.png', 'activating'})
# NR2F2(+) 31 NR2F2 frozenset({'metacluster_24.2.png', 'activating'})
# NR3C1(+) 46 NR3C1 frozenset({'activating', 'tfdimers__MD00280.png'})
# OTX1(+) 10 OTX1 frozenset({'activating', 'tfdimers__MD00429.png'})
# PATZ1(+) 15 PATZ1 frozenset({'tfdimers__MD00332.png', 'activating'})
# PAX7(+) 9 PAX7 frozenset({'activating', 'metacluster_9.31.png'})
# PBX1(+) 19 PBX1 frozenset({'activating', 'tfdimers__MD00533.png'})
# PHOX2A(+) 10 PHOX2A frozenset({'activating', 'metacluster_9.15.png'})
# PITX2(+) 7 PITX2 frozenset({'activating', 'tfdimers__MD00002.png'})
# PKNOX1(+) 4 PKNOX1 frozenset({'transfac_pro__M07464.png', 'activating'})
# PLAGL1(+) 11 PLAGL1 frozenset({'metacluster_7.5.png', 'activating'})
# POU2F1(+) 11 POU2F1 frozenset({'activating', 'metacluster_4.4.png'})
# POU3F1(+) 29 POU3F1 frozenset({'activating', 'taipale_tf_pairs__POU5F1_NATATGCTAATKN_HT.png'})
# POU3F2(+) 18 POU3F2 frozenset({'activating', 'metacluster_124.2.png'})
# POU5F1(+) 42 POU5F1 frozenset({'activating', 'tfdimers__MD00517.png'})
# PRDM1(+) 18 PRDM1 frozenset({'metacluster_187.2.png', 'activating'})
# PRRX1(+) 35 PRRX1 frozenset({'activating', 'metacluster_9.30.png'})
# PURG(+) 9 PURG frozenset({'activating', 'hdpi__PURG.png'})
# RARA(+) 20 RARA frozenset({'activating', 'metacluster_4.4.png'})
# RARG(+) 26 RARG frozenset({'activating', 'metacluster_119.2.png'})
# REL(+) 19 REL frozenset({'tfdimers__MD00217.png', 'activating'})
# REST(+) 16 REST frozenset({'activating', 'metacluster_187.7.png'})
# RFX2(+) 5 RFX2 frozenset({'activating', 'tfdimers__MD00591.png'})
# RFX5(+) 40 RFX5 frozenset({'tfdimers__MD00061.png', 'activating'})
# RFXANK(+) 23 RFXANK frozenset({'tfdimers__MD00043.png', 'activating'})
# RFXAP(+) 8 RFXAP frozenset({'activating', 'tfdimers__MD00594.png'})
# RORA(+) 6 RORA frozenset({'jaspar__MA1532.2.png', 'activating'})
# RORB(+) 14 RORB frozenset({'jaspar__MA1532.2.png', 'activating'})
# RXRA(+) 26 RXRA frozenset({'tfdimers__MD00066.png', 'activating'})
# RXRB(+) 34 RXRB frozenset({'activating', 'tfdimers__MD00304.png'})
# SATB1(+) 6 SATB1 frozenset({'activating', 'metacluster_9.34.png'})
# SCRT1(+) 9 SCRT1 frozenset({'activating', 'metacluster_149.2.png'})
# SF1(+) 18 SF1 frozenset({'activating', 'hdpi__SF1.png'})
# SHOX2(+) 31 SHOX2 frozenset({'activating', 'metacluster_51.11.png'})
# SIRT6(+) 17 SIRT6 frozenset({'activating', 'tfdimers__MD00591.png'})
# SMAD1(+) 13 SMAD1 frozenset({'activating', 'metacluster_4.4.png'})
# SMAD3(+) 29 SMAD3 frozenset({'swissregulon__hs__SMAD3.png', 'activating'})
# SMARCC2(+) 5 SMARCC2 frozenset({'activating', 'transfac_pro__M09849.png'})
# SOX1(+) 12 SOX1 frozenset({'activating', 'metacluster_4.4.png'})
# SOX10(+) 40 SOX10 frozenset({'activating', 'tfdimers__MD00088.png'})
# SOX12(+) 5 SOX12 frozenset({'activating', 'taipale_tf_pairs__SOX17_ACCGAACAAT_HT.png'})
# SOX15(+) 20 SOX15 frozenset({'activating', 'taipale_tf_pairs__GCM2_SOX15_ATRCGGGYNNNNNYWTTGTNN_CAP_repr.png'})
# SOX2(+) 10 SOX2 frozenset({'activating', 'taipale_tf_pairs__GCM1_SOX2_RTRSGGGNNNATTGTKY_CAP_repr.png'})
# SOX21(+) 16 SOX21 frozenset({'activating', 'metacluster_4.4.png'})
# SOX3(+) 7 SOX3 frozenset({'activating', 'metacluster_4.4.png'})
# SOX8(+) 26 SOX8 frozenset({'activating', 'metacluster_4.3.png'})
# SOX9(+) 18 SOX9 frozenset({'activating', 'metacluster_4.4.png'})
# SP1(+) 8 SP1 frozenset({'metacluster_195.2.png', 'activating'})
# SP2(+) 42 SP2 frozenset({'activating', 'metacluster_174.6.png'})
# SP4(+) 11 SP4 frozenset({'tfdimers__MD00557.png', 'activating'})
# SPIB(+) 19 SPIB frozenset({'tfdimers__MD00007.png', 'activating'})
# SREBF1(+) 20 SREBF1 frozenset({'tfdimers__MD00151.png', 'activating'})
# SREBF2(+) 8 SREBF2 frozenset({'tfdimers__MD00587.png', 'activating'})
# STAT1(+) 61 STAT1 frozenset({'activating', 'tfdimers__MD00432.png'})
# STAT2(+) 31 STAT2 frozenset({'tfdimers__MD00527.png', 'activating'})
# STAT3(+) 24 STAT3 frozenset({'activating', 'transfac_pro__M04829.png'})
# STAT5B(+) 6 STAT5B frozenset({'jaspar__MA1625.1.png', 'activating'})
# TAF1(+) 10 TAF1 frozenset({'activating', 'metacluster_141.6.png'})
# TAF6(+) 29 TAF6 frozenset({'tfdimers__MD00196.png', 'activating'})
# TBP(+) 13 TBP frozenset({'tfdimers__MD00355.png', 'activating'})
# TCF3(+) 24 TCF3 frozenset({'activating', 'tfdimers__MD00434.png'})
# TCF4(+) 33 TCF4 frozenset({'tfdimers__MD00529.png', 'activating'})
# TCF7L2(+) 29 TCF7L2 frozenset({'transfac_pro__M00671.png', 'activating'})
# TFAP2C(+) 13 TFAP2C frozenset({'activating', 'metacluster_4.4.png'})
# TFAP2E(+) 26 TFAP2E frozenset({'metacluster_125.2.png', 'activating'})
# TFE3(+) 24 TFE3 frozenset({'tfdimers__MD00568.png', 'activating'})
# TFEB(+) 42 TFEB frozenset({'activating', 'metacluster_169.2.png'})
# THAP5(+) 3 THAP5 frozenset({'activating', 'hdpi__THAP5.png'})
# THRA(+) 50 THRA frozenset({'tfdimers__MD00162.png', 'activating'})
# THRB(+) 18 THRB frozenset({'tfdimers__MD00127.png', 'activating'})
# TP53(+) 9 TP53 frozenset({'activating', 'tfdimers__MD00518.png'})
# UNCX(+) 14 UNCX frozenset({'activating', 'metacluster_9.19.png'})
# VDR(+) 10 VDR frozenset({'activating', 'tfdimers__MD00321.png'})
# VEZF1(+) 27 VEZF1 frozenset({'metacluster_133.2.png', 'activating'})
# VSX1(+) 20 VSX1 frozenset({'tfdimers__MD00207.png', 'activating'})
# WRNIP1(+) 20 WRNIP1 frozenset({'metacluster_24.2.png', 'activating'})
# XBP1(+) 8 XBP1 frozenset({'metacluster_139.7.png', 'activating'})
# YBX1(+) 10 YBX1 frozenset({'metacluster_174.2.png', 'activating'})
# YY1(+) 64 YY1 frozenset({'activating', 'metacluster_141.6.png'})
# ZBTB14(+) 23 ZBTB14 frozenset({'activating', 'hocomoco__ZBT14_HUMAN.H11MO.0.C.png'})
# ZBTB21(+) 17 ZBTB21 frozenset({'activating', 'metacluster_24.3.png'})
# ZBTB33(+) 10 ZBTB33 frozenset({'transfac_pro__M04923.png', 'activating'})
# ZBTB40(+) 6 ZBTB40 frozenset({'activating', 'metacluster_166.2.png'})
# ZBTB43(+) 14 ZBTB43 frozenset({'activating', 'metacluster_131.4.png'})
# ZBTB49(+) 8 ZBTB49 frozenset({'metacluster_20.8.png', 'activating'})
# ZBTB5(+) 26 ZBTB5 frozenset({'activating', 'metacluster_131.7.png'})
# ZBTB7A(+) 17 ZBTB7A frozenset({'activating', 'tfdimers__MD00137.png'})
# ZEB1(+) 6 ZEB1 frozenset({'tfdimers__MD00031.png', 'activating'})
# ZFHX2(+) 38 ZFHX2 frozenset({'metacluster_24.2.png', 'activating'})
# ZFP37(+) 38 ZFP37 frozenset({'metacluster_133.2.png', 'activating'})
# ZFP82(+) 9 ZFP82 frozenset({'kznf__ZFP82_Isakova2017_SMiLE-seq.png', 'activating'})
# ZNF143(+) 2 ZNF143 frozenset({'metacluster_34.4.png', 'activating'})
# ZNF148(+) 48 ZNF148 frozenset({'activating', 'metacluster_24.4.png'})
# ZNF18(+) 25 ZNF18 frozenset({'activating', 'metacluster_65.15.png'})
# ZNF182(+) 6 ZNF182 frozenset({'activating', 'metacluster_130.2.png'})
# ZNF202(+) 8 ZNF202 frozenset({'activating', 'transfac_pro__M05482.png'})
# ZNF22(+) 4 ZNF22 frozenset({'activating', 'metacluster_187.8.png'})
# ZNF260(+) 9 ZNF260 frozenset({'activating', 'metacluster_27.16.png'})
# ZNF267(+) 3 ZNF267 frozenset({'activating', 'transfac_pro__M06235.png'})
# ZNF274(+) 6 ZNF274 frozenset({'metacluster_88.2.png', 'activating'})
# ZNF287(+) 5 ZNF287 frozenset({'activating', 'transfac_pro__M06678.png'})
# ZNF300(+) 5 ZNF300 frozenset({'activating', 'metacluster_122.4.png'})
# ZNF317(+) 9 ZNF317 frozenset({'transfac_pro__M06673.png', 'activating'})
# ZNF324(+) 22 ZNF324 frozenset({'metacluster_24.2.png', 'activating'})
# ZNF354B(+) 9 ZNF354B frozenset({'kznf__ZNF354B_Imbeault2017_RP_RCADE.png', 'activating'})
# ZNF354C(+) 14 ZNF354C frozenset({'activating', 'tfdimers__MD00005.png'})
# ZNF37A(+) 15 ZNF37A frozenset({'activating', 'metacluster_24.3.png'})
# ZNF382(+) 8 ZNF382 frozenset({'activating', 'transfac_pro__M05918.png'})
# ZNF398(+) 32 ZNF398 frozenset({'activating', 'metacluster_24.4.png'})
# ZNF419(+) 3 ZNF419 frozenset({'metacluster_155.32.png', 'activating'})
# ZNF429(+) 10 ZNF429 frozenset({'activating', 'transfac_pro__M06415.png'})
# ZNF431(+) 18 ZNF431 frozenset({'metacluster_72.11.png', 'activating'})
# ZNF432(+) 9 ZNF432 frozenset({'tfdimers__MD00569.png', 'activating'})
# ZNF439(+) 6 ZNF439 frozenset({'transfac_pro__M05900.png', 'activating'})
# ZNF443(+) 19 ZNF443 frozenset({'transfac_pro__M06783.png', 'activating'})
# ZNF444(+) 14 ZNF444 frozenset({'metacluster_133.2.png', 'activating'})
# ZNF480(+) 18 ZNF480 frozenset({'transfac_pro__M06599.png', 'activating'})
# ZNF496(+) 14 ZNF496 frozenset({'activating', 'metacluster_187.7.png'})
# ZNF501(+) 8 ZNF501 frozenset({'activating', 'metacluster_67.2.png'})
# ZNF529(+) 15 ZNF529 frozenset({'activating', 'metacluster_24.4.png'})
# ZNF546(+) 9 ZNF546 frozenset({'transfac_pro__M05822.png', 'activating'})
# ZNF554(+) 6 ZNF554 frozenset({'metacluster_58.3.png', 'activating'})
# ZNF562(+) 6 ZNF562 frozenset({'activating', 'transfac_pro__M06378.png'})
# ZNF582(+) 7 ZNF582 frozenset({'kznf__ZNF582_Schmitges2016_RCADE.png', 'activating'})
# ZNF595(+) 17 ZNF595 frozenset({'activating', 'transfac_pro__M06463.png'})
# ZNF596(+) 20 ZNF596 frozenset({'activating', 'metacluster_24.4.png'})
# ZNF614(+) 9 ZNF614 frozenset({'activating', 'metacluster_24.3.png'})
# ZNF626(+) 4 ZNF626 frozenset({'activating', 'metacluster_185.1.png'})
# ZNF652(+) 7 ZNF652 frozenset({'metacluster_168.4.png', 'activating'})
# ZNF674(+) 13 ZNF674 frozenset({'activating', 'transfac_pro__M06334.png'})
# ZNF691(+) 11 ZNF691 frozenset({'activating', 'c2h2_zfs__M0406.png'})
# ZNF692(+) 34 ZNF692 frozenset({'metacluster_133.2.png', 'activating'})
# ZNF7(+) 5 ZNF7 frozenset({'activating', 'metacluster_13.1.png'})
# ZNF701(+) 11 ZNF701 frozenset({'activating', 'metacluster_24.4.png'})
# ZNF71(+) 32 ZNF71 frozenset({'activating', 'kznf__ZNF71_Schmitges2016_RCADE.png'})
# ZNF740(+) 34 ZNF740 frozenset({'activating', 'metacluster_131.4.png'})
# ZNF76(+) 7 ZNF76 frozenset({'metacluster_34.1.png', 'activating'})
# ZNF764(+) 6 ZNF764 frozenset({'metacluster_101.5.png', 'activating'})
# ZNF768(+) 6 ZNF768 frozenset({'transfac_pro__M05892.png', 'activating'})
# ZNF789(+) 22 ZNF789 frozenset({'transfac_pro__M06863.png', 'activating'})
# ZNF791(+) 7 ZNF791 frozenset({'activating', 'transfac_pro__M06287.png'})
# ZNF84(+) 19 ZNF84 frozenset({'metacluster_167.3.png', 'activating'})
# ZSCAN9(+) 22 ZSCAN9 frozenset({'metacluster_36.1.png', 'activating'})
# ZXDB(+) 19 ZXDB frozenset({'metacluster_23.3.png', 'activating'})
# ZXDC(+) 5 ZXDC frozenset({'metacluster_80.7.png', 'activating'})

# %%
## Isolate TFs for Each Regulon#

TFs = [i.strip('(+)') for i in auc_mtx.columns]

# Make DF where TFs are on the X and all cells arranged by subtype on the Y

TF_df = pd.DataFrame(data=scz_adata[scz_adata.obs.sort_values('subclass_annotations_markers').index,TFs].layers['log1p_norm'].toarray(),
                     index=scz_adata.obs.sort_values('subclass_annotations_markers').index,
                     columns=TFs)

TF_df = TF_df.reset_index(drop=True)
TF_df.columns = [str(col) for col in TF_df.columns]

# Make DF where TFs are on the X and aggregated subtypes are on the Y

TF_subtype_df = pd.DataFrame(
    scz_adata[:, TFs].layers['log1p_norm'].toarray(),  # convert sparse matrix to dense
    columns=TFs,
    index=scz_adata.obs['subclass_annotations_markers'])

TF_subtype_df = TF_subtype_df.groupby(level=0).mean()

## Visualize #

# top 10% variance
sns.clustermap(TF_subtype_df.loc[:, TF_subtype_df.var(axis=0) >= TF_subtype_df.var(axis=0).quantile(0.9)])

# %%
## Trying to make a Cell Type Specific Regulon Heatmap ##

# Ensure alignment
auc_mtx = auc_mtx.loc[scz_adata.obs_names]

# Compute RSS (regulons x cell types)
rss = regulon_specificity_scores(auc_mtx, scz_adata.obs['subclass_annotations_markers'])

# %%
top_n = 4

# Convert to long format
rss_long = rss.reset_index().melt(id_vars='index', var_name='regulon', value_name='rss').rename(columns={'index': 'cell_type'})

# Get top N regulons per cell type
top_regulons_df = (rss_long.sort_values(['cell_type', 'rss'], ascending=[True, False]).groupby('cell_type').head(top_n))

top_regulons_df = top_regulons_df[~top_regulons_df['regulon'].duplicated()]

# %%
# Add cell type labels
auc_with_ct = auc_mtx.copy()
auc_with_ct['cell_type'] = scz_adata.obs['subclass_annotations_markers'].values

# Mean AUC per cell type
mean_auc = auc_with_ct.groupby('cell_type').mean()
# Out:
# /tmp/ipykernel_134569/346727537.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_auc = auc_with_ct.groupby('cell_type').mean()

# %%
mean_auc['celltype'] = mean_auc.index

mean_auc_melted = pd.melt(mean_auc[top_regulons_df['regulon'].tolist() + ['celltype']], id_vars=['celltype'], value_name='AUC')

# %%
# -----------------------------
# 1. Choose regulons (same as heatmap)
# -----------------------------
regulons = mean_auc[top_regulons_df['regulon'].tolist()].columns.tolist()
celltypes = mean_auc.index.tolist()

auc_mat = mean_auc.loc[celltypes, regulons]
rss_mat = rss.loc[celltypes, regulons]

# -----------------------------
# 2. Build coordinate maps
# -----------------------------
x_map = {r: i for i, r in enumerate(regulons)}
y_map = {c: i for i, c in enumerate(celltypes)}

# -----------------------------
# 3. Convert RSS to long format
# -----------------------------
rss_long = (rss_mat.reset_index().rename(columns={'index': 'celltype'}).melt(id_vars='celltype',
                                                                             var_name='regulon',
                                                                             value_name='rss_score'))
# -----------------------------
# 4. Align to heatmap grid ONLY
# -----------------------------
rss_long = rss_long[rss_long['celltype'].isin(celltypes) & rss_long['regulon'].isin(regulons)].copy()

# -----------------------------
# 5. Map to heatmap coordinates
# -----------------------------
rss_long['x'] = rss_long['regulon'].map(x_map)
rss_long['y'] = rss_long['celltype'].map(y_map)

# -----------------------------
# 6. Final safety checks
# -----------------------------
assert rss_long['x'].notnull().all()
assert rss_long['y'].notnull().all()
assert len(rss_long) == len(celltypes) * len(regulons)

# %%
baseline = rss_long['rss_score'].min()

rss_scaled = (rss_long['rss_score'] - baseline)
rss_scaled = np.clip(rss_scaled, 0, None)

rss_scaled = rss_scaled / rss_scaled.max()
rss_scaled = np.sqrt(rss_scaled)

# %%
fig, ax = plt.subplots()

sns.heatmap(mean_auc[top_regulons_df['regulon'].tolist()], ax=ax)

ax = plt.gca()

ax.scatter(
    rss_long['x'] + 0.5,
    rss_long['y'] + 0.5,
    s=rss_scaled * 75,
    c='white',
    edgecolor='black',
    linewidth=0.5,
    alpha=0.7,
    zorder=10)

plt.show()

# %%
## Trying to make a Disease Specific Regulon Heatmap ##

top_n = 3


scz_adata.obs = scz_adata.obs.sort_values(['Genotype', 'CellType'])

# Convert to long format
rss_22q11['Genotype_Celltype'] = scz_adata.obs['Genotype_Celltype']
rss_22q11['Genotype'] = scz_adata.obs['Broad_Genotype']
rss_22q11['CellType'] = scz_adata.obs['subclass_annotations_markers']

rss_long = rss_22q11.reset_index(drop=True).melt(id_vars=['Genotype_Celltype','CellType', 'Genotype'], 
                                                 var_name='regulon', value_name='rss')

# assign genotype by matching prefix (safe for underscores)
rss_long['Genotype'] = pd.NA
for g in genotype_order:
    mask = rss_long['Genotype_Celltype'].str.startswith(g + "_")
    rss_long.loc[mask, 'Genotype'] = g

# enforce ordering
rss_long['Genotype'] = pd.Categorical(rss_long['Genotype'], genotype_order, True)
rss_long['CellType'] = pd.Categorical(rss_long['CellType'], celltype_order, True)

rss_long = rss_long.sort_values(['Genotype', 'CellType'])

# Get top N regulons per cell type
top_regulons_df = (rss_long.sort_values(['Genotype_Celltype', 
                                         'rss'], ascending=[True, False]).groupby('Genotype_Celltype').head(top_n))

top_regulons_df = top_regulons_df[~top_regulons_df['regulon'].duplicated()]

# Add cell type labels
# auc_with_ct = auc_mtx.copy()
auc_with_ct = auc_mtx_22q11.copy()
auc_with_ct['Genotype_Celltype'] = scz_adata.obs['Genotype_Celltype']

# Mean AUC per cell type
mean_auc = auc_with_ct.groupby('Genotype_Celltype').mean()

mean_auc['Genotype_Celltype'] = mean_auc.index

mean_auc['Broad_Genotype'] = mean_auc['Genotype_Celltype'].str.split('_').apply(lambda x: x[0])
mean_auc['Broad_Genotype'] = pd.Categorical(mean_auc['Broad_Genotype'], ordered=True, categories=genotype_order)

mean_auc['CellType'] = mean_auc['Genotype_Celltype'].str.split('_').apply(lambda x: x[1])
mean_auc['CellType'] = pd.Categorical(mean_auc['CellType'], ordered=True, categories=celltype_order)

mean_auc = mean_auc.sort_values(by=['Broad_Genotype', 'CellType'])

# %%
# (rss_long.sort_values(['Genotype_Celltype', 'rss'], ascending=[True, False, False]) #.groupby('Genotype_Celltype').head(top_n))

# %%
# -----------------------------
# 1. Choose regulons (same as heatmap)
# -----------------------------
regulons = mean_auc[top_regulons_df['regulon'].tolist()].columns.tolist()
celltypes = mean_auc.index.tolist()

auc_mat = mean_auc.loc[celltypes, regulons]
rss_mat = rss.loc[celltypes, regulons]

# -----------------------------
# 2. Build coordinate maps
# -----------------------------
x_map = {r: i for i, r in enumerate(regulons)}
y_map = {c: i for i, c in enumerate(celltypes)}

# -----------------------------
# 3. Convert RSS to long format
# -----------------------------
rss_long = (rss_mat.reset_index().rename(columns={'index': 'Genotype_Celltype'}).melt(id_vars='Genotype_Celltype',
                                                                             var_name='regulon',
                                                                             value_name='rss_score'))
# -----------------------------
# 4. Align to heatmap grid ONLY
# -----------------------------
rss_long = rss_long[rss_long['Genotype_Celltype'].isin(celltypes) & rss_long['regulon'].isin(regulons)].copy()

# -----------------------------
# 5. Map to heatmap coordinates
# -----------------------------
rss_long['x'] = rss_long['regulon'].map(x_map)
rss_long['y'] = rss_long['Genotype_Celltype'].map(y_map)

# %%
baseline = rss_long['rss_score'].min()

rss_scaled = (rss_long['rss_score'] - baseline)
rss_scaled = np.clip(rss_scaled, 0, None)

rss_scaled = rss_scaled / rss_scaled.max()
rss_scaled = np.sqrt(rss_scaled)

fig, ax = plt.subplots()

mean_auc_plot = mean_auc[top_regulons_df['regulon'].tolist()]

mean_auc_plot = (mean_auc_plot - mean_auc_plot.min()) / (mean_auc_plot.max() - mean_auc_plot.min())

sns.heatmap(mean_auc_plot, ax=ax)

ax = plt.gca()

ax.scatter(
    rss_long['x'] + 0.5,
    rss_long['y'] + 0.5,
    s=rss_scaled * 75,
    c='white',
    edgecolor='black',
    linewidth=0.5,
    alpha=0.7,
    zorder=10)

plt.show()
