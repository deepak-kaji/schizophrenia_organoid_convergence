# %%
import glob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
DONOR_ID_PATHS = glob.glob('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/*/donor_ids.tsv')

# %%
glob.glob('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/*')
# Out:
# ['/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424584',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424573',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424577',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424568',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424574',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424589',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424579',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424583',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424585',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424582',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424570',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424588',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424578',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424580',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424587',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424586',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424571',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424569',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424576',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424575',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424581',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424590',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424572']

# %%
DONOR_ID_PATHS
# Out:
# ['/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424584/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424573/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424577/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424574/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424579/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424583/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424585/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424582/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424570/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424588/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424578/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424580/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424587/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424586/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424571/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424569/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424576/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424575/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424581/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424572/donor_ids.tsv']

# %%
donor_id_path_list = []

for donor_id_path in DONOR_ID_PATHS:
   # print(donor_id_path)
    temp_df = None
    temp_df = pd.read_table(donor_id_path, sep='\t')
    donor_id_path_list.append(temp_df)

donor_id_df = pd.concat(donor_id_path_list, axis=0)

# %%
donor_id_df['donor_id'].value_counts()
# Out:
# donor_id
# 5401-35_NOW1_205061460074_R08C01    47604
# unassigned                          44928
# 1323-4_NOW26_205061460074_R11C02    26777
# 3577-3_NOW28_205061460121_R09C01    26580
# 28126_NOW4_205061460121_R03C02      25436
# 60C2_NOW29_205061460121_R11C02      21040
# doublet                             10964
# WTC11_NOW6_205061460074_R05C02        639
# Name: count, dtype: int64

# %%
(donor_id_df['donor_id'].value_counts() / donor_id_df.shape[0])*100
# Out:
# donor_id
# 5401-35_NOW1_205061460074_R08C01    23.338955
# unassigned                          22.026985
# 1323-4_NOW26_205061460074_R11C02    13.128040
# 3577-3_NOW28_205061460121_R09C01    13.031456
# 28126_NOW4_205061460121_R03C02      12.470584
# 60C2_NOW29_205061460121_R11C02      10.315344
# doublet                              5.375353
# WTC11_NOW6_205061460074_R05C02       0.313284
# Name: count, dtype: float64

# %%
(test['donor_id'].value_counts() / test.shape[0])*100
# Out:
# donor_id
# 5401-35_NOW1_205061460074_R08C01    23.860635
# unassigned                          17.906125
# 1323-4_NOW26_205061460074_R11C02    14.796831
# 3577-3_NOW28_205061460121_R09C01    13.612744
# 28126_NOW4_205061460121_R03C02      13.425334
# 60C2_NOW29_205061460121_R11C02      10.341596
# doublet                              6.056734
# Name: count, dtype: float64

# %%
temp_df['assigned'] = temp_df['donor_id'].apply(lambda x: False if x == 'unassigned' else True)
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 11734     True
# 11735     True
# 11736     True
# 11737    False
# 11738     True
# Name: donor_id, Length: 11739, dtype: bool

# %%
sns.histplot(data=test, x='prob_max', hue='assigned')
plt.ylim(0,100)
# Out:
# (0.0, 100.0)
