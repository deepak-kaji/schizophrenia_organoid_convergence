# %%
import glob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import vireoSNP

# %matplotlib inline

# %%
DONOR_ID_PATHS = glob.glob('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/*/donor_ids.tsv')

DONOR_ID_PATHS = [PATH for PATH in DONOR_ID_PATHS if 'unsup' not in PATH]

# %%
DONOR_ID_PATHS

# Note SRR26424568 missing because not in the study and only one donor
# Out:
# ['/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424584/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424563/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424573/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424577/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424566/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424562/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424574/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424589/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424579/donor_ids.tsv',
#  '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424583/donor_ids.tsv',
# ...

# %%
donor_id_path_list = []

for donor_id_path in DONOR_ID_PATHS:
    temp_df = None
    temp_df = pd.read_table(donor_id_path, sep='\t')
    temp_df['library'] = donor_id_path.split('/')[-2]
    donor_id_path_list.append(temp_df)

donor_id_df = pd.concat(donor_id_path_list, axis=0)

# %%
donor_id_df['donor_id'].value_counts()
# Out:
# donor_id
# 5401-35_NOW1_205061460074_R08C01     78407
# unassigned                           60493
# doublet                              51910
# 1323-4_NOW26_205061460074_R11C02     35367
# 3577-3_NOW28_205061460121_R09C01     35295
# 60C2_NOW29_205061460121_R11C02       32896
# 28126_NOW4_205061460121_R03C02       32166
# WTC11_NOW6_205061460074_R05C02       10468
# 20961B_NOW9_205061460121_R11C01       7838
# 2909_NOW12_205061460121_R07C01        6603
# 7215-32_NOW11_205061460121_R05C01       12
# Name: count, dtype: int64

# %%
(donor_id_df['donor_id'].value_counts() / donor_id_df.shape[0])*100
# Out:
# donor_id
# 5401-35_NOW1_205061460074_R08C01     22.309257
# unassigned                           17.212161
# doublet                              14.770027
# 1323-4_NOW26_205061460074_R11C02     10.063024
# 3577-3_NOW28_205061460121_R09C01     10.042537
# 60C2_NOW29_205061460121_R11C02        9.359947
# 28126_NOW4_205061460121_R03C02        9.152239
# WTC11_NOW6_205061460074_R05C02        2.978475
# 20961B_NOW9_205061460121_R11C01       2.230157
# 2909_NOW12_205061460121_R07C01        1.878761
# 7215-32_NOW11_205061460121_R05C01     0.003414
# Name: count, dtype: float64

# %%
donor_id_df['assigned'] = donor_id_df['donor_id'].apply(lambda x: False if (x == 'unassigned' or x == 'doublet') else True)

# %%
donor_id_df['assigned'].sum() / donor_id_df['assigned'].shape[0]
# Out:
# np.float64(0.6801781166863468)

# %%
donor_id_df['assigned'].sum()
# Out:
# np.int64(239052)

# %%
sns.histplot(data=donor_id_df, x='prob_max', hue='assigned')
plt.ylim(0,50000)
# Out:
# (0.0, 50000.0)

# %%
sns.histplot(data=donor_id_df, x='prob_max', hue='assigned')
plt.ylim(0,10000)
# Out:
# (0.0, 10000.0)

# %%
# Calculate the total count per library
total_counts = donor_id_df.groupby('library')['assigned'].count()

# Calculate the count of True values per library
true_counts = donor_id_df[donor_id_df['assigned'] == True].groupby('library')['assigned'].count()

# Calculate percentage of True values per library
percentage_true = (true_counts / total_counts) * 100

# Merge both the count and percentage into a new DataFrame
result = pd.DataFrame({
    'true_count': true_counts,
    'percentage_true': percentage_true
})

# Display the result
result.sort_values(by='percentage_true', ascending=False)
# Out:
#              true_count  percentage_true
# library
# SRR26424566        7599        91.964178
# SRR26424572        7538        84.459384
# SRR26424571        8016        84.183995
# SRR26424570        8006        84.105473
# SRR26424569        8060        83.975828
# SRR26424567       21107        83.721391
# SRR26424580        9136        80.486301
# SRR26424579        9213        80.245623
# SRR26424578        9038        79.798693
# SRR26424577        9324        79.794608
# SRR26424574        9616        79.137520
# SRR26424573        9784        78.826942
# SRR26424575        9788        78.669024
# SRR26424576        9786        78.281737
# SRR26424584        8992        76.599370
# SRR26424581        9001        76.111957
# SRR26424583        9117        75.892783
# SRR26424582        9290        74.810759
# SRR26424589        7676        71.960251
# SRR26424590        5654        63.664002
# SRR26424588        8636        55.784510
# SRR26424564       14271        53.666516
# ...

# %%
## Compare Efficiency of Different cellSNP-lite Runs With Varying Parameters ##

minMAF01_minCount10 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/anndata_objs/minMAF_0pt1_minCount_10.csv', index_col=0)
minMAF01_minCount20 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/anndata_objs/minMAF_0pt1_minCount_20.csv', index_col=0)
minMAF00_minCount10 = pd.read_csv('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/anndata_objs/minMAF_0pt0_minCount_10.csv', index_col=0)

# %%
## Calculate Percentage of Assignment ##

## note minMAF01_minCount10 is final and most recent import ##

print(minMAF01_minCount10[minMAF01_minCount10['assigned'] == True].shape[0] / minMAF01_minCount10.shape[0])

print(minMAF01_minCount20[minMAF01_minCount20['assigned'] == True].shape[0] / minMAF01_minCount20.shape[0])

print(minMAF00_minCount10[minMAF00_minCount10['assigned'] == True].shape[0] / minMAF00_minCount10.shape[0])
# Out:
# 0.7064872032223362
# 0.6903358893741731
# 0.6801781166863468

# %%
## Are There Any Runs Where Things Go Particularly Wrong ##

minMAF01_minCount10.groupby('library')['assigned'].mean().mul(100)
# Out:
# library
# SRR26424562    60.205451
# SRR26424563    43.468770
# SRR26424564    62.112665
# SRR26424565    92.105263
# SRR26424566    92.194118
# SRR26424567    87.481655
# SRR26424569    86.007502
# SRR26424570    85.786322
# SRR26424571    86.231884
# SRR26424572    87.114846
# SRR26424573    79.060587
# SRR26424574    79.820591
# SRR26424575    78.902106
# SRR26424576    78.321734
# SRR26424577    80.102696
# SRR26424578    79.710401
# SRR26424579    80.715966
# SRR26424580    81.147036
# SRR26424581    76.078133
# SRR26424582    72.451280
# SRR26424583    75.393324
# SRR26424584    76.037141
# SRR26424585    20.240311
# SRR26424586    13.480482
# SRR26424587    15.857826
# SRR26424588    63.781409
# SRR26424589    75.063279
# SRR26424590    66.692940
# Name: assigned, dtype: float64

# %%
## Check Donor Relatedness ##

donors = pd.read_table('/mnt/sda/scz_meta_analysis/shin_nowakowski_cellstemcell_2025/genotypes/gtc2vcf/vcfs/donors_relatedness.genome', 
                       delim_whitespace=True)

donors[['FID1', 'FID2', 'PI_HAT']]

# no PI_HATs are > 1 suggesting no off target donor relatedness #
# Out:
# /tmp/ipykernel_45926/102095187.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   donors = pd.read_table('/mnt/sda/scz_meta_analysis/shin_nowakowski_cellstemcell_2025/genotypes/gtc2vcf/vcfs/donors_relatedness.genome',
#                                  FID1                               FID2  \
# 0    5401-35_NOW1_205061460074_R08C01     WTC11_NOW6_205061460074_R05C02
# 1    5401-35_NOW1_205061460074_R08C01   1323-4_NOW26_205061460074_R11C02
# 2    5401-35_NOW1_205061460074_R08C01  7215-32_NOW11_205061460121_R05C01
# 3    5401-35_NOW1_205061460074_R08C01   3577-3_NOW28_205061460121_R09C01
# 4    5401-35_NOW1_205061460074_R08C01     60C2_NOW29_205061460121_R11C02
# 5    5401-35_NOW1_205061460074_R08C01    20961B_NOW9_205061460121_R11C01
# 6    5401-35_NOW1_205061460074_R08C01     2909_NOW12_205061460121_R07C01
# ...

# %%
## Import SRR26424589_unsupervised Vireo Run to Assign Donors ##

unsupervised = pd.read_table('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424589_unsup/donor_ids.tsv')

unsupervised['library'] = 'SRR26424589_unsup'

unsupervised['assigned'] = unsupervised['donor_id'].str.contains('donor')

# %%
## Percentage of Assigned Cells ##

unsupervised['assigned'].sum() / unsupervised.shape[0]
# Out:
# np.float64(0.7817568200993719)

# %%
unsupervised
# Out:
#                    cell    donor_id  prob_max  prob_doublet  n_vars  \
# 0      AAACCTGAGACTGGGT      donor2    1.0000  3.690000e-06     843
# 1      AAACCTGAGAGGGATA     doublet    0.0119  9.880000e-01     539
# 2      AAACCTGAGATGCCAG      donor1    1.0000  2.100000e-04     464
# 3      AAACCTGAGCCACCTG      donor2    1.0000  2.730000e-30    1331
# 4      AAACCTGAGGTTCCTA  unassigned    0.0916  8.680000e-01     291
# ...                 ...         ...       ...           ...     ...
# 10662  TTTGTCAGTGGCGAAT      donor2    1.0000  6.370000e-11     928
# 10663  TTTGTCAGTGTAACGG      donor1    1.0000  3.590000e-04     523
# 10664  TTTGTCAGTTTGGGCC      donor2    1.0000  1.740000e-06     266
# 10665  TTTGTCATCGATGAGG      donor1    0.9830  1.190000e-02     286
# 10666  TTTGTCATCGCTGATA      donor0    1.0000  1.480000e-25    1142
#
#       best_singlet   best_doublet  doublet_logLikRatio            library  \
# 0           donor2  donor0,donor2               -9.979  SRR26424589_unsup
# ...

# %%
## Run VCF Comparison ##

res = vireoSNP.vcf.match_VCF_samples('/mnt/sda/scz_meta_analysis/shin_nowakowski_cellstemcell_2025/genotypes/gtc2vcf/vcfs/from_idat_chr_mapped.vcf.gz', 
                                     '/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/vireo_out/SRR26424589_unsup/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'GT', GT_tag2='PL')
# Out:
# Shape for Geno Prob in VCF1: (643635, 9, 3)
# Shape for Geno Prob in VCF2: (32881, 4, 3)
# n_variants in VCF1, VCF2 and matched: 643635, 32881, 32881
# aligned donors:
# ['5401-35_NOW1_205061460074_R08C01' '7215-32_NOW11_205061460121_R05C01'
#  '3577-3_NOW28_205061460121_R09C01' '28126_NOW4_205061460121_R03C02']
# ['donor0' 'donor3' 'donor2' 'donor1']

# %%
## Lower Numbers Represent Smaller Genotypic Distances ##

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()

## donor 3 matches equally well everywhere, because it's identity was not in the VCF, 
## because it was not genotyped in the snp array

# %%
donor_assignment_dict = {'donor0':'5401-35_NOW1_205061460074_R08C01', 
                         'donor3':'28815_unseqeuenced_nochip_noposition',
                         'donor2':'3577-3_NOW28_205061460121_R09C01',
                         'donor1':'28126_NOW4_205061460121_R03C02'}

unsupervised['donor_id'] = unsupervised['donor_id'].apply(lambda x: donor_assignment_dict[x] 
                                      if x in donor_assignment_dict.keys() else x)

# %%
## Create New File For Assigning Donors ##

minMAF01_minCount10 = minMAF01_minCount10[minMAF01_minCount10['library'] != 'SRR26424589']

# %%
minMAF01_minCount10
# Out:
#                   cell                          donor_id  prob_max  \
# 0     AAACCCAAGAAGATCT                        unassigned     0.679
# 1     AAACCCAAGCAGATAT  3577-3_NOW28_205061460121_R09C01     1.000
# 2     AAACCCAAGCTACGTT                        unassigned     0.956
# 3     AAACCCAAGCTTCGTA    28126_NOW4_205061460121_R03C02     0.994
# 4     AAACCCAAGTACAACA                        unassigned     0.711
# ...                ...                               ...       ...
# 8920  TTTGGTTTCGCAATTG  5401-35_NOW1_205061460074_R08C01     1.000
# 8921  TTTGTTGGTGTCGCTG  5401-35_NOW1_205061460074_R08C01     0.993
# 8922  TTTGTTGTCATCGTAG                        unassigned     0.695
# 8923  TTTGTTGTCGCTTACC  5401-35_NOW1_205061460074_R08C01     1.000
# 8924  TTTGTTGTCTAGTGTG  1323-4_NOW26_205061460074_R11C02     1.000
#
#       prob_doublet  n_vars                      best_singlet  \
# 0     1.480000e-01      14  5401-35_NOW1_205061460074_R08C01
# ...

# %%
unsupervised
# Out:
#                    cell                          donor_id  prob_max  \
# 0      AAACCTGAGACTGGGT  3577-3_NOW28_205061460121_R09C01    1.0000
# 1      AAACCTGAGAGGGATA                           doublet    0.0119
# 2      AAACCTGAGATGCCAG    28126_NOW4_205061460121_R03C02    1.0000
# 3      AAACCTGAGCCACCTG  3577-3_NOW28_205061460121_R09C01    1.0000
# 4      AAACCTGAGGTTCCTA                        unassigned    0.0916
# ...                 ...                               ...       ...
# 10662  TTTGTCAGTGGCGAAT  3577-3_NOW28_205061460121_R09C01    1.0000
# 10663  TTTGTCAGTGTAACGG    28126_NOW4_205061460121_R03C02    1.0000
# 10664  TTTGTCAGTTTGGGCC  3577-3_NOW28_205061460121_R09C01    1.0000
# 10665  TTTGTCATCGATGAGG    28126_NOW4_205061460121_R03C02    0.9830
# 10666  TTTGTCATCGCTGATA  5401-35_NOW1_205061460074_R08C01    1.0000
#
#        prob_doublet  n_vars best_singlet   best_doublet  doublet_logLikRatio  \
# ...

# %%
minMAF01_minCount10 = pd.concat([minMAF01_minCount10, unsupervised], axis=0)
# Out:
#                    cell                          donor_id  prob_max  \
# 0      AAACCCAAGAAGATCT                        unassigned     0.679
# 1      AAACCCAAGCAGATAT  3577-3_NOW28_205061460121_R09C01     1.000
# 2      AAACCCAAGCTACGTT                        unassigned     0.956
# 3      AAACCCAAGCTTCGTA    28126_NOW4_205061460121_R03C02     0.994
# 4      AAACCCAAGTACAACA                        unassigned     0.711
# ...                 ...                               ...       ...
# 10662  TTTGTCAGTGGCGAAT  3577-3_NOW28_205061460121_R09C01     1.000
# 10663  TTTGTCAGTGTAACGG    28126_NOW4_205061460121_R03C02     1.000
# 10664  TTTGTCAGTTTGGGCC  3577-3_NOW28_205061460121_R09C01     1.000
# 10665  TTTGTCATCGATGAGG    28126_NOW4_205061460121_R03C02     0.983
# 10666  TTTGTCATCGCTGATA  5401-35_NOW1_205061460074_R08C01     1.000
#
#        prob_doublet  n_vars                      best_singlet  \
# 0      1.480000e-01      14  5401-35_NOW1_205061460074_R08C01
# ...

# %%
minMAF01_minCount10.to_csv('/mnt/sdb/scz_meta_analysis_processed/shin_nowakowski/anndata_objs/donor_assignments.csv')
