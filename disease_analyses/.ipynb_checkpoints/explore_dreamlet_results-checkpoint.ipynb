# %%
import os
import gc
from pathlib import Path
from itertools import combinations

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import anndata as ad
import scanpy as sc

# %matplotlib inline

# %%
## Known Genes In Deleted Regions ##

GENES_22q11 = ["TBX1",  "COMT",  "DGCR8",    "CRKL",  "PRODH",  "HIRA",  "LZTR1",    "RTN4R",   "SNAP29",    "ZDHHC8"]

GENES_22q11_EXTENDED = ["RANBP1", "MED15",  "PI4KA",  "SLC25A1", "SEPT5", "GP1BB", "ZNF74",   
                     "CLDN5",    "ARVCF", "FAM230"]

GENES_3q29 = ["DLG1", "PAK2", "FBXO45", "RNF168", "TFRC", "BDH1", "PCYT1A", "ATP13A3"]

GENES_3q29_EXTENDED = ["WDR53", "CEP19",  "TM4SF1",  "SENP5", "MFI2", "UBXN7"]

GENES_15q13 = ["CHRNA7", "OTUD7A", "KLF13", "TRPM1", "FAN1", "MTMR10", "ARHGAP11B"]

GENES_15q13_EXTNEDED = ["POLR2M", "GOLGA8A", "GOLGA8B", "GOLGA8C", "GOLGA8D", "GOLGA8E", "GOLGA8F", "GOLGA8G", "GOLGA8H", "GOLGA8I"]

# %%
## Read in DEG Lists ##

CSV_PATH = '/mnt/sdb/scz_meta_analysis_processed/dge_signatures/dreamlet_dges/disease_analyses/'

dge_22q11 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_22q11_dge_scz_results.csv')
dge_NRXN1 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_NRNXN1_dge_scz_results.csv')
dge_3q29 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_3q29_dge_scz_results.csv')
dge_15q13 = pd.read_csv(Path(CSV_PATH) / 'dreamlet_15q13_dge_scz_results.csv')
dge_Idiopathic = pd.read_csv(Path(CSV_PATH) / 'dreamlet_Idiopathic_dge_scz_results.csv')

# %%
UNIQUE_22q11 = np.unique(dge_22q11[(dge_22q11['adj.P.Val'] < 0.05)]['ID'])

UNIQUE_NRXN1 = np.unique(dge_NRXN1[(dge_NRXN1['adj.P.Val'] < 0.05)]['ID'])

UNIQUE_3q29 = np.unique(dge_3q29[(dge_3q29['adj.P.Val'] < 0.05)]['ID'])

UNIQUE_15q13 = np.unique(dge_15q13[(dge_15q13['adj.P.Val'] < 0.05)]['ID'])

UNIQUE_Idiopathic = np.unique(dge_Idiopathic[(dge_Idiopathic['adj.P.Val'] < 0.05)]['ID'])

# %%
## Pairwise Combinations

gene_sets = {"22q11": set(UNIQUE_22q11), "NRXN1": set(UNIQUE_NRXN1), 
             "3q29": set(UNIQUE_3q29),    "15q13": set(UNIQUE_15q13),
             "Idiopathic": set(UNIQUE_Idiopathic),}

for (name1, set1), (name2, set2) in combinations(gene_sets.items(), 2):
    overlap = set1 & set2
    print(f"{name1} ∩ {name2}: {len(overlap)} genes")
    if len(overlap) > 0:
        print(overlap)
        print()
# Out:
# 22q11 ∩ NRXN1: 0 genes
# 22q11 ∩ 3q29: 0 genes
# 22q11 ∩ 15q13: 0 genes
# 22q11 ∩ Idiopathic: 2 genes
# {'PHC1', 'SSC4D'}
#
# NRXN1 ∩ 3q29: 0 genes
# NRXN1 ∩ 15q13: 0 genes
# NRXN1 ∩ Idiopathic: 0 genes
# 3q29 ∩ 15q13: 0 genes
# 3q29 ∩ Idiopathic: 2 genes
# {'DYNLT2B', 'FBXO45'}
#
# 15q13 ∩ Idiopathic: 0 genes

# %%
## What percentage of the Known Genes in the Chr Block are DE ##

## make a heatmap for this ##

## 22q11 ##

print('22q11')
print(np.unique(dge_22q11[dge_22q11['adj.P.Val'] < 0.05]['ID'][dge_22q11[dge_22q11['adj.P.Val'] < 0.05]['ID'].isin(GENES_22q11)]))
print('22q11 extended')
print(np.unique(dge_22q11[dge_22q11['adj.P.Val'] < 0.05]['ID'][dge_22q11[dge_22q11['adj.P.Val'] < 0.05]['ID'].isin(GENES_22q11_EXTENDED)]))
print('\n')

## 3q29 ##

print('3q29')
print(np.unique(dge_3q29[dge_3q29['adj.P.Val'] < 0.05]['ID'][dge_3q29[dge_3q29['adj.P.Val'] < 0.05]['ID'].isin(GENES_3q29)]))
print('3q29 extended')
print(np.unique(dge_3q29[dge_3q29['adj.P.Val'] < 0.05]['ID'][dge_3q29[dge_3q29['adj.P.Val'] < 0.05]['ID'].isin(GENES_3q29_EXTENDED)]))
print('\n')

## NRXN1 ##

print('NRXN1')
print(np.unique(dge_NRXN1[dge_NRXN1['adj.P.Val'] < 0.05]['ID'][dge_NRXN1[dge_NRXN1['adj.P.Val'] < 0.05]['ID'].isin(['NRXN1'])]))
print('\n')

## 15q13 ##

print('15q13')
print(np.unique(dge_15q13[dge_15q13['adj.P.Val'] < 0.05]['ID'][dge_15q13[dge_15q13['adj.P.Val'] < 0.05]['ID'].isin([GENES_15q13])]))
print('15q13 extended')
print(np.unique(dge_15q13[dge_15q13['adj.P.Val'] < 0.05]['ID'][dge_15q13[dge_15q13['adj.P.Val'] < 0.05]['ID'].isin([GENES_15q13_EXTNEDED])]))
print('\n')

## Idiopathic ##

print('Idiopathic')
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_22q11)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_22q11_EXTENDED)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_3q29)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_3q29_EXTENDED)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_15q13)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(GENES_15q13_EXTNEDED)]))
print(np.unique(dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'][dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]['ID'].isin(['NRXN1'])]))

## Idiopathic SCZ Shares 2 genes in Common with 3q29 deletion and Nothing Else ##
# Out:
# 22q11
# ['COMT' 'CRKL' 'HIRA' 'LZTR1' 'RTN4R' 'SNAP29' 'ZDHHC8']
# 22q11 extended
# ['ARVCF' 'MED15' 'PI4KA' 'RANBP1' 'SLC25A1']
#
#
# 3q29
# ['DLG1' 'FBXO45' 'PCYT1A' 'RNF168']
# 3q29 extended
# ['WDR53']
#
#
# NRXN1
# []
#
#
# 15q13
# []
# 15q13 extended
# []
#
#
# Idiopathic
# []
# []
# ['FBXO45' 'TFRC']
# []
# []
# []
# []

# %%
dge_22q11[(dge_22q11['adj.P.Val'] < 0.05) & (np.abs(dge_22q11['logFC']) > 1)]
# Out:
#                                           assay       ID     logFC   AveExpr  \
# 3            Mixed Neurons FGF12+GRIN2B+CAMK2B+   DGCR6L -1.005780  5.543906
# 30       Mesenchymal-like cells VIM+VCAN+SPARC+  C6orf47  1.059411  3.883652
# 34                  Radial Glia SOX2+VIM+FABP7+     HIRA -1.042272  3.166057
# 35       Mesenchymal-like cells VIM+VCAN+SPARC+    IFI27  1.987861  3.392458
# 41                 Radial Glia SOX2+PAX6+FABP7+  SLC25A1 -1.006556  5.840882
# 44                 Radial Glia SOX2+PAX6+FABP7+     COMT -2.124549  4.210205
# 45                  Radial Glia SOX2+VIM+FABP7+    ARVCF -1.029302  3.941597
# 49       Mesenchymal-like cells VIM+VCAN+SPARC+   PIK3CA -1.522734  4.096901
# 54                  Radial Glia SOX2+VIM+FABP7+     COMT -2.063470  4.120611
# 56   Proliferative Radial Glia SOX2+HES6+TOP2A+     COMT -2.073465  3.273161
# 59       Mesenchymal-like cells VIM+VCAN+SPARC+     PHC1 -1.237607  4.141524
# 65                  Radial Glia SOX2+VIM+FABP7+    SSC4D  1.050100  1.567539
# 66  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     COMT -2.035749  3.011438
#
#            t       P.Value  adj.P.Val         B     z.std
# 3  -7.139504  6.647040e-10   0.000016  3.078634 -6.174269
# 30  5.483152  5.061716e-07   0.001607  5.938861  5.023959
# 34 -5.502756  1.474575e-06   0.004144 -0.418815 -4.814651
# 35  5.275109  1.515710e-06   0.004144  2.179954  4.809153
# 41 -5.017550  2.999994e-06   0.007030  0.486380 -4.670820
# 44 -4.908568  4.015905e-06   0.008783 -0.907957 -4.610557
# 45 -6.089659  4.626996e-06   0.009900  2.785095 -4.581026
# 49 -5.037840  9.245791e-06   0.017921  4.222712 -4.434100
# 54 -4.594966  1.611281e-05   0.028833 -3.930001 -4.312898
# 56 -4.558106  1.692035e-05   0.029215 -2.852614 -4.302078
# 59 -4.713216  1.866853e-05   0.030622  2.763915 -4.280248
# 65  4.439816  2.872640e-05   0.042836 -0.131626  4.183335
# 66 -4.546270  2.945175e-05   0.043262 -2.451204 -4.177665

# %%
dge_22q11[(dge_22q11['adj.P.Val'] < 0.05) & (dge_22q11['assay'] == 'Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+')]
# Out:
#                                           assay        ID     logFC   AveExpr  \
# 0   Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     PI4KA -0.820498  4.971860
# 1   Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     MED15 -0.821131  4.531648
# 12  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    SNAP29 -0.772316  5.014354
# 14  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+      CRKL -0.796497  4.724569
# 15  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  C22orf39 -0.727337  5.706293
# 20  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+      ESS2 -0.741827  4.140018
# 27  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    RANBP1 -0.634556  7.820246
# 32  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     ARVCF -0.899626  3.588668
# 38  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     DGCR2 -0.861911  3.808937
# 46  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     RTN4R -0.856013  4.226957
# 53  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+     DGCR6 -0.828870  3.342403
# 66  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+      COMT -2.035749  3.011438
#
#            t       P.Value  adj.P.Val          B     z.std
# 0  -7.643632  3.560559e-11   0.000004  10.374025 -6.621299
# 1  -7.388265  1.384501e-10   0.000007   6.960852 -6.417588
# 12 -6.811021  2.954268e-08   0.000224   6.188181 -5.544126
# 14 -5.997730  4.843240e-08   0.000318   5.201524 -5.456972
# 15 -5.954626  6.794210e-08   0.000418   3.263112 -5.396530
# 20 -5.784844  1.609722e-07   0.000754   4.854414 -5.239546
# 27 -5.553408  4.388332e-07   0.001542   2.782138 -5.051291
# 32 -5.340270  7.006262e-07   0.002090   3.825270 -4.961190
# 38 -5.091005  2.016560e-06   0.004994   2.892076 -4.751758
# 46 -4.904799  5.077799e-06   0.010633   2.310817 -4.561547
# 53 -4.694025  1.447625e-05   0.026384   1.588390 -4.336511
# 66 -4.546270  2.945175e-05   0.043262  -2.451204 -4.177665

# %%
dge_22q11[dge_22q11['adj.P.Val'] < 0.05].groupby('assay').count()
# Out:
#                                              ID  logFC  AveExpr   t  P.Value  \
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  12     12       12  12       12
# Hindbrain Neurons NR2F2+PBX3+LHX1+           15     15       15  15       15
# Mesenchymal-like cells VIM+VCAN+SPARC+        6      6        6   6        6
# Mixed Neurons FGF12+GRIN2B+CAMK2B+           10     10       10  10       10
# Proliferative Radial Glia SOX2+HES6+TOP2A+   10     10       10  10       10
# Radial Glia SOX2+PAX6+FABP7+                  9      9        9   9        9
# Radial Glia SOX2+VIM+FABP7+                  11     11       11  11       11
#
#                                              adj.P.Val   B  z.std
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+         12  12     12
# Hindbrain Neurons NR2F2+PBX3+LHX1+                  15  15     15
# Mesenchymal-like cells VIM+VCAN+SPARC+               6   6      6
# Mixed Neurons FGF12+GRIN2B+CAMK2B+                  10  10     10
# Proliferative Radial Glia SOX2+HES6+TOP2A+          10  10     10
# Radial Glia SOX2+PAX6+FABP7+                         9   9      9
# Radial Glia SOX2+VIM+FABP7+                         11  11     11

# %%
dge_NRXN1[dge_NRXN1['adj.P.Val'] < 0.05].groupby('assay').count()
# Out:
# Empty DataFrame
# Columns: [ID, logFC, AveExpr, t, P.Value, adj.P.Val, B, z.std]
# Index: []

# %%
dge_3q29[dge_3q29['adj.P.Val'] < 0.05].groupby('assay').count()
# Out:
#                                              ID  logFC  AveExpr   t  P.Value  \
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+   7      7        7   7        7
# GABAergic GAD1+GAD2+CALB2+                    5      5        5   5        5
# Hindbrain Neurons NR2F2+PBX3+LHX1+            7      7        7   7        7
# Mixed Neurons FGF12+GRIN2B+CAMK2B+            7      7        7   7        7
# Proliferative Radial Glia SOX2+HES6+TOP2A+    8      8        8   8        8
# Radial Glia SOX2+PAX6+FABP7+                  6      6        6   6        6
# Radial Glia SOX2+VIM+FABP7+                  11     11       11  11       11
#
#                                              adj.P.Val   B  z.std
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+          7   7      7
# GABAergic GAD1+GAD2+CALB2+                           5   5      5
# Hindbrain Neurons NR2F2+PBX3+LHX1+                   7   7      7
# Mixed Neurons FGF12+GRIN2B+CAMK2B+                   7   7      7
# Proliferative Radial Glia SOX2+HES6+TOP2A+           8   8      8
# Radial Glia SOX2+PAX6+FABP7+                         6   6      6
# Radial Glia SOX2+VIM+FABP7+                         11  11     11

# %%
dge_15q13[dge_15q13['adj.P.Val'] < 0.05].groupby('assay').count()
# Out:
#                                              ID  logFC  AveExpr  t  P.Value  \
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+   3      3        3  3        3
# GABAergic GAD1+GAD2+CALB2+                    1      1        1  1        1
# Hindbrain Neurons NR2F2+PBX3+LHX1+            1      1        1  1        1
# Mixed Neurons FGF12+GRIN2B+CAMK2B+            1      1        1  1        1
#
#                                              adj.P.Val  B  z.std
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+          3  3      3
# GABAergic GAD1+GAD2+CALB2+                           1  1      1
# Hindbrain Neurons NR2F2+PBX3+LHX1+                   1  1      1
# Mixed Neurons FGF12+GRIN2B+CAMK2B+                   1  1      1

# %%
dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05].groupby('assay').count()
# Out:
#                                               ID  logFC  AveExpr    t  \
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+  441    441      441  441
# GABAergic GAD1+GAD2+CALB2+                    56     56       56   56
# Hindbrain Neurons NR2F2+PBX3+LHX1+           121    121      121  121
# Mesenchymal-like cells VIM+VCAN+SPARC+       147    147      147  147
# Mixed Neurons FGF12+GRIN2B+CAMK2B+            34     34       34   34
# Proliferative Radial Glia SOX2+HES6+TOP2A+   519    519      519  519
# Radial Glia SOX2+PAX6+FABP7+                 159    159      159  159
# Radial Glia SOX2+VIM+FABP7+                  327    327      327  327
#
#                                              P.Value  adj.P.Val    B  z.std
# assay
# Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+      441        441  441    441
# GABAergic GAD1+GAD2+CALB2+                        56         56   56     56
# Hindbrain Neurons NR2F2+PBX3+LHX1+               121        121  121    121
# Mesenchymal-like cells VIM+VCAN+SPARC+           147        147  147    147
# Mixed Neurons FGF12+GRIN2B+CAMK2B+                34         34   34     34
# Proliferative Radial Glia SOX2+HES6+TOP2A+       519        519  519    519
# Radial Glia SOX2+PAX6+FABP7+                     159        159  159    159
# Radial Glia SOX2+VIM+FABP7+                      327        327  327    327

# %%
## Focusing on Idiopathic SCZ ##

## To what degree are DEGs conserved across celltype ##

dge_Idiopathic[dge_Idiopathic['adj.P.Val'] < 0.05]
# Out:
#                                             assay       ID     logFC  \
# 0      Proliferative Radial Glia SOX2+HES6+TOP2A+     ALAD  3.052905
# 1      Proliferative Radial Glia SOX2+HES6+TOP2A+    BLVRB  4.073698
# 2                     Radial Glia SOX2+VIM+FABP7+    CERS4  3.180029
# 3      Proliferative Radial Glia SOX2+HES6+TOP2A+   ELOVL1  2.858966
# 4                     Radial Glia SOX2+VIM+FABP7+   ZNF165  2.641726
# ...                                           ...      ...       ...
# 1799   Proliferative Radial Glia SOX2+HES6+TOP2A+  HTATSF1 -0.823571
# 1800  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    GINM1 -1.534939
# 1801                 Radial Glia SOX2+PAX6+FABP7+  JAKMIP2 -1.782013
# 1802  Dorsal Forebrain Neuron FOXG1+EMX1+NEUROG1+    GON4L -1.527373
# 1803   Proliferative Radial Glia SOX2+HES6+TOP2A+     SOX2 -0.896669
#
#        AveExpr          t       P.Value     adj.P.Val          B     z.std
# 0     2.824755  16.271148  6.344177e-21  6.243812e-16  53.005946  9.384124
# 1     5.689543  10.447764  2.266840e-16  1.115489e-11  23.195661  8.207053
# 2     4.737593   9.621767  3.727709e-15  1.222912e-10  24.164181  7.863760
# 3     3.220990   9.258769  4.689903e-13  1.153927e-08  18.202019  7.233995
# 4     1.035159   7.982792  3.805093e-12  7.489793e-08  17.282845  6.944238
# ...        ...        ...           ...           ...        ...       ...
# 1799  6.902916  -3.501434  9.113152e-04  4.980459e-02  -1.614194 -3.316565
# 1800  5.492069  -3.484913  9.113990e-04  4.980459e-02  -0.637860 -3.316539
# 1801  5.269445  -3.554382  9.125631e-04  4.984053e-02  -0.655860 -3.316182
# 1802  6.045581  -3.581194  9.148642e-04  4.993850e-02  -0.493868 -3.315478
# 1803  9.114642  -3.434510  9.154335e-04  4.994187e-02  -2.011146 -3.315304
#
# [1804 rows x 9 columns]

# %%
## negative overlap and shared lists ##

## code to test difference of differences ##

# %%
print(dge_22q11[(dge_22q11['adj.P.Val'] < 0.05) & (dge_22q11['logFC'] > 1)]['ID'].shape)

print(dge_NRXN1[(dge_NRXN1['adj.P.Val'] < 0.05) & (dge_NRXN1['logFC'] > 1)]['ID'].shape)

print(dge_3q29[(dge_3q29['adj.P.Val'] < 0.05) & (dge_3q29['logFC'] > 1)]['ID'].shape)

print(dge_15q13[(dge_15q13['adj.P.Val'] < 0.05) & (dge_15q13['logFC'] > 1)]['ID'].shape)

print(dge_Idiopathic[(dge_Idiopathic['adj.P.Val'] < 0.05) & (dge_Idiopathic['logFC'] > 1)]['ID'].shape)
# Out:
# (3,)
# (0,)
# (6,)
# (6,)
# (1123,)

# %%
print(np.unique(dge_22q11[(dge_22q11['adj.P.Val'] < 0.05) & (dge_22q11['logFC'] > 1)]['ID']).tolist())

print(np.unique(dge_NRXN1[(dge_NRXN1['adj.P.Val'] < 0.05) & (dge_NRXN1['logFC'] > 1)]['ID'].tolist()))

print(np.unique(dge_3q29[(dge_3q29['adj.P.Val'] < 0.05) & (dge_3q29['logFC'] > 1)]['ID'].tolist()))

print(np.unique(dge_15q13[(dge_15q13['adj.P.Val'] < 0.05) & (dge_15q13['logFC'] > 1)]['ID'].tolist()))

print(np.unique(dge_Idiopathic[(dge_Idiopathic['adj.P.Val'] < 0.05) & (dge_Idiopathic['logFC'] > 1)]['ID']).tolist())
# Out:
# ['C6orf47', 'IFI27', 'SSC4D']
# []
# ['CHCHD2' 'CTSF' 'ELAPOR2' 'NLRP2']
# ['BEX5' 'POTEI' 'TCEAL5']
# ['ABALON', 'ABCA7', 'ABCB10', 'ABCC10', 'ABCG4', 'ABCG8', 'ABHD14B', 'ABHD16A', 'ABHD4', 'ACAD10', 'ACADS', 'ACSL1', 'ADA', 'ADAM19', 'ADAM8', 'ADAMTS4', 'ADAMTSL4', 'ADAT2', 'ADCK1', 'ADCY7', 'ADCYAP1R1', 'ADIPOR1', 'AFAP1L2', 'AGAP4', 'AGAP6', 'AGER', 'AHCY', 'AKAP3', 'ALAD', 'ALDH16A1', 'ALDH2', 'AMACR', 'AMOT', 'ANGEL1', 'ANKDD1A', 'ANKFY1', 'ANKH', 'ANKLE1', 'ANKMY1', 'ANKRD24', 'ANKRD52', 'ANKRD9', 'ANLN', 'ANXA2R', 'ANXA4', 'AP4B1-AS1', 'AP5B1', 'APOBEC3C', 'APOC1', 'APOE', 'APOL2', 'ARFGAP1', 'ARHGEF11', 'ARHGEF17', 'ARHGEF39', 'ARHGEF40', 'ARHGEF7-AS2', 'ARID3A', 'ARL4D', 'ARL8B', 'ARMC7', 'ARMT1', 'ARNT', 'ARPC1B', 'ARRDC2', 'ASB1', 'ASH2L', 'ASIC4', 'ASNS', 'ATAD3C', 'ATF5', 'ATG14', 'ATG9A', 'ATL2', 'ATL3', 'ATOX1', 'ATP11A', 'ATP1B2', 'ATP5MGL', 'ATP6V1E1', 'ATP6V1FNB', 'ATRIP', 'ATXN7', 'AXIN1', 'AZU1', 'B3GNT2', 'B4GALT4', 'BAMBI', 'BBS9', 'BCL11B', 'BCL2L1', 'BCL2L11', 'BCL2L12', 'BEND3', 'BET1L', 'BLM', 'BLOC1S3', 'BLVRB', 'BMP2', 'BRI3BP', 'BRPF3', 'BTD', 'C15orf39', 'C16orf95-DT', 'C18orf25', 'C1GALT1', 'C1QL3', 'C1orf220', 'C1orf74', 'C2orf72', 'C2orf88', 'C6orf163', 'C7orf25', 'C8orf58', 'CA11', 'CA5B', 'CABLES2', 'CACNA1C-AS2', 'CACNB2', 'CAD', 'CAMK2D', 'CAPG', 'CAPN1', 'CAVIN1', 'CBFA2T3', 'CCDC106', 'CCDC122', 'CCDC24', 'CCNA2', 'CCNB1', 'CCND3', 'CCNDBP1', 'CD160', 'CD2AP-DT', 'CD68', 'CDC6', 'CDC7', 'CDCA5', 'CDHR1', 'CDK3', 'CDKL1', 'CDON', 'CELF4', 'CELSR1', 'CEP131', 'CEP85', 'CERCAM', 'CERNA1', 'CERS4', 'CES3', 'CFD', 'CFP', 'CGN', 'CHEK2', 'CHPT1', 'CIART', 'CINP', 'CISD3', 'CISH', 'CLDN6', 'CLN8', 'CMAS', 'CMC4', 'CNIH3', 'CNTD1', 'COL18A1', 'COL5A1', 'COL9A2', 'COLGALT1', 'COQ10B', 'COX17', 'CPNE7', 'CPOX', 'CRIM1', 'CRLF1', 'CSNK2A3', 'CSRNP1', 'CTBP1-AS', 'CTBS', 'CTF1', 'CTSV', 'CUL4A', 'CXADR', 'CXCL12', 'CYB5R1', 'CYP7B1', 'DBNDD1', 'DCAF4', 'DCST1-AS1', 'DDIAS', 'DDIT3', 'DDT', 'DEDD2', 'DEGS2', 'DESI1', 'DGKZ', 'DIP2C-AS1', 'DLC1', 'DLGAP1-AS2', 'DMGDH', 'DMKN', 'DNAAF5', 'DNAH10', 'DNAH5', 'DNAJB6', 'DNASE1L1', 'DNMBP', 'DNMT3B', 'DNPEP', 'DOCK6', 'DOK4', 'DPF3', 'DRP2', 'DUSP5', 'ECE1', 'ECHDC2', 'EDC4', 'EDEM1', 'EDEM2', 'EEF1D', 'EFNA1', 'EFNA3', 'EFNA4', 'EGFL7', 'EID3', 'EIF5A', 'ELF1', 'ELF3', 'ELFN2', 'ELK1', 'ELL2', 'ELMO3', 'ELOVL1', 'ELOVL4', 'EML2', 'ENGASE', 'ENSG00000185065', 'ENSG00000203279', 'ENSG00000204055', 'ENSG00000204758', 'ENSG00000205959', 'ENSG00000225173', 'ENSG00000225489', 'ENSG00000225554', 'ENSG00000225889', 'ENSG00000227388', 'ENSG00000227782', 'ENSG00000227908', 'ENSG00000228748', 'ENSG00000232533', 'ENSG00000232748', 'ENSG00000232995', 'ENSG00000233178', 'ENSG00000242539', 'ENSG00000242628', 'ENSG00000244701', 'ENSG00000246465', 'ENSG00000246731', 'ENSG00000250790', 'ENSG00000251143', 'ENSG00000253200', 'ENSG00000253210', 'ENSG00000253636', 'ENSG00000254528', 'ENSG00000255224', 'ENSG00000255471', 'ENSG00000257433', 'ENSG00000257764', 'ENSG00000258634', 'ENSG00000258813', 'ENSG00000258944', 'ENSG00000259529', 'ENSG00000259715', 'ENSG00000260163', 'ENSG00000260641', 'ENSG00000261071', 'ENSG00000261478', 'ENSG00000261839', 'ENSG00000261888', 'ENSG00000263823', 'ENSG00000264207', 'ENSG00000267198', 'ENSG00000267388', 'ENSG00000267397', 'ENSG00000267469', 'ENSG00000267651', 'ENSG00000267940', 'ENSG00000268220', 'ENSG00000269935', 'ENSG00000269937', 'ENSG00000269983', 'ENSG00000270074', 'ENSG00000270091', 'ENSG00000270096', 'ENSG00000270127', 'ENSG00000271344', 'ENSG00000271858', 'ENSG00000271941', 'ENSG00000272009', 'ENSG00000272077', 'ENSG00000272079', 'ENSG00000272128', 'ENSG00000272275', 'ENSG00000272356', 'ENSG00000272361', 'ENSG00000272432', 'ENSG00000272486', 'ENSG00000272512', 'ENSG00000272563', 'ENSG00000272604', 'ENSG00000272696', 'ENSG00000272744', 'ENSG00000272871', 'ENSG00000273011', 'ENSG00000273032', 'ENSG00000273084', 'ENSG00000273188', 'ENSG00000273226', 'ENSG00000273230', 'ENSG00000273237', 'ENSG00000273271', 'ENSG00000273619', 'ENSG00000274315', 'ENSG00000274341', 'ENSG00000274400', 'ENSG00000274678', 'ENSG00000274987', 'ENSG00000275055', ' ...
